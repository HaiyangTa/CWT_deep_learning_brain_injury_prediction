# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# ### 7 fold cross validation

# %%
BIO = [0.0494326480170767, 0.921428571428571, 0.537305421363392, 0.987179487179487, 0.959444444444444, 0.712893659087699, 1]
BIO_EEG = [0.561566, 0.855357	, 0.917874, 0.987179, 0.961667, 0.867533, 0.750085]
EEG = [0.72636815920398, 0.501041666666666, 0.651128139633886, 0.649166666666666, 0.367326732673267, 0.524648547328959, 0.208942836393816]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# ----- style knobs -----
LW        = 4   # line width
MS        = 9.5   # marker size
LABEL_FS  = 40    # x/y axis label fontsize
TICK_FS   = 40    # tick label fontsize
ANNO_FS   = 35    # per-point text fontsize
SPINE_W   = 2.4   # outer border width
LEGEND_FS = 32    # legend text fontsize

folds = np.arange(1, len(BIO) + 1)

plt.figure(figsize=(15, 10))
ax = plt.gca()

# --- lines (thicker) ---
line1, = ax.plot(
    folds, BIO, color='red', marker='o', linewidth=LW, markersize=MS,
    markerfacecolor='red', markeredgecolor='red', label='DIAG ONLY'
)
line2, = ax.plot(
    folds, BIO_EEG, color='black', marker='s', linewidth=LW, markersize=MS,
    markerfacecolor='black', markeredgecolor='black', label='DIAG+EEG'
)
line3, = ax.plot(
    folds, EEG, color='blue', marker='^', linewidth=LW, markersize=MS,
    markerfacecolor='blue', markeredgecolor='black', label='EEG ONLY'
)

# --- annotate each point with its value ---
def annotate_points(x, y):
    for xi, yi in zip(x, y):
        ax.annotate(f"{yi:.3f}", (xi, yi),
                    textcoords="offset points", xytext=(0, 8),
                    ha='center', fontsize=ANNO_FS)

annotate_points(folds, BIO)
annotate_points(folds, BIO_EEG)
annotate_points(folds, EEG)

# --- axes & labels (larger) ---
ax.set_xlabel("# of Fold", fontsize=LABEL_FS, fontweight="bold")
ax.set_ylabel("AUROC",    fontsize=LABEL_FS, fontweight="bold")

ax.set_ylim(0.0, 1.05)
ax.set_yticks(np.arange(0.0, 1.01, 0.1))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax.set_xticks(folds)

# larger tick labels + thicker ticks
ax.tick_params(axis='both', which='major', labelsize=TICK_FS, width=SPINE_W*0.75, length=6)

# outer border in bold black
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(SPINE_W)

# legend with black border, larger text
leg = ax.legend(frameon=True, fontsize=LEGEND_FS)
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(1.6)

ax.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.savefig("fold_series_plot_matplotlib.png", dpi=400)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import matplotlib.transforms as mtransforms

# assumes BIO, BIO_EEG, EEG are already defined lists
labels = ["BIO", "BIO+EEG", "EEG"]
series = [BIO, BIO_EEG, EEG]

means = np.array([np.mean(s) for s in series], dtype=float)
stds  = np.array([np.std(s, ddof=1) for s in series], dtype=float)  # sample std

x = np.arange(len(labels))

# ------- figure -------
fig, ax = plt.subplots(figsize=(9, 7))
ax.set_facecolor("white")
ax.set_axisbelow(True)

# dynamic y-top (cap to 1.0 and add a small headroom)
m_plus_s = float(np.max(means + stds))
y_top = min(1.2, m_plus_s + 0.2)
ax.set_ylim(0.0, y_top)

# ------- white bars + black edges -------
bars = ax.bar(
    x, means, width=0.6,
    facecolor="white", edgecolor="black", linewidth=2.0, zorder=3
)

# black error bars
ax.errorbar(
    x, means, yerr=stds, fmt="none",
    ecolor="black", elinewidth=2.0, capsize=6, zorder=4
)

# ------- axis formatting -------
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=13, fontweight="bold")
ax.set_ylabel("AUROC", fontsize=15, fontweight="bold")

ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax.tick_params(axis='y', labelsize=12)
ax.grid(axis="y", linestyle="--", alpha=0.35)

# bold black border
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(2.2)

# ------- non-overlapping value labels (to the right of whisker) -------
offset_pts = mtransforms.ScaledTranslation(0, 6/72., fig.dpi_scale_trans)  # 6pt up
for i, (m, s) in enumerate(zip(means, stds)):
    y_text = min(y_top - 0.01, m + s)  # at whisker tip (with cap)
    ax.text(i, y_text, f"{m:.2f} ± {s:.2f}",
            transform=ax.transData + offset_pts,
            ha="center", va="bottom", fontsize=12, color="black")

plt.tight_layout()
plt.savefig("mean_std_bar_matplotlib_beautiful.png", dpi=300)
plt.show()

# %% [markdown]
# ### 14 fold cross validation

# %%
BIO_EEG = [0.919540, 0.515152, 0.752381, 1.000000, 1.000000, 0.999001, 0.866667, 1.000000, 1.000000, 0.850000, 0.315789, 1.000000, 0.000000, 1.000000]
BIO = [0.08045977011494254, 1.0, 0.8, 0.24489795918367352, 1.0, 0.038461538461538436, 0.0, 1.0, 1.0, 0.85, 0.0, 1.0, 0.0, 0.0]
EEG = [0.5142857142857143,
 0.27037037037037037,
 0.14705882352941177,
 0.6664086687306502,
 0.0,
 0.893028024606972,
 0.75,
 0.603448275862069,
 0.3564839934888768,
 1.0,
 0.07236842105263162,
 0.6269303201506591,
 0.3090909090909091,
 0.6053067993366501]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter


folds = np.arange(1, len(BIO) + 1)

plt.figure(figsize=(15, 10))
ax = plt.gca()

# --- plot with matplotlib only ---
# --- plot with specified colors ---
line1, = ax.plot(folds, BIO,      color='red',   marker='o', linewidth=2, label='BIO ONLY',
                  markerfacecolor='red', markeredgecolor='red')
line2, = ax.plot(folds, BIO_EEG,  color='black', marker='s', linewidth=2, label='BIO+EEG',
                  markerfacecolor='black', markeredgecolor='black')
line3, = ax.plot(folds, EEG,      color='blue',  marker='^', linewidth=2, label='EEG ONLY',
                  markerfacecolor='blue', markeredgecolor='black')

# --- annotate each point with its value ---
def annotate_points(x, y):
    for xi, yi in zip(x, y):
        ax.annotate(f"{yi:.3f}", (xi, yi),
                    textcoords="offset points", xytext=(0, 6),
                    ha='center', fontsize=9)

annotate_points(folds, BIO)
annotate_points(folds, BIO_EEG)
annotate_points(folds, EEG)

# --- titles & axes ---
ax.set_title("14-fold cross validation", fontsize=16, pad=12)
ax.set_xlabel("# of Fold")
ax.set_ylabel("Value")

# y-axis: resolution 0.1
ax.set_ylim(0.0, 1.05)
ax.set_yticks(np.arange(0.0, 1.01, 0.1))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

# x-axis ticks at each fold
ax.set_xticks(folds)

# outer border in black
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(1.5)

# legend with black border
leg = ax.legend(frameon=True)
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(1.2)

ax.grid(True)
plt.tight_layout()
plt.savefig("fold_series_plot_matplotlib.png", dpi=200)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# assumes BIO, BIO_EEG, EEG are already defined lists
labels = ["BIO", "BIO+EEG", "EEG"]
series = [BIO, BIO_EEG, EEG]

means = [np.mean(s) for s in series]
stds  = [np.std(s, ddof=1) for s in series]  # sample std

x = np.arange(len(labels))
colors = ["#111111", "#111111", "#111111"]  # red, black, gold

fig, ax = plt.subplots(figsize=(7.5, 6.5))
ax.set_facecolor("white")
ax.set_axisbelow(True)

# dynamic y-top (capped at 1.0)
y_top = min(1.0, max(m + s for m, s in zip(means, stds)) + 0.08)

bars = ax.bar(
    x, means, yerr=stds, width=0.6,
    color=colors, edgecolor="black", linewidth=1.4,
    error_kw=dict(ecolor="black", elinewidth=1.2, capsize=6),  # <-- pass errorbar styling here
    zorder=3
)

# y-axis formatting (0.1 resolution)
ax.set_ylim(0, y_top+0.2)
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=11)
ax.set_ylabel("Value", fontsize=12)
ax.set_title("7 fold corss validation", fontsize=14, pad=12)

ax.grid(axis="y", linestyle="--", alpha=0.35)

for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(1.5)

for i, (m, s) in enumerate(zip(means, stds)):
    y_text = min(y_top - 0.02, m + s + 0.02)
    ax.text(i, y_text, f"{m:.2f} ± {s:.2f}",
            ha="center", va="bottom", fontsize=11, fontweight="medium")

plt.tight_layout()
plt.savefig("mean_std_bar_matplotlib_beautiful.png", dpi=200)
plt.show()

# %% [markdown]
# ### Different features

# %%
AGE_DIAGNOSIS_WEIGHT_HEIGHT = [0.561566, 0.855357, 0.917874, 0.987179, 0.961667, 0.867533, 0.750085]
AGE_DIAGNOSIS = [0.548815, 0.925000, 0.863661, 0.979487, 0.961667, 0.874029, 0.988666]
AGE_DIAGNOSIS_BSA = [0.578137, 0.877976, 0.876543, 0.982906, 0.961667, 0.875371, 0.673694]
AGE_DIAGNOSIS_WEIGHT_bsa_Type = [0.634030, 0.805060, 0.888352, 1.000000, 0.960000, 0.953961, 0.495183]
DIAGNOSIS = [0.679418, 0.937202, 0.879764, 0.913675, 0.961111, 0.947536, 0.596282]

# %%
np.mean(AGE_DIAGNOSIS_WEIGHT_HEIGHT)
# Out:
# 0.8430372857142858

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# ---------- style knobs ----------
LW        = 3.8    # line width
MS        = 9.5    # marker size
LABEL_FS  = 20     # x/y axis label fontsize
TITLE_FS  = 22
TICK_FS   = 16     # tick label fontsize
ANNO_FS   = 11     # per-point text fontsize
SPINE_W   = 2.4    # outer border width
LEGEND_FS = 13

# Distinct colors
COLORS = {
    "AGE_DIAGNOSIS_WEIGHT_HEIGHT": "#d62728",  # red
    "AGE_DIAGNOSIS":               "#1f77b4",  # blue
    "AGE_DIAGNOSIS_BSA":           "#2ca02c",  # green
    "AGE_DIAGNOSIS_WEIGHT_bsa_Type":"#9467bd", # purple
    "DIAGNOSIS":                   "#ff7f0e",  # orange
}

folds = np.arange(1, len(AGE_DIAGNOSIS_WEIGHT_HEIGHT) + 1)

plt.figure(figsize=(15, 10))
ax = plt.gca()

# ----- lines -----
l1, = ax.plot(
    folds, AGE_DIAGNOSIS_WEIGHT_HEIGHT, color=COLORS["AGE_DIAGNOSIS_WEIGHT_HEIGHT"],
    marker='o', linewidth=LW, markersize=MS,
    markerfacecolor=COLORS["AGE_DIAGNOSIS_WEIGHT_HEIGHT"], markeredgecolor="black",
    label='AGE_DIAGNOSIS_WEIGHT_HEIGHT'
)
l2, = ax.plot(
    folds, AGE_DIAGNOSIS, color=COLORS["AGE_DIAGNOSIS"],
    marker='s', linewidth=LW, markersize=MS,
    markerfacecolor=COLORS["AGE_DIAGNOSIS"], markeredgecolor="black",
    label='AGE_DIAGNOSIS'
)
l3, = ax.plot(
    folds, AGE_DIAGNOSIS_BSA, color=COLORS["AGE_DIAGNOSIS_BSA"],
    marker='^', linewidth=LW, markersize=MS,
    markerfacecolor=COLORS["AGE_DIAGNOSIS_BSA"], markeredgecolor="black",
    label='AGE_DIAGNOSIS_BSА'
)
l4, = ax.plot(
    folds, AGE_DIAGNOSIS_WEIGHT_bsa_Type, color=COLORS["AGE_DIAGNOSIS_WEIGHT_bsa_Type"],
    marker='D', linewidth=LW, markersize=MS,
    markerfacecolor=COLORS["AGE_DIAGNOSIS_WEIGHT_bsa_Type"], markeredgecolor="black",
    label='AGE_DIAGNOSIS_WEIGHT_bsa_Type'
)
l5, = ax.plot(
    folds, DIAGNOSIS, color=COLORS["DIAGNOSIS"],
    marker='p', linewidth=LW, markersize=MS,
    markerfacecolor=COLORS["DIAGNOSIS"], markeredgecolor="black",
    label='DIAGNOSIS'
)

# ----- annotate each point with its value -----
def annotate_points(x, y):
    for xi, yi in zip(x, y):
        ax.annotate(f"{yi:.3f}", (xi, yi),
                    textcoords="offset points", xytext=(0, 8),
                    ha='center', fontsize=ANNO_FS)

annotate_points(folds, AGE_DIAGNOSIS_WEIGHT_HEIGHT)
annotate_points(folds, AGE_DIAGNOSIS)
annotate_points(folds, AGE_DIAGNOSIS_BSA)
annotate_points(folds, AGE_DIAGNOSIS_WEIGHT_bsa_Type)
annotate_points(folds, DIAGNOSIS)

# ----- axes / labels / ticks -----
ax.set_title("7-fold cross validation", fontsize=TITLE_FS, pad=12, fontweight="bold")
ax.set_xlabel("# of Fold", fontsize=LABEL_FS, fontweight="bold")
ax.set_ylabel("AUROC",     fontsize=LABEL_FS, fontweight="bold")

ax.set_ylim(0.4, 1.05)
ax.set_yticks(np.arange(0.4, 1.01, 0.1))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax.set_xticks(folds)

ax.tick_params(axis='both', which='major', labelsize=TICK_FS, width=SPINE_W*0.75, length=6)

# bold black border
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(SPINE_W)

# legend with border
leg = ax.legend(frameon=True, fontsize=LEGEND_FS, ncol=1)
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(1.6)

ax.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.savefig("fold_series_plot_matplotlib.png", dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import matplotlib.transforms as mtransforms

# assumes these lists already exist
labels = [
    "AGE_DIAGNOSIS_WEIGHT_HEIGHT",
    "AGE_DIAGNOSIS",
    "AGE_DIAGNOSIS_BSA",
    "AGE_DIAGNOSIS_WEIGHT_bsa_Type",
    "DIAGNOSIS",
]
series = [
    AGE_DIAGNOSIS_WEIGHT_HEIGHT,
    AGE_DIAGNOSIS,
    AGE_DIAGNOSIS_BSA,
    AGE_DIAGNOSIS_WEIGHT_bsa_Type,
    DIAGNOSIS,
]

# stats
means = np.array([np.mean(s) for s in series], dtype=float)
stds  = np.array([np.std(s, ddof=1) for s in series], dtype=float)  # sample std

# --- sort by mean ascending ---
order  = np.argsort(means)
labels = [labels[i] for i in order]
means  = means[order]
stds   = stds[order]

x = np.arange(len(labels))

# figure
fig, ax = plt.subplots(figsize=(14, 8))
ax.set_facecolor("white")
ax.set_axisbelow(True)

# dynamic y-top (cap to 1.0 with a bit of headroom)
y_top = float(np.max(means + stds) + 0.08)
y_top = min(1.0, y_top)
ax.set_ylim(0.0, y_top+0.2)

# white bars + black edges
ax.bar(
    x, means, width=0.6,
    facecolor="white", edgecolor="black", linewidth=2.0, zorder=3
)

# black error bars
ax.errorbar(
    x, means, yerr=stds, fmt="none",
    ecolor="black", elinewidth=2.0, capsize=6, zorder=4
)

# axes / ticks / labels
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=12, rotation=25, ha="right")
ax.set_ylabel("AUROC", fontsize=16, fontweight="bold")

ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax.tick_params(axis='y', labelsize=12)

ax.grid(axis="y", linestyle="--", alpha=0.35)

# bold black border
for spine in ax.spines.values():
    spine.set_visible(True)
    spine.set_color("black")
    spine.set_linewidth(2.2)

# non-overlapping value labels (just above whisker tip)
offset_pts = mtransforms.ScaledTranslation(0, 6/72., fig.dpi_scale_trans)  # 6pt up
for i, (m, s) in enumerate(zip(means, stds)):
    y_text = min(y_top - 0.005, m + s)  # clamp to top
    ax.text(i, y_text, f"{m:.2f} ± {s:.2f}",
            transform=ax.transData + offset_pts,
            ha="center", va="bottom", fontsize=12, color="black")

plt.tight_layout()
plt.savefig("mean_std_bar_matplotlib_beautiful.png", dpi=300)
plt.show()

# %%
import numpy as np
import pandas as pd

data = {
    "AGE_DIAGNOSIS_WEIGHT_HEIGHT": [0.561566, 0.855357, 0.917874, 0.987179, 0.961667, 0.867533, 0.750085],
    "AGE_DIAGNOSIS":               [0.548815, 0.925000, 0.863661, 0.979487, 0.961667, 0.874029, 0.988666],
    "AGE_DIAGNOSIS_BSA":           [0.578137, 0.877976, 0.876543, 0.982906, 0.961667, 0.875371, 0.673694],
    "AGE_DIAGNOSIS_WEIGHT_bsa_Type":[0.634030, 0.805060, 0.888352, 1.000000, 0.960000, 0.953961, 0.495183],
    "DIAGNOSIS":                   [0.679418, 0.937202, 0.879764, 0.913675, 0.961111, 0.947536, 0.596282],
}

rows = []
for name, vals in data.items():
    arr = np.asarray(vals, dtype=float)
    mean = arr.mean()
    std  = arr.std(ddof=1)   # sample std (n-1)
    rows.append({"name": name, "n": arr.size, "mean": mean, "std": std})

df = pd.DataFrame(rows, columns=["name", "n", "mean", "std"])
print(df.to_string(index=False, float_format=lambda x: f"{x:.6f}"))
# Out:
#                          name  n     mean      std
#   AGE_DIAGNOSIS_WEIGHT_HEIGHT  7 0.843037 0.146668
#                 AGE_DIAGNOSIS  7 0.877332 0.152936
#             AGE_DIAGNOSIS_BSA  7 0.832328 0.150040
# AGE_DIAGNOSIS_WEIGHT_bsa_Type  7 0.819512 0.189266
#                     DIAGNOSIS  7 0.844998 0.145888
