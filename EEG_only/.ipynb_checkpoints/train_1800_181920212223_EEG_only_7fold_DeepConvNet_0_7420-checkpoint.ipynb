# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.transforms as transforms
import os
import argparse
from pathlib import Path
import re
import random
import math
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
from torch.utils.data import Dataset, DataLoader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### EEGNet-8,2

# %%
from pathlib import Path
import re, random, math, os
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    accuracy_score, roc_auc_score, classification_report, confusion_matrix,
    precision_score, recall_score, f1_score, roc_curve,
)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.constraints import max_norm   # used in DeepConvNet

# =========================
# Config
# =========================
SPLIT_DIR = r"/content/drive/MyDrive/CD/patient_data_clean_1800s_nozero_181920212223_in3days_v2"
POS_PATIENTS = {1, 2, 16, 19, 21, 22, 25, 37, 39, 43, 44, 47, 50, 56, 58, 62, 65, 66, 73, 78}

BATCH_SIZE       = 3
EPOCHS           = 100
LR               = 1e-4
SEED             = 1
K_FOLDS          = 7
BEST_MODEL_TPL   = "best_fold_{:02d}.h5"

# not used for dedup height; kept for reference
TARGET_H = 300

# =========================
# Noise config (train-time augmentation only)
# =========================
TRAIN_ADD_GAUSS_NOISE = True     # training generator only
TRAIN_NOISE_FRAC      = 0.10
TRAIN_NOISE_PROB      = 1.0
EPS_STD               = 1e-8

# =========================
# Repro
# =========================
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
for g in tf.config.list_physical_devices('GPU'):
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception:
        pass

# =========================
# Helpers for ID/labels
# =========================
PATIENT_NUM_RX = re.compile(r'^ID(\d+)')

def patient_num_from_path(pathlike):
    stem = Path(pathlike).stem
    m = PATIENT_NUM_RX.match(stem)
    return int(m.group(1)) if m else None

def label_for_file(p: Path) -> int:
    pnum = patient_num_from_path(p)
    return 1 if (pnum is not None and pnum in POS_PATIENTS) else 0

# =========================
# List files (all) & labels by patient ID
# =========================
split_dir = Path(SPLIT_DIR)
all_csvs = sorted(split_dir.glob("*.csv"))
if not all_csvs:
    raise FileNotFoundError(f"No CSV found in {SPLIT_DIR}")

id_to_files = {}
for f in all_csvs:
    pid = patient_num_from_path(f)
    if pid is None or pid == 12:    # exclude ID 12
        continue
    id_to_files.setdefault(pid, []).append(f)

all_ids = sorted(id_to_files.keys())
id_labels = np.array([1 if pid in POS_PATIENTS else 0 for pid in all_ids], dtype=int)
print("Total IDs:", len(all_ids), "| Pos IDs:", id_labels.sum(), "| Neg IDs:", (1 - id_labels).sum())

# =========================
# Column handling
# =========================
def _drop_time_cols(df: pd.DataFrame) -> pd.DataFrame:
    time_like = [c for c in df.columns if isinstance(c, str) and c.strip().lower() == "time"]
    return df.drop(columns=time_like, errors="ignore")

def _to_numeric_df(df: pd.DataFrame) -> pd.DataFrame:
    df = _drop_time_cols(df)
    return df.apply(pd.to_numeric, errors="coerce").fillna(0.0)

def _pad_crop_2d(x: np.ndarray, H: int, W: int) -> np.ndarray:
    h, w = x.shape
    if h < H:
        pad = np.zeros((H, w), dtype=x.dtype); pad[:h, :] = x; x = pad; h = H
    elif h > H:
        x = x[:H, :]; h = H
    if w < W:
        pad = np.zeros((h, W), dtype=x.dtype); pad[:, :w] = x; x = pad
    elif w > W:
        x = x[:, :W]
    return x

def _infer_target_width(example_csv: Path) -> int:
    df = pd.read_csv(example_csv)
    df2 = _to_numeric_df(df)
    return df2.shape[1]

# Fix width/height ONCE using the whole dataset (so all folds match)
TARGET_W = _infer_target_width(all_csvs[0])
print(f"TARGET_W={TARGET_W} (non-Time columns)")

def _dedupe_consecutive_rows(mat: np.ndarray) -> np.ndarray:
    if mat.size == 0:
        return mat
    if mat.ndim == 1:
        mat = mat[:, None]
    if mat.shape[0] == 1:
        return mat
    diffs = np.any(mat[1:] != mat[:-1], axis=1)
    keep = np.concatenate(([True], diffs))
    return mat[keep]

def _dedup_len_from_csv(p: Path) -> int:
    df = pd.read_csv(p)
    mat = _to_numeric_df(df).to_numpy(dtype=np.float32)
    mat_d = _dedupe_consecutive_rows(mat)
    return int(mat_d.shape[0])

TARGET_H_DEDUP = max(_dedup_len_from_csv(f) for f in all_csvs)
if TARGET_H_DEDUP <= 0:
    raise RuntimeError("After de-dup, zero-length found in data.")
print(f"Fixed input height after de-dup (all IDs): H={TARGET_H_DEDUP}")

def load_csv_as_image_dedup(csv_path: Path) -> np.ndarray:
    df  = pd.read_csv(csv_path)
    df2 = _to_numeric_df(df)
    mat = df2.to_numpy(dtype=np.float32)      # shape ~ (Samples, Chans)
    if mat.ndim != 2:
        mat = mat.reshape(mat.shape[0], -1) if mat.ndim > 2 else mat
    mat = _dedupe_consecutive_rows(mat)
    if mat.shape[0] == 0:
        mat = np.zeros((1, TARGET_W), dtype=np.float32)
    mat = _pad_crop_2d(mat, TARGET_H_DEDUP, TARGET_W)
    # keep shape as (Samples, Chans); model will permute internally
    img = np.expand_dims(mat, axis=-1).astype(np.float32)  # (Samples, Chans, 1)
    if img.shape != (TARGET_H_DEDUP, TARGET_W, 1):
        raise ValueError(f"loader produced {img.shape}, expected {(TARGET_H_DEDUP, TARGET_W, 1)} for {csv_path}")
    return img

# cache
CACHE_DEDUP = {}
def load_csv_as_image_cached(csv_path: Path) -> np.ndarray:
    key = ("dedup", str(csv_path))
    if key in CACHE_DEDUP:
        return CACHE_DEDUP[key]
    img = load_csv_as_image_dedup(csv_path)
    CACHE_DEDUP[key] = img
    return img

print("Normalization: NONE. De-dup: remove consecutive duplicate rows (row-wise).")

# =========================
# Keras Sequence
# =========================
class ImageSequence(keras.utils.Sequence):
    def __init__(self, files, batch_size=BATCH_SIZE, shuffle=True,
                 add_noise=False, noise_frac=TRAIN_NOISE_FRAC, noise_prob=TRAIN_NOISE_PROB):
        super().__init__()
        self.files = list(files)
        self.batch_size = int(batch_size)
        self.shuffle = shuffle
        self.add_noise = add_noise
        self.noise_frac = float(noise_frac)
        self.noise_prob = float(noise_prob)
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.files) / self.batch_size)

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.files))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __getitem__(self, idx):
        idxs = self.indexes[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch_files = [self.files[i] for i in idxs]
        B = len(batch_files)
        X = np.empty((B, TARGET_H_DEDUP, TARGET_W, 1), dtype=np.float32)  # (Samples, Chans, 1)
        y = np.empty((B,), dtype=np.int32)

        for i, f in enumerate(batch_files):
            xi = load_csv_as_image_cached(f)
            if xi.ndim == 2:
                xi = xi[..., None]
            if xi.shape != (TARGET_H_DEDUP, TARGET_W, 1):
                raise ValueError(f"Sample shape {xi.shape} for {f}; expected {(TARGET_H_DEDUP, TARGET_W, 1)}")
            X[i] = xi
            y[i] = label_for_file(f)

        if self.add_noise and self.noise_frac > 0.0 and self.noise_prob > 0.0:
            samp_std = X.reshape(B, -1).std(axis=1).astype(np.float32)
            samp_std = np.maximum(samp_std, EPS_STD).reshape(B, 1, 1, 1)
            noise = np.random.normal(0.0, 1.0, size=X.shape).astype(np.float32)
            noise *= (self.noise_frac * samp_std)
            if self.noise_prob < 1.0:
                mask = (np.random.rand(B, 1, 1, 1) < self.noise_prob).astype(np.float32)
                noise *= mask
            X = X + noise

        if X.shape[1:] != (TARGET_H_DEDUP, TARGET_W, 1):
            raise ValueError(f"Batch X has shape {X.shape}; expected (B, {TARGET_H_DEDUP}, {TARGET_W}, 1)")
        return X, y

# =========================
# DeepConvNet model (binary head)
# =========================
def build_model(samples=TARGET_H_DEDUP, chans=TARGET_W, lr=LR,
                F1=25, F2=50, F3=100, F4=200,
                dropout=0.5):
    """
    DeepConvNet (Schirrmeister et al. 2017) adapted for binary classification.
    Input: (Samples, Chans, 1), internally permuted to (Chans, Samples, 1).
    """
    inputs = keras.Input(shape=(samples, chans, 1))  # (T, C, 1)

    # Permute to (Chans, Samples, 1)
    x = layers.Permute((2, 1, 3))(inputs)  # (C, T, 1)

    # Block 1: temporal conv + spatial conv
    x = layers.Conv2D(
        F1, (1, 5),
        padding="same",
        use_bias=False
    )(x)
    x = layers.Conv2D(
        F1, (chans, 1),  # across all channels
        padding="valid",
        use_bias=False
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("elu")(x)
    x = layers.MaxPooling2D(pool_size=(1, 2))(x)
    x = layers.Dropout(dropout)(x)

    # Block 2
    x = layers.Conv2D(
        F2, (1, 5),
        padding="same",
        use_bias=False
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("elu")(x)
    x = layers.MaxPooling2D(pool_size=(1, 2))(x)
    x = layers.Dropout(dropout)(x)

    # Block 3
    x = layers.Conv2D(
        F3, (1, 5),
        padding="same",
        use_bias=False
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("elu")(x)
    x = layers.MaxPooling2D(pool_size=(1, 2))(x)
    x = layers.Dropout(dropout)(x)

    # Block 4
    x = layers.Conv2D(
        F4, (1, 5),
        padding="same",
        use_bias=False
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("elu")(x)
    x = layers.MaxPooling2D(pool_size=(1, 2))(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, kernel_constraint=max_norm(0.5))(x)
    x = layers.Activation("elu")(x)
    x = layers.Dropout(dropout)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[keras.metrics.BinaryAccuracy(name="acc"),
                 keras.metrics.AUC(name="auc")],
    )
    return model

# =========================
# Metric helpers (for TEST)
# =========================
def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
    return tn / (tn + fp) if (tn + fp) > 0 else 0.0

def youden_threshold_from_probs(y_true, y_prob):
    """Return best threshold and J on this set."""
    if len(np.unique(y_true)) < 2:
        return 0.5, 0.0
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    j = tpr - fpr
    i = int(np.argmax(j))
    return float(thr[i]), float(j[i])

def mean_std(x):
    x = np.asarray(x, dtype=float)
    return np.nanmean(x), np.nanstd(x)

# =========================
# 7-fold CV by patient ID
# =========================
skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

# Lists for TEST metrics (@0.5 and @Youden-J)
AUC_list,  ACC_list,  PREC_list,  REC_list,  F1_list,  SPEC_list  = [], [], [], [], [], []
AUC_J_list, ACC_J_list, PREC_J_list, REC_J_list, F1_J_list, SPEC_J_list = [], [], [], [], [], []

rows = []

print(f"\n=== {K_FOLDS}-Fold CV (by patient ID) ===")
for fold_idx, (train_idx, test_idx) in enumerate(skf.split(all_ids, id_labels), start=1):
    ids_train_full = [all_ids[i] for i in train_idx]
    ids_test       = [all_ids[i] for i in test_idx]

    # small validation split from training IDs (for checkpointing)
    train_labels_full = np.array([1 if pid in POS_PATIENTS else 0 for pid in ids_train_full], dtype=int)
    try:
        ids_tr, ids_val = train_test_split(
            ids_train_full, test_size=0.10, random_state=SEED, stratify=train_labels_full
        )
    except ValueError:
        ids_tr, ids_val = train_test_split(ids_train_full, test_size=0.10, random_state=SEED, shuffle=True)
        print(f"(Fold {fold_idx}) Warning: stratified VAL split failed; using unstratified split.")

    # Files for each split
    train_files = [f for pid in ids_tr  for f in id_to_files[pid]]
    val_files   = [f for pid in ids_val for f in id_to_files[pid]]
    test_files  = [f for pid in ids_test for f in id_to_files[pid]]

    def split_summary(name, ids, files):
        ys = np.array([label_for_file(f) for f in files], dtype=int)
        print(f"{name:>6} | ids: {len(ids):4d} | files: {len(files):5d} | pos files: {(ys==1).sum():4d} | neg files: {(ys==0).sum():4d}")

    print(f"\n--- Fold {fold_idx}/{K_FOLDS} ---")
    split_summary("train", ids_tr,  train_files)
    split_summary("val",   ids_val, val_files)
    split_summary("test",  ids_test, test_files)

    # Generators
    train_gen = ImageSequence(train_files, batch_size=BATCH_SIZE, shuffle=True,
                              add_noise=TRAIN_ADD_GAUSS_NOISE,
                              noise_frac=TRAIN_NOISE_FRAC,
                              noise_prob=TRAIN_NOISE_PROB)
    val_gen   = ImageSequence(val_files,   batch_size=BATCH_SIZE, shuffle=False, add_noise=False)
    test_gen  = ImageSequence(test_files,  batch_size=BATCH_SIZE, shuffle=False, add_noise=False)

    # Train & pick best by val_loss
    model = build_model()
    best_path = BEST_MODEL_TPL.format(fold_idx)
    ckpt = keras.callbacks.ModelCheckpoint(best_path, monitor="val_loss", mode="min",
                                           save_best_only=True, verbose=1)
    _ = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS, callbacks=[ckpt], verbose=1)

    # Evaluate on TEST
    best_model = keras.models.load_model(best_path)
    test_probs = best_model.predict(test_gen, verbose=0).ravel().astype(float)
    test_y     = np.array([label_for_file(f) for f in test_gen.files], dtype=int)

    # AUC (threshold-free)
    try:
        test_auc = roc_auc_score(test_y, test_probs)
    except ValueError:
        test_auc = float('nan')

    # --- Threshold 0.5 ---
    y_pred_05 = (test_probs >= 0.5).astype(int)
    acc_05  = accuracy_score(test_y, y_pred_05)
    prec_05 = precision_score(test_y, y_pred_05, zero_division=0)
    rec_05  = recall_score(test_y, y_pred_05, zero_division=0)
    f1_05   = f1_score(test_y, y_pred_05, zero_division=0)
    spec_05 = specificity_score(test_y, y_pred_05)

    # --- Youden-J threshold on TEST ---
    t_star, J_val = youden_threshold_from_probs(test_y, test_probs)
    y_pred_J = (test_probs >= t_star).astype(int)
    acc_J  = accuracy_score(test_y, y_pred_J)
    prec_J = precision_score(test_y, y_pred_J, zero_division=0)
    rec_J  = recall_score(test_y, y_pred_J, zero_division=0)
    f1_J   = f1_score(test_y, y_pred_J, zero_division=0)
    spec_J = specificity_score(test_y, y_pred_J)

    # collect lists
    AUC_list.append(test_auc); ACC_list.append(acc_05);   PREC_list.append(prec_05)
    REC_list.append(rec_05);   F1_list.append(f1_05);     SPEC_list.append(spec_05)

    AUC_J_list.append(test_auc); ACC_J_list.append(acc_J);   PREC_J_list.append(prec_J)
    REC_J_list.append(rec_J);    F1_J_list.append(f1_J);     SPEC_J_list.append(spec_J)

    print(f"Fold {fold_idx} | TEST@0.5  ACC={acc_05:.4f} | PREC={prec_05:.4f} | "
          f"REC={rec_05:.4f} | F1={f1_05:.4f} | AUC={test_auc:.4f} | SPEC={spec_05:.4f} | n={len(test_y)}")
    print(f"Fold {fold_idx} | TEST@J    ACC={acc_J:.4f} | PREC={prec_J:.4f} | "
          f"REC={rec_J:.4f} | F1={f1_J:.4f} | AUC={test_auc:.4f} | SPEC={spec_J:.4f} | thr={t_star:.4f}, J={J_val:.4f}")
    print("Confusion matrix (@0.5):\n", confusion_matrix(test_y, y_pred_05))
    print("Classification report (@0.5):\n", classification_report(test_y, y_pred_05, digits=3))

    rows.append({
        "fold": fold_idx,
        "train_files": len(train_files),
        "val_files": len(val_files),
        "test_files": len(test_files),

        "ACC_0.5": acc_05,
        "PREC_0.5": prec_05,
        "REC_0.5": rec_05,
        "F1_0.5": f1_05,
        "AUC": test_auc,
        "SPEC_0.5": spec_05,

        "thr_J": t_star,
        "J": J_val,
        "ACC_J": acc_J,
        "PREC_J": prec_J,
        "REC_J": rec_J,
        "F1_J": f1_J,
        "SPEC_J": spec_J,
    })

# =========================
# Summary across folds
# =========================
print("\n=== TEST metrics per fold — threshold 0.5 ===")
print("AUC :", [None if np.isnan(x) else round(x,4) for x in AUC_list])
print("ACC :", [round(x,4) for x in ACC_list])
print("PREC:", [round(x,4) for x in PREC_list])
print("REC :", [round(x,4) for x in REC_list])
print("SPEC:", [round(x,4) for x in SPEC_list])
print("F1  :", [round(x,4) for x in F1_list])

print("\n=== TEST metrics per fold — Youden-J (on TEST) ===")
print("AUC@J :", [None if np.isnan(x) else round(x,4) for x in AUC_J_list])
print("ACC@J :", [round(x,4) for x in ACC_J_list])
print("PREC@J:", [round(x,4) for x in PREC_J_list])
print("REC@J :", [round(x,4) for x in REC_J_list])
print("SPEC@J:", [round(x,4) for x in SPEC_J_list])
print("F1@J  :", [round(x,4) for x in F1_J_list])

mAUC,  sAUC  = mean_std(AUC_list)
mACC,  sACC  = mean_std(ACC_list)
mPREC, sPREC = mean_std(PREC_list)
mREC,  sREC  = mean_std(REC_list)
mF1,   sF1   = mean_std(F1_list)
mSPEC, sSPEC = mean_std(SPEC_list)

print("\n=== Mean ± SD across folds (TEST) — 0.5 ===")
print(f"{'AUC':>12}: {mAUC:.4f} ± {sAUC:.4f}")
print(f"{'ACC':>12}: {mACC:.4f} ± {sACC:.4f}")
print(f"{'Precision':>12}: {mPREC:.4f} ± {sPREC:.4f}")
print(f"{'Recall':>12}: {mREC:.4f} ± {sREC:.4f}")
print(f"{'Specificity':>12}: {mSPEC:.4f} ± {sSPEC:.4f}")
print(f"{'F1':>12}: {mF1:.4f} ± {sF1:.4f}")

mAUC_J,  sAUC_J  = mean_std(AUC_J_list)
mACC_J,  sACC_J  = mean_std(ACC_J_list)
mPREC_J, sPREC_J = mean_std(PREC_J_list)
mREC_J,  sREC_J  = mean_std(REC_J_list)
mF1_J,   sF1_J   = mean_std(F1_J_list)
mSPEC_J, sSPEC_J = mean_std(SPEC_J_list)

print("\n=== Mean ± SD across folds (TEST) — Youden-J (on TEST) ===")
print(f"{'AUC@J':>12}: {mAUC_J:.4f} ± {sAUC_J:.4f}")
print(f"{'ACC@J':>12}: {mACC_J:.4f} ± {sACC_J:.4f}")
print(f"{'Precision@J':>12}: {mPREC_J:.4f} ± {sPREC_J:.4f}")
print(f"{'Recall@J':>12}: {mREC_J:.4f} ± {sREC_J:.4f}")
print(f"{'Specificity@J':>12}: {mSPEC_J:.4f} ± {sSPEC_J:.4f}")
print(f"{'F1@J':>12}: {mF1_J:.4f} ± {sF1_J:.4f}")

metrics_df = pd.DataFrame(rows)
metrics_df.to_csv("cv7_img_fold_metrics.csv", index=False)
print("\nSaved TEST-only per-fold metrics to cv7_img_fold_metrics.csv")
# Out:
# Total IDs: 42 | Pos IDs: 13 | Neg IDs: 29
# TARGET_W=6 (non-Time columns)
# Fixed input height after de-dup (all IDs): H=360
# Normalization: NONE. De-dup: remove consecutive duplicate rows (row-wise).
#
# === 7-Fold CV (by patient ID) ===
#
# --- Fold 1/7 ---
#  train | ids:   32 | files:   808 | pos files:  320 | neg files:  488
#    val | ids:    4 | files:    85 | pos files:    6 | neg files:   79
#   test | ids:    6 | files:   131 | pos files:   45 | neg files:   86
# Epoch 1/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.5378 - auc: 0.5421 - loss: 0.8756
# Epoch 1: val_loss improved from inf to 0.24776, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - acc: 0.5380 - auc: 0.5425 - loss: 0.8757 - val_acc: 0.9294 - val_auc: 0.8249 - val_loss: 0.2478
# Epoch 2/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6322 - auc: 0.6218 - loss: 0.7960
# Epoch 2: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6314 - auc: 0.6212 - loss: 0.7968 - val_acc: 0.9412 - val_auc: 0.9293 - val_loss: 0.4114
# Epoch 3/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5469 - auc: 0.5647 - loss: 0.8417
# Epoch 3: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5471 - auc: 0.5652 - loss: 0.8416 - val_acc: 0.3529 - val_auc: 0.7911 - val_loss: 0.8502
# Epoch 4/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5928 - auc: 0.5982 - loss: 0.7904
# Epoch 4: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5941 - auc: 0.6006 - loss: 0.7877 - val_acc: 0.3765 - val_auc: 0.9641 - val_loss: 0.7698
# Epoch 5/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5828 - auc: 0.6093 - loss: 0.7884
# Epoch 5: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5827 - auc: 0.6083 - loss: 0.7891 - val_acc: 0.3765 - val_auc: 0.8734 - val_loss: 0.8938
# Epoch 6/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5804 - auc: 0.5825 - loss: 0.7938
# Epoch 6: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5809 - auc: 0.5833 - loss: 0.7928 - val_acc: 0.3647 - val_auc: 0.7954 - val_loss: 1.1295
# Epoch 7/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5765 - auc: 0.5966 - loss: 0.7467
# Epoch 7: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5764 - auc: 0.5966 - loss: 0.7468 - val_acc: 0.8118 - val_auc: 0.6582 - val_loss: 0.3557
# Epoch 8/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5957 - auc: 0.6203 - loss: 0.7743
# Epoch 8: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5958 - auc: 0.6203 - loss: 0.7742 - val_acc: 0.3529 - val_auc: 0.7405 - val_loss: 1.4217
# Epoch 9/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5967 - auc: 0.6091 - loss: 0.7346
# Epoch 9: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5965 - auc: 0.6101 - loss: 0.7350 - val_acc: 0.4588 - val_auc: 0.9335 - val_loss: 0.6104
# Epoch 10/100
# 251/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6175 - auc: 0.6826 - loss: 0.6807
# Epoch 10: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6173 - auc: 0.6805 - loss: 0.6827 - val_acc: 0.3765 - val_auc: 0.9082 - val_loss: 1.2922
# Epoch 11/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6127 - auc: 0.6582 - loss: 0.6951
# Epoch 11: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6115 - auc: 0.6570 - loss: 0.6969 - val_acc: 0.8941 - val_auc: 0.8091 - val_loss: 0.2978
# Epoch 12/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5810 - auc: 0.6223 - loss: 0.6963
# Epoch 12: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5816 - auc: 0.6237 - loss: 0.6960 - val_acc: 0.3882 - val_auc: 0.9536 - val_loss: 0.8711
# Epoch 13/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6322 - auc: 0.6687 - loss: 0.7023
# Epoch 13: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6316 - auc: 0.6684 - loss: 0.7024 - val_acc: 0.9294 - val_auc: 0.7479 - val_loss: 0.3045
# Epoch 14/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6151 - auc: 0.6106 - loss: 0.7264
# Epoch 14: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6153 - auc: 0.6114 - loss: 0.7259 - val_acc: 0.8824 - val_auc: 0.4346 - val_loss: 0.3334
# Epoch 15/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6163 - auc: 0.6406 - loss: 0.7059
# Epoch 15: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6161 - auc: 0.6410 - loss: 0.7056 - val_acc: 0.3765 - val_auc: 0.9156 - val_loss: 1.6616
# Epoch 16/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6090 - auc: 0.6493 - loss: 0.6777
# Epoch 16: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6091 - auc: 0.6497 - loss: 0.6776 - val_acc: 0.3647 - val_auc: 0.9409 - val_loss: 1.9502
# Epoch 17/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6102 - auc: 0.6619 - loss: 0.6646
# Epoch 17: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6107 - auc: 0.6619 - loss: 0.6649 - val_acc: 0.5294 - val_auc: 0.7732 - val_loss: 0.5567
# Epoch 18/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6739 - auc: 0.7049 - loss: 0.6311
# Epoch 18: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6734 - auc: 0.7046 - loss: 0.6318 - val_acc: 0.4588 - val_auc: 0.8059 - val_loss: 0.5442
# Epoch 19/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6458 - auc: 0.7016 - loss: 0.6463
# Epoch 19: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6458 - auc: 0.7012 - loss: 0.6466 - val_acc: 0.3882 - val_auc: 0.9430 - val_loss: 0.8506
# Epoch 20/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6698 - auc: 0.7004 - loss: 0.6284
# Epoch 20: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6694 - auc: 0.7000 - loss: 0.6293 - val_acc: 0.3765 - val_auc: 0.9251 - val_loss: 2.4550
# Epoch 21/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5857 - auc: 0.6365 - loss: 0.7051
# Epoch 21: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5860 - auc: 0.6366 - loss: 0.7050 - val_acc: 0.9294 - val_auc: 0.5960 - val_loss: 0.4008
# Epoch 22/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6681 - auc: 0.7247 - loss: 0.6169
# Epoch 22: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6681 - auc: 0.7246 - loss: 0.6169 - val_acc: 0.9176 - val_auc: 0.4800 - val_loss: 0.3713
# Epoch 23/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6850 - auc: 0.6915 - loss: 0.6435
# Epoch 23: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6849 - auc: 0.6916 - loss: 0.6434 - val_acc: 0.9059 - val_auc: 0.4483 - val_loss: 0.3425
# Epoch 24/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6434 - auc: 0.6900 - loss: 0.6580
# Epoch 24: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6432 - auc: 0.6898 - loss: 0.6581 - val_acc: 0.6824 - val_auc: 0.5253 - val_loss: 0.4914
# Epoch 25/100
# 251/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6481 - auc: 0.6754 - loss: 0.6550
# Epoch 25: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6465 - auc: 0.6746 - loss: 0.6571 - val_acc: 0.4353 - val_auc: 0.7901 - val_loss: 1.6306
# Epoch 26/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6723 - auc: 0.7122 - loss: 0.6327
# Epoch 26: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6723 - auc: 0.7121 - loss: 0.6327 - val_acc: 0.3647 - val_auc: 0.6329 - val_loss: 0.7196
# Epoch 27/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6482 - auc: 0.7056 - loss: 0.6115
# Epoch 27: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6479 - auc: 0.7053 - loss: 0.6122 - val_acc: 0.3647 - val_auc: 0.8776 - val_loss: 2.7949
# Epoch 28/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6387 - auc: 0.7121 - loss: 0.6158
# Epoch 28: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6388 - auc: 0.7122 - loss: 0.6158 - val_acc: 0.3765 - val_auc: 0.8776 - val_loss: 0.8024
# Epoch 29/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6627 - auc: 0.7284 - loss: 0.6125
# Epoch 29: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6621 - auc: 0.7276 - loss: 0.6132 - val_acc: 0.9059 - val_auc: 0.4589 - val_loss: 0.4362
# Epoch 30/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6895 - auc: 0.7690 - loss: 0.5592
# Epoch 30: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6894 - auc: 0.7688 - loss: 0.5594 - val_acc: 0.3294 - val_auc: 0.6445 - val_loss: 1.0769
# Epoch 31/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6456 - auc: 0.7106 - loss: 0.6131
# Epoch 31: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6457 - auc: 0.7106 - loss: 0.6131 - val_acc: 0.3765 - val_auc: 0.8038 - val_loss: 1.0053
# Epoch 32/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6246 - auc: 0.6468 - loss: 0.7078
# Epoch 32: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6257 - auc: 0.6488 - loss: 0.7050 - val_acc: 0.5412 - val_auc: 0.8038 - val_loss: 0.6050
# Epoch 33/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6863 - auc: 0.7346 - loss: 0.5713
# Epoch 33: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6857 - auc: 0.7349 - loss: 0.5722 - val_acc: 0.4235 - val_auc: 0.7458 - val_loss: 1.9443
# Epoch 34/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6625 - auc: 0.6884 - loss: 0.6302
# Epoch 34: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6621 - auc: 0.6890 - loss: 0.6297 - val_acc: 0.8941 - val_auc: 0.6593 - val_loss: 0.3954
# Epoch 35/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6659 - auc: 0.7083 - loss: 0.6068
# Epoch 35: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6655 - auc: 0.7081 - loss: 0.6077 - val_acc: 0.5765 - val_auc: 0.8724 - val_loss: 0.5281
# Epoch 36/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7083 - auc: 0.7587 - loss: 0.5486
# Epoch 36: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7080 - auc: 0.7584 - loss: 0.5492 - val_acc: 0.6353 - val_auc: 0.7700 - val_loss: 0.5430
# Epoch 37/100
# 251/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7074 - auc: 0.7557 - loss: 0.5716
# Epoch 37: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7061 - auc: 0.7550 - loss: 0.5722 - val_acc: 0.4000 - val_auc: 0.8892 - val_loss: 1.0545
# Epoch 38/100
# 255/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6526 - auc: 0.6937 - loss: 0.6406
# Epoch 38: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6525 - auc: 0.6937 - loss: 0.6405 - val_acc: 0.3176 - val_auc: 0.7732 - val_loss: 1.3310
# Epoch 39/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6662 - auc: 0.7208 - loss: 0.6290
# Epoch 39: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6673 - auc: 0.7214 - loss: 0.6277 - val_acc: 0.6235 - val_auc: 0.8608 - val_loss: 0.5115
# Epoch 40/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6473 - auc: 0.7101 - loss: 0.6192
# Epoch 40: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6504 - auc: 0.7130 - loss: 0.6158 - val_acc: 0.4118 - val_auc: 0.8122 - val_loss: 1.7362
# Epoch 41/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7173 - auc: 0.7379 - loss: 0.5766
# Epoch 41: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7175 - auc: 0.7390 - loss: 0.5757 - val_acc: 0.7412 - val_auc: 0.8302 - val_loss: 0.4526
# Epoch 42/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6790 - auc: 0.7211 - loss: 0.6050
# Epoch 42: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6790 - auc: 0.7212 - loss: 0.6050 - val_acc: 0.6000 - val_auc: 0.9040 - val_loss: 0.5579
# Epoch 43/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6726 - auc: 0.7633 - loss: 0.5457
# Epoch 43: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6722 - auc: 0.7623 - loss: 0.5471 - val_acc: 0.5294 - val_auc: 0.6477 - val_loss: 0.6277
# Epoch 44/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6787 - auc: 0.7226 - loss: 0.5946
# Epoch 44: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6786 - auc: 0.7229 - loss: 0.5941 - val_acc: 0.9294 - val_auc: 0.5485 - val_loss: 0.2732
# Epoch 45/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6546 - auc: 0.7240 - loss: 0.5815
# Epoch 45: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6549 - auc: 0.7240 - loss: 0.5816 - val_acc: 0.4588 - val_auc: 0.8576 - val_loss: 0.9539
# Epoch 46/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6793 - auc: 0.7354 - loss: 0.5683
# Epoch 46: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6793 - auc: 0.7354 - loss: 0.5684 - val_acc: 0.9176 - val_auc: 0.4884 - val_loss: 0.3980
# Epoch 47/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6797 - auc: 0.7297 - loss: 0.6121
# Epoch 47: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6791 - auc: 0.7291 - loss: 0.6122 - val_acc: 0.4706 - val_auc: 0.8861 - val_loss: 0.8539
# Epoch 48/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7072 - auc: 0.7787 - loss: 0.5268
# Epoch 48: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7067 - auc: 0.7782 - loss: 0.5275 - val_acc: 0.5059 - val_auc: 0.8819 - val_loss: 0.7048
# Epoch 49/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7216 - auc: 0.7709 - loss: 0.5334
# Epoch 49: val_loss did not improve from 0.24776
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7203 - auc: 0.7703 - loss: 0.5344 - val_acc: 0.5176 - val_auc: 0.8882 - val_loss: 1.1043
# Epoch 50/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7045 - auc: 0.7592 - loss: 0.5572
# Epoch 50: val_loss improved from 0.24776 to 0.24504, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7042 - auc: 0.7589 - loss: 0.5574 - val_acc: 0.9294 - val_auc: 0.7015 - val_loss: 0.2450
# Epoch 51/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7025 - auc: 0.7492 - loss: 0.5634
# Epoch 51: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7029 - auc: 0.7499 - loss: 0.5628 - val_acc: 0.7176 - val_auc: 0.7890 - val_loss: 0.5368
# Epoch 52/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6858 - auc: 0.7239 - loss: 0.5686
# Epoch 52: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6858 - auc: 0.7241 - loss: 0.5685 - val_acc: 0.9294 - val_auc: 0.4989 - val_loss: 0.3223
# Epoch 53/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6791 - auc: 0.7275 - loss: 0.5707
# Epoch 53: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6796 - auc: 0.7291 - loss: 0.5699 - val_acc: 0.8353 - val_auc: 0.7257 - val_loss: 0.3645
# Epoch 54/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6887 - auc: 0.7412 - loss: 0.5711
# Epoch 54: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6886 - auc: 0.7412 - loss: 0.5711 - val_acc: 0.6235 - val_auc: 0.6160 - val_loss: 0.5248
# Epoch 55/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6558 - auc: 0.7169 - loss: 0.6098
# Epoch 55: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6565 - auc: 0.7174 - loss: 0.6089 - val_acc: 0.7059 - val_auc: 0.7669 - val_loss: 0.4901
# Epoch 56/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6872 - auc: 0.7381 - loss: 0.5668
# Epoch 56: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6874 - auc: 0.7384 - loss: 0.5665 - val_acc: 0.9294 - val_auc: 0.5127 - val_loss: 0.2988
# Epoch 57/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6830 - auc: 0.7609 - loss: 0.5614
# Epoch 57: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6831 - auc: 0.7609 - loss: 0.5613 - val_acc: 0.5059 - val_auc: 0.7890 - val_loss: 0.9947
# Epoch 58/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7095 - auc: 0.7538 - loss: 0.5625
# Epoch 58: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7092 - auc: 0.7543 - loss: 0.5621 - val_acc: 0.8353 - val_auc: 0.7300 - val_loss: 0.3066
# Epoch 59/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7098 - auc: 0.7728 - loss: 0.5380
# Epoch 59: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7098 - auc: 0.7729 - loss: 0.5380 - val_acc: 0.4706 - val_auc: 0.7342 - val_loss: 0.9590
# Epoch 60/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7074 - auc: 0.7742 - loss: 0.5453
# Epoch 60: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7072 - auc: 0.7740 - loss: 0.5453 - val_acc: 0.6824 - val_auc: 0.4283 - val_loss: 0.4910
# Epoch 61/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6898 - auc: 0.7571 - loss: 0.5573
# Epoch 61: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6905 - auc: 0.7577 - loss: 0.5568 - val_acc: 0.9294 - val_auc: 0.3840 - val_loss: 0.3434
# Epoch 62/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6968 - auc: 0.7726 - loss: 0.5470
# Epoch 62: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6969 - auc: 0.7724 - loss: 0.5471 - val_acc: 0.4941 - val_auc: 0.5390 - val_loss: 0.7336
# Epoch 63/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6850 - auc: 0.7528 - loss: 0.5630
# Epoch 63: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6858 - auc: 0.7531 - loss: 0.5623 - val_acc: 0.9176 - val_auc: 0.3892 - val_loss: 0.3563
# Epoch 64/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7137 - auc: 0.7841 - loss: 0.5300
# Epoch 64: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7131 - auc: 0.7831 - loss: 0.5311 - val_acc: 0.9176 - val_auc: 0.4652 - val_loss: 0.3207
# Epoch 65/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7153 - auc: 0.7690 - loss: 0.5519
# Epoch 65: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7150 - auc: 0.7689 - loss: 0.5522 - val_acc: 0.7294 - val_auc: 0.7057 - val_loss: 0.5187
# Epoch 66/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7158 - auc: 0.7587 - loss: 0.5256
# Epoch 66: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7168 - auc: 0.7601 - loss: 0.5251 - val_acc: 0.9294 - val_auc: 0.4019 - val_loss: 0.3026
# Epoch 67/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6592 - auc: 0.7282 - loss: 0.5899
# Epoch 67: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6598 - auc: 0.7287 - loss: 0.5893 - val_acc: 0.8000 - val_auc: 0.7637 - val_loss: 0.3608
# Epoch 68/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7062 - auc: 0.7878 - loss: 0.5281
# Epoch 68: val_loss did not improve from 0.24504
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7067 - auc: 0.7874 - loss: 0.5283 - val_acc: 0.9294 - val_auc: 0.6572 - val_loss: 0.3067
# Epoch 69/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6997 - auc: 0.7902 - loss: 0.5076
# Epoch 69: val_loss improved from 0.24504 to 0.23806, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6997 - auc: 0.7901 - loss: 0.5078 - val_acc: 0.9294 - val_auc: 0.7015 - val_loss: 0.2381
# Epoch 70/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7322 - auc: 0.8047 - loss: 0.4960
# Epoch 70: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7307 - auc: 0.8033 - loss: 0.4985 - val_acc: 0.9176 - val_auc: 0.6245 - val_loss: 0.3019
# Epoch 71/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7282 - auc: 0.7859 - loss: 0.5099
# Epoch 71: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7280 - auc: 0.7856 - loss: 0.5103 - val_acc: 0.9294 - val_auc: 0.5411 - val_loss: 0.2666
# Epoch 72/100
# 255/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7010 - auc: 0.7361 - loss: 0.5593
# Epoch 72: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7026 - auc: 0.7389 - loss: 0.5570 - val_acc: 0.9176 - val_auc: 0.6719 - val_loss: 0.2811
# Epoch 73/100
# 251/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7299 - auc: 0.7797 - loss: 0.5148
# Epoch 73: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7286 - auc: 0.7792 - loss: 0.5162 - val_acc: 0.7882 - val_auc: 0.6994 - val_loss: 0.4461
# Epoch 74/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6771 - auc: 0.7090 - loss: 0.5728
# Epoch 74: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6787 - auc: 0.7123 - loss: 0.5704 - val_acc: 0.9294 - val_auc: 0.5876 - val_loss: 0.2796
# Epoch 75/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7422 - auc: 0.7816 - loss: 0.5208
# Epoch 75: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7420 - auc: 0.7815 - loss: 0.5209 - val_acc: 0.7647 - val_auc: 0.4895 - val_loss: 0.4540
# Epoch 76/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6608 - auc: 0.7590 - loss: 0.5444
# Epoch 76: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6625 - auc: 0.7592 - loss: 0.5442 - val_acc: 0.9176 - val_auc: 0.6013 - val_loss: 0.3011
# Epoch 77/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7185 - auc: 0.7773 - loss: 0.5218
# Epoch 77: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7184 - auc: 0.7773 - loss: 0.5219 - val_acc: 0.8118 - val_auc: 0.6276 - val_loss: 0.4010
# Epoch 78/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7248 - auc: 0.7759 - loss: 0.5238
# Epoch 78: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7247 - auc: 0.7759 - loss: 0.5239 - val_acc: 0.8000 - val_auc: 0.7489 - val_loss: 0.4024
# Epoch 79/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7305 - auc: 0.7977 - loss: 0.5048
# Epoch 79: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7297 - auc: 0.7970 - loss: 0.5056 - val_acc: 0.5765 - val_auc: 0.6297 - val_loss: 0.9205
# Epoch 80/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7524 - auc: 0.8120 - loss: 0.4876
# Epoch 80: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7516 - auc: 0.8114 - loss: 0.4886 - val_acc: 0.5294 - val_auc: 0.7489 - val_loss: 0.9537
# Epoch 81/100
# 255/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6838 - auc: 0.7802 - loss: 0.5304
# Epoch 81: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6837 - auc: 0.7792 - loss: 0.5312 - val_acc: 0.9176 - val_auc: 0.3892 - val_loss: 0.3621
# Epoch 82/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7082 - auc: 0.7725 - loss: 0.5254
# Epoch 82: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7083 - auc: 0.7725 - loss: 0.5254 - val_acc: 0.9176 - val_auc: 0.5580 - val_loss: 0.3788
# Epoch 83/100
# 251/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7084 - auc: 0.7860 - loss: 0.5111
# Epoch 83: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7097 - auc: 0.7878 - loss: 0.5099 - val_acc: 0.5294 - val_auc: 0.6403 - val_loss: 0.5839
# Epoch 84/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6716 - auc: 0.7610 - loss: 0.5526
# Epoch 84: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6721 - auc: 0.7612 - loss: 0.5521 - val_acc: 0.9294 - val_auc: 0.4715 - val_loss: 0.3538
# Epoch 85/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6917 - auc: 0.7668 - loss: 0.5378
# Epoch 85: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6921 - auc: 0.7681 - loss: 0.5365 - val_acc: 0.6941 - val_auc: 0.5981 - val_loss: 0.4276
# Epoch 86/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7738 - auc: 0.8354 - loss: 0.4787
# Epoch 86: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7717 - auc: 0.8335 - loss: 0.4805 - val_acc: 0.8353 - val_auc: 0.6508 - val_loss: 0.3445
# Epoch 87/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7164 - auc: 0.7842 - loss: 0.5076
# Epoch 87: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7154 - auc: 0.7835 - loss: 0.5085 - val_acc: 0.7059 - val_auc: 0.6709 - val_loss: 0.5164
# Epoch 88/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7005 - auc: 0.7943 - loss: 0.5056
# Epoch 88: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6999 - auc: 0.7928 - loss: 0.5077 - val_acc: 0.9059 - val_auc: 0.7046 - val_loss: 0.2797
# Epoch 89/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7536 - auc: 0.8029 - loss: 0.4899
# Epoch 89: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7535 - auc: 0.8033 - loss: 0.4897 - val_acc: 0.9059 - val_auc: 0.7542 - val_loss: 0.2554
# Epoch 90/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6980 - auc: 0.7716 - loss: 0.5422
# Epoch 90: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6982 - auc: 0.7719 - loss: 0.5418 - val_acc: 0.8824 - val_auc: 0.7310 - val_loss: 0.2781
# Epoch 91/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7375 - auc: 0.8111 - loss: 0.4935
# Epoch 91: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7370 - auc: 0.8102 - loss: 0.4947 - val_acc: 0.7647 - val_auc: 0.5485 - val_loss: 0.4300
# Epoch 92/100
# 251/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7061 - auc: 0.7880 - loss: 0.5167
# Epoch 92: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7059 - auc: 0.7875 - loss: 0.5175 - val_acc: 0.9294 - val_auc: 0.5981 - val_loss: 0.3093
# Epoch 93/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7180 - auc: 0.8047 - loss: 0.5078
# Epoch 93: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7189 - auc: 0.8046 - loss: 0.5076 - val_acc: 0.8824 - val_auc: 0.7595 - val_loss: 0.2867
# Epoch 94/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7100 - auc: 0.7814 - loss: 0.5318
# Epoch 94: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7084 - auc: 0.7806 - loss: 0.5322 - val_acc: 0.8235 - val_auc: 0.7416 - val_loss: 0.3685
# Epoch 95/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7455 - auc: 0.8034 - loss: 0.4893
# Epoch 95: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7441 - auc: 0.8026 - loss: 0.4907 - val_acc: 0.9294 - val_auc: 0.4388 - val_loss: 0.3428
# Epoch 96/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7513 - auc: 0.8309 - loss: 0.4629
# Epoch 96: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7508 - auc: 0.8304 - loss: 0.4636 - val_acc: 0.9294 - val_auc: 0.6614 - val_loss: 0.2661
# Epoch 97/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7018 - auc: 0.7923 - loss: 0.5320
# Epoch 97: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7023 - auc: 0.7927 - loss: 0.5311 - val_acc: 0.8941 - val_auc: 0.6371 - val_loss: 0.2925
# Epoch 98/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7435 - auc: 0.8250 - loss: 0.5029
# Epoch 98: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7430 - auc: 0.8243 - loss: 0.5029 - val_acc: 0.9294 - val_auc: 0.3101 - val_loss: 0.3611
# Epoch 99/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7247 - auc: 0.7787 - loss: 0.5133
# Epoch 99: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7247 - auc: 0.7792 - loss: 0.5138 - val_acc: 0.7412 - val_auc: 0.4082 - val_loss: 0.4701
# Epoch 100/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7442 - auc: 0.8138 - loss: 0.4743
# Epoch 100: val_loss did not improve from 0.23806
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7445 - auc: 0.8137 - loss: 0.4750 - val_acc: 0.7765 - val_auc: 0.6002 - val_loss: 0.3884
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 1 | TEST@0.5  ACC=0.6412 | PREC=0.0000 | REC=0.0000 | F1=0.0000 | AUC=0.7848 | SPEC=0.9767 | n=131
# Fold 1 | TEST@J    ACC=0.7557 | PREC=0.6444 | REC=0.6444 | F1=0.6444 | AUC=0.7848 | SPEC=0.8140 | thr=0.2385, J=0.4584
# Confusion matrix (@0.5):
#  [[84  2]
#  [45  0]]
# Classification report (@0.5):
#                precision    recall  f1-score   support
#
#            0      0.651     0.977     0.781        86
#            1      0.000     0.000     0.000        45
#
#     accuracy                          0.641       131
#    macro avg      0.326     0.488     0.391       131
# weighted avg      0.427     0.641     0.513       131
#
#
# --- Fold 2/7 ---
#  train | ids:   32 | files:   763 | pos files:  322 | neg files:  441
#    val | ids:    4 | files:   149 | pos files:    4 | neg files:  145
#   test | ids:    6 | files:   112 | pos files:   45 | neg files:   67
# Epoch 1/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.5994 - auc: 0.5449 - loss: 0.9386
# Epoch 1: val_loss improved from inf to 0.26935, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - acc: 0.5993 - auc: 0.5457 - loss: 0.9378 - val_acc: 0.9732 - val_auc: 0.4810 - val_loss: 0.2694
# Epoch 2/100
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5430 - auc: 0.5369 - loss: 0.9119
# Epoch 2: val_loss improved from 0.26935 to 0.12663, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.5431 - auc: 0.5371 - loss: 0.9117 - val_acc: 0.9732 - val_auc: 0.8741 - val_loss: 0.1266
# Epoch 3/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5835 - auc: 0.5903 - loss: 0.8221
# Epoch 3: val_loss did not improve from 0.12663
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5824 - auc: 0.5906 - loss: 0.8215 - val_acc: 0.8926 - val_auc: 0.6190 - val_loss: 0.2515
# Epoch 4/100
# 242/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5806 - auc: 0.6077 - loss: 0.8286
# Epoch 4: val_loss improved from 0.12663 to 0.11099, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.5808 - auc: 0.6076 - loss: 0.8276 - val_acc: 0.9732 - val_auc: 0.9362 - val_loss: 0.1110
# Epoch 5/100
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5496 - auc: 0.5801 - loss: 0.8345
# Epoch 5: val_loss did not improve from 0.11099
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5507 - auc: 0.5810 - loss: 0.8329 - val_acc: 0.9664 - val_auc: 0.9414 - val_loss: 0.2123
# Epoch 6/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5697 - auc: 0.5824 - loss: 0.8123
# Epoch 6: val_loss did not improve from 0.11099
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5707 - auc: 0.5831 - loss: 0.8116 - val_acc: 0.9732 - val_auc: 0.8957 - val_loss: 0.1481
# Epoch 7/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5746 - auc: 0.6042 - loss: 0.7888
# Epoch 7: val_loss did not improve from 0.11099
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5761 - auc: 0.6054 - loss: 0.7872 - val_acc: 0.9732 - val_auc: 0.9069 - val_loss: 0.1493
# Epoch 8/100
# 238/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5998 - auc: 0.6176 - loss: 0.7503
# Epoch 8: val_loss did not improve from 0.11099
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5988 - auc: 0.6157 - loss: 0.7520 - val_acc: 0.9732 - val_auc: 0.8552 - val_loss: 0.1447
# Epoch 9/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5499 - auc: 0.5702 - loss: 0.8030
# Epoch 9: val_loss did not improve from 0.11099
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5511 - auc: 0.5710 - loss: 0.8021 - val_acc: 0.9597 - val_auc: 0.8991 - val_loss: 0.2199
# Epoch 10/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6028 - auc: 0.6225 - loss: 0.7269
# Epoch 10: val_loss did not improve from 0.11099
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6021 - auc: 0.6211 - loss: 0.7299 - val_acc: 0.8389 - val_auc: 0.9767 - val_loss: 0.2627
# Epoch 11/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5671 - auc: 0.5797 - loss: 0.7849
# Epoch 11: val_loss did not improve from 0.11099
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5674 - auc: 0.5801 - loss: 0.7846 - val_acc: 0.9732 - val_auc: 0.8897 - val_loss: 0.1736
# Epoch 12/100
# 248/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5740 - auc: 0.5932 - loss: 0.7642
# Epoch 12: val_loss did not improve from 0.11099
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.5751 - auc: 0.5939 - loss: 0.7639 - val_acc: 0.9530 - val_auc: 0.9362 - val_loss: 0.1643
# Epoch 13/100
# 237/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6573 - auc: 0.6627 - loss: 0.7127
# Epoch 13: val_loss improved from 0.11099 to 0.10207, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6548 - auc: 0.6609 - loss: 0.7145 - val_acc: 0.9732 - val_auc: 0.9991 - val_loss: 0.1021
# Epoch 14/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6335 - auc: 0.6430 - loss: 0.7165
# Epoch 14: val_loss did not improve from 0.10207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6335 - auc: 0.6430 - loss: 0.7167 - val_acc: 0.9732 - val_auc: 0.7647 - val_loss: 0.1195
# Epoch 15/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6157 - auc: 0.6423 - loss: 0.7128
# Epoch 15: val_loss did not improve from 0.10207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6157 - auc: 0.6427 - loss: 0.7127 - val_acc: 0.9732 - val_auc: 0.9793 - val_loss: 0.1089
# Epoch 16/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6042 - auc: 0.6399 - loss: 0.7400
# Epoch 16: val_loss did not improve from 0.10207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6043 - auc: 0.6403 - loss: 0.7400 - val_acc: 0.9732 - val_auc: 0.9983 - val_loss: 0.1111
# Epoch 17/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5804 - auc: 0.6095 - loss: 0.7393
# Epoch 17: val_loss did not improve from 0.10207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5814 - auc: 0.6106 - loss: 0.7389 - val_acc: 0.9262 - val_auc: 0.9534 - val_loss: 0.2028
# Epoch 18/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6012 - auc: 0.6432 - loss: 0.7602
# Epoch 18: val_loss did not improve from 0.10207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6016 - auc: 0.6426 - loss: 0.7614 - val_acc: 0.9732 - val_auc: 0.9517 - val_loss: 0.1208
# Epoch 19/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5900 - auc: 0.6387 - loss: 0.7384
# Epoch 19: val_loss did not improve from 0.10207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5901 - auc: 0.6384 - loss: 0.7382 - val_acc: 0.9329 - val_auc: 0.9690 - val_loss: 0.1608
# Epoch 20/100
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6077 - auc: 0.6477 - loss: 0.7269
# Epoch 20: val_loss did not improve from 0.10207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6083 - auc: 0.6481 - loss: 0.7261 - val_acc: 0.9329 - val_auc: 1.0000 - val_loss: 0.1167
# Epoch 21/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6133 - auc: 0.6588 - loss: 0.6965
# Epoch 21: val_loss improved from 0.10207 to 0.06682, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6133 - auc: 0.6590 - loss: 0.6960 - val_acc: 0.9732 - val_auc: 1.0000 - val_loss: 0.0668
# Epoch 22/100
# 242/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6135 - auc: 0.6644 - loss: 0.6931
# Epoch 22: val_loss did not improve from 0.06682
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6138 - auc: 0.6644 - loss: 0.6931 - val_acc: 0.9732 - val_auc: 1.0000 - val_loss: 0.0714
# Epoch 23/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6216 - auc: 0.6953 - loss: 0.6607
# Epoch 23: val_loss did not improve from 0.06682
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6218 - auc: 0.6950 - loss: 0.6607 - val_acc: 0.8658 - val_auc: 0.8784 - val_loss: 0.2647
# Epoch 24/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6343 - auc: 0.6745 - loss: 0.6608
# Epoch 24: val_loss did not improve from 0.06682
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6335 - auc: 0.6744 - loss: 0.6624 - val_acc: 0.8859 - val_auc: 1.0000 - val_loss: 0.1949
# Epoch 25/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5692 - auc: 0.6235 - loss: 0.7210
# Epoch 25: val_loss did not improve from 0.06682
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5697 - auc: 0.6240 - loss: 0.7205 - val_acc: 0.9732 - val_auc: 1.0000 - val_loss: 0.0758
# Epoch 26/100
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6218 - auc: 0.6623 - loss: 0.6939
# Epoch 26: val_loss did not improve from 0.06682
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6219 - auc: 0.6627 - loss: 0.6934 - val_acc: 0.8456 - val_auc: 0.7862 - val_loss: 0.4717
# Epoch 27/100
# 238/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6518 - auc: 0.6898 - loss: 0.6437
# Epoch 27: val_loss did not improve from 0.06682
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6516 - auc: 0.6902 - loss: 0.6437 - val_acc: 0.8658 - val_auc: 0.7819 - val_loss: 0.3314
# Epoch 28/100
# 238/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6125 - auc: 0.6780 - loss: 0.6789
# Epoch 28: val_loss improved from 0.06682 to 0.06155, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6141 - auc: 0.6783 - loss: 0.6781 - val_acc: 0.9732 - val_auc: 1.0000 - val_loss: 0.0615
# Epoch 29/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6246 - auc: 0.6768 - loss: 0.6866
# Epoch 29: val_loss did not improve from 0.06155
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6246 - auc: 0.6767 - loss: 0.6865 - val_acc: 0.9732 - val_auc: 1.0000 - val_loss: 0.0672
# Epoch 30/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6339 - auc: 0.6822 - loss: 0.6527
# Epoch 30: val_loss did not improve from 0.06155
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6339 - auc: 0.6822 - loss: 0.6528 - val_acc: 0.9732 - val_auc: 0.9793 - val_loss: 0.0722
# Epoch 31/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6371 - auc: 0.6932 - loss: 0.6453
# Epoch 31: val_loss improved from 0.06155 to 0.06142, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6362 - auc: 0.6924 - loss: 0.6465 - val_acc: 0.9732 - val_auc: 1.0000 - val_loss: 0.0614
# Epoch 32/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6250 - auc: 0.6847 - loss: 0.6547
# Epoch 32: val_loss did not improve from 0.06142
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6249 - auc: 0.6837 - loss: 0.6554 - val_acc: 0.9732 - val_auc: 0.9526 - val_loss: 0.0841
# Epoch 33/100
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6254 - auc: 0.6875 - loss: 0.6647
# Epoch 33: val_loss did not improve from 0.06142
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6254 - auc: 0.6875 - loss: 0.6647 - val_acc: 0.9732 - val_auc: 0.7078 - val_loss: 0.1341
# Epoch 34/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6116 - auc: 0.6724 - loss: 0.6898
# Epoch 34: val_loss did not improve from 0.06142
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6122 - auc: 0.6725 - loss: 0.6889 - val_acc: 0.9732 - val_auc: 0.9897 - val_loss: 0.1171
# Epoch 35/100
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6583 - auc: 0.7380 - loss: 0.6041
# Epoch 35: val_loss did not improve from 0.06142
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6577 - auc: 0.7374 - loss: 0.6047 - val_acc: 0.9530 - val_auc: 0.9655 - val_loss: 0.1538
# Epoch 36/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6734 - auc: 0.7400 - loss: 0.5890
# Epoch 36: val_loss did not improve from 0.06142
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6739 - auc: 0.7399 - loss: 0.5893 - val_acc: 0.9732 - val_auc: 0.9448 - val_loss: 0.0992
# Epoch 37/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6157 - auc: 0.6792 - loss: 0.6729
# Epoch 37: val_loss did not improve from 0.06142
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6160 - auc: 0.6797 - loss: 0.6723 - val_acc: 0.7315 - val_auc: 0.8560 - val_loss: 0.5119
# Epoch 38/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6074 - auc: 0.6862 - loss: 0.6627
# Epoch 38: val_loss did not improve from 0.06142
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6083 - auc: 0.6866 - loss: 0.6617 - val_acc: 0.9732 - val_auc: 0.9966 - val_loss: 0.0674
# Epoch 39/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6393 - auc: 0.6673 - loss: 0.6305
# Epoch 39: val_loss improved from 0.06142 to 0.05933, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6384 - auc: 0.6671 - loss: 0.6314 - val_acc: 0.9732 - val_auc: 0.9983 - val_loss: 0.0593
# Epoch 40/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6323 - auc: 0.7180 - loss: 0.6244
# Epoch 40: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6326 - auc: 0.7180 - loss: 0.6245 - val_acc: 0.7718 - val_auc: 0.9922 - val_loss: 0.5095
# Epoch 41/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6569 - auc: 0.7228 - loss: 0.6276
# Epoch 41: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6570 - auc: 0.7230 - loss: 0.6272 - val_acc: 0.9732 - val_auc: 0.9905 - val_loss: 0.0732
# Epoch 42/100
# 240/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6759 - auc: 0.7172 - loss: 0.6114
# Epoch 42: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6751 - auc: 0.7181 - loss: 0.6109 - val_acc: 0.9664 - val_auc: 0.8560 - val_loss: 0.1186
# Epoch 43/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6735 - auc: 0.7120 - loss: 0.6275
# Epoch 43: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6735 - auc: 0.7126 - loss: 0.6269 - val_acc: 0.9664 - val_auc: 0.9845 - val_loss: 0.1020
# Epoch 44/100
# 248/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6294 - auc: 0.6791 - loss: 0.6423
# Epoch 44: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6298 - auc: 0.6794 - loss: 0.6421 - val_acc: 0.9866 - val_auc: 1.0000 - val_loss: 0.0788
# Epoch 45/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6529 - auc: 0.7124 - loss: 0.5931
# Epoch 45: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6518 - auc: 0.7121 - loss: 0.5942 - val_acc: 0.9732 - val_auc: 0.9871 - val_loss: 0.0686
# Epoch 46/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6640 - auc: 0.7150 - loss: 0.6272
# Epoch 46: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6625 - auc: 0.7144 - loss: 0.6276 - val_acc: 0.8188 - val_auc: 0.9879 - val_loss: 0.4038
# Epoch 47/100
# 242/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6501 - auc: 0.7091 - loss: 0.6190
# Epoch 47: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6497 - auc: 0.7093 - loss: 0.6189 - val_acc: 0.9732 - val_auc: 0.9940 - val_loss: 0.0779
# Epoch 48/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6600 - auc: 0.7298 - loss: 0.5969
# Epoch 48: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6600 - auc: 0.7299 - loss: 0.5970 - val_acc: 0.9597 - val_auc: 0.9759 - val_loss: 0.1210
# Epoch 49/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7032 - auc: 0.7736 - loss: 0.5621
# Epoch 49: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7025 - auc: 0.7730 - loss: 0.5630 - val_acc: 0.9329 - val_auc: 0.9983 - val_loss: 0.1140
# Epoch 50/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6460 - auc: 0.7153 - loss: 0.6221
# Epoch 50: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6465 - auc: 0.7153 - loss: 0.6217 - val_acc: 0.9732 - val_auc: 0.9603 - val_loss: 0.0766
# Epoch 51/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6321 - auc: 0.7117 - loss: 0.5939
# Epoch 51: val_loss did not improve from 0.05933
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6318 - auc: 0.7113 - loss: 0.5948 - val_acc: 0.9732 - val_auc: 0.9491 - val_loss: 0.0836
# Epoch 52/100
# ...
# Epoch 57/100
# 269/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6991 - auc: 0.8012 - loss: 0.5143
# Epoch 57: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6985 - auc: 0.7999 - loss: 0.5158 - val_acc: 0.7838 - val_auc: 0.5753 - val_loss: 0.8467
# Epoch 58/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6610 - auc: 0.7369 - loss: 0.5855
# Epoch 58: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6612 - auc: 0.7373 - loss: 0.5852 - val_acc: 0.8108 - val_auc: 0.5806 - val_loss: 0.5386
# Epoch 59/100
# 274/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7069 - auc: 0.7999 - loss: 0.5183
# Epoch 59: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7067 - auc: 0.7993 - loss: 0.5191 - val_acc: 0.7838 - val_auc: 0.4516 - val_loss: 0.6717
# Epoch 60/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6788 - auc: 0.7465 - loss: 0.5611
# Epoch 60: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6788 - auc: 0.7468 - loss: 0.5610 - val_acc: 0.8378 - val_auc: 0.4032 - val_loss: 1.6396
# Epoch 61/100
# 273/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7042 - auc: 0.7935 - loss: 0.5180
# Epoch 61: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7043 - auc: 0.7931 - loss: 0.5187 - val_acc: 0.8378 - val_auc: 0.3602 - val_loss: 0.5798
# Epoch 62/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7034 - auc: 0.7790 - loss: 0.5402
# Epoch 62: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7036 - auc: 0.7792 - loss: 0.5401 - val_acc: 0.7838 - val_auc: 0.3925 - val_loss: 0.9525
# Epoch 63/100
# 270/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6848 - auc: 0.7651 - loss: 0.5377
# Epoch 63: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6849 - auc: 0.7653 - loss: 0.5382 - val_acc: 0.8378 - val_auc: 0.4731 - val_loss: 0.8591
# Epoch 64/100
# 271/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7177 - auc: 0.7944 - loss: 0.5211
# Epoch 64: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7173 - auc: 0.7938 - loss: 0.5220 - val_acc: 0.8378 - val_auc: 0.2903 - val_loss: 1.0402
# Epoch 65/100
# 279/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6648 - auc: 0.7320 - loss: 0.6016
# Epoch 65: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6655 - auc: 0.7328 - loss: 0.6007 - val_acc: 0.8378 - val_auc: 0.5887 - val_loss: 0.6086
# Epoch 66/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6643 - auc: 0.7319 - loss: 0.5911
# Epoch 66: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6647 - auc: 0.7326 - loss: 0.5903 - val_acc: 0.8378 - val_auc: 0.4892 - val_loss: 0.6384
# Epoch 67/100
# 273/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6638 - auc: 0.7375 - loss: 0.5672
# Epoch 67: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6644 - auc: 0.7391 - loss: 0.5658 - val_acc: 0.8108 - val_auc: 0.5000 - val_loss: 0.4847
# Epoch 68/100
# 270/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6440 - auc: 0.7273 - loss: 0.6055
# Epoch 68: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6464 - auc: 0.7294 - loss: 0.6026 - val_acc: 0.7838 - val_auc: 0.4435 - val_loss: 0.9751
# Epoch 69/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6910 - auc: 0.7784 - loss: 0.5356
# Epoch 69: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6908 - auc: 0.7780 - loss: 0.5360 - val_acc: 0.7838 - val_auc: 0.2903 - val_loss: 1.0907
# Epoch 70/100
# 268/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7076 - auc: 0.7681 - loss: 0.5495
# Epoch 70: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7065 - auc: 0.7677 - loss: 0.5496 - val_acc: 0.8108 - val_auc: 0.3817 - val_loss: 0.6423
# Epoch 71/100
# 269/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6608 - auc: 0.7485 - loss: 0.5697
# Epoch 71: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6613 - auc: 0.7490 - loss: 0.5693 - val_acc: 0.8378 - val_auc: 0.4032 - val_loss: 1.3174
# Epoch 72/100
# 281/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6713 - auc: 0.7566 - loss: 0.5675
# Epoch 72: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6716 - auc: 0.7568 - loss: 0.5671 - val_acc: 0.8378 - val_auc: 0.2796 - val_loss: 0.6857
# Epoch 73/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7006 - auc: 0.7840 - loss: 0.5309
# Epoch 73: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6998 - auc: 0.7830 - loss: 0.5315 - val_acc: 0.8378 - val_auc: 0.3065 - val_loss: 1.0541
# Epoch 74/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7072 - auc: 0.7756 - loss: 0.5285
# Epoch 74: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7076 - auc: 0.7762 - loss: 0.5284 - val_acc: 0.7838 - val_auc: 0.5511 - val_loss: 0.7153
# Epoch 75/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7342 - auc: 0.8258 - loss: 0.4781
# Epoch 75: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7330 - auc: 0.8246 - loss: 0.4797 - val_acc: 0.8378 - val_auc: 0.4194 - val_loss: 1.4986
# Epoch 76/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7110 - auc: 0.7899 - loss: 0.5224
# Epoch 76: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7110 - auc: 0.7899 - loss: 0.5224 - val_acc: 0.7838 - val_auc: 0.4140 - val_loss: 0.7020
# Epoch 77/100
# 268/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6915 - auc: 0.7686 - loss: 0.5433
# Epoch 77: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6918 - auc: 0.7688 - loss: 0.5430 - val_acc: 0.8378 - val_auc: 0.5027 - val_loss: 0.4529
# Epoch 78/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6964 - auc: 0.7663 - loss: 0.5451
# Epoch 78: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6960 - auc: 0.7662 - loss: 0.5454 - val_acc: 0.8108 - val_auc: 0.5914 - val_loss: 0.5931
# Epoch 79/100
# 273/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6655 - auc: 0.7402 - loss: 0.5641
# Epoch 79: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6665 - auc: 0.7419 - loss: 0.5627 - val_acc: 0.7838 - val_auc: 0.5376 - val_loss: 0.6331
# Epoch 80/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7088 - auc: 0.8024 - loss: 0.5226
# Epoch 80: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7092 - auc: 0.8023 - loss: 0.5227 - val_acc: 0.7838 - val_auc: 0.5699 - val_loss: 0.6240
# Epoch 81/100
# 274/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7126 - auc: 0.7678 - loss: 0.5404
# Epoch 81: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7128 - auc: 0.7685 - loss: 0.5402 - val_acc: 0.7838 - val_auc: 0.4919 - val_loss: 0.6342
# Epoch 82/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7243 - auc: 0.7798 - loss: 0.5232
# Epoch 82: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7241 - auc: 0.7805 - loss: 0.5232 - val_acc: 0.8108 - val_auc: 0.5726 - val_loss: 0.6756
# Epoch 83/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7275 - auc: 0.8017 - loss: 0.5079
# Epoch 83: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7276 - auc: 0.8016 - loss: 0.5082 - val_acc: 0.7838 - val_auc: 0.5430 - val_loss: 0.5153
# Epoch 84/100
# 272/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6691 - auc: 0.7553 - loss: 0.5642
# Epoch 84: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6711 - auc: 0.7572 - loss: 0.5622 - val_acc: 0.7568 - val_auc: 0.5027 - val_loss: 0.8754
# Epoch 85/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7044 - auc: 0.7788 - loss: 0.5448
# Epoch 85: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7046 - auc: 0.7790 - loss: 0.5444 - val_acc: 0.8378 - val_auc: 0.4758 - val_loss: 0.5356
# Epoch 86/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6668 - auc: 0.7867 - loss: 0.5288
# Epoch 86: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6680 - auc: 0.7872 - loss: 0.5283 - val_acc: 0.8108 - val_auc: 0.4005 - val_loss: 0.5831
# Epoch 87/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7333 - auc: 0.8288 - loss: 0.4831
# Epoch 87: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7331 - auc: 0.8285 - loss: 0.4834 - val_acc: 0.7568 - val_auc: 0.4409 - val_loss: 0.5873
# Epoch 88/100
# 279/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6845 - auc: 0.7847 - loss: 0.5217
# Epoch 88: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6850 - auc: 0.7849 - loss: 0.5216 - val_acc: 0.7568 - val_auc: 0.4543 - val_loss: 0.6875
# Epoch 89/100
# 271/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7363 - auc: 0.8326 - loss: 0.4783
# Epoch 89: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7344 - auc: 0.8306 - loss: 0.4809 - val_acc: 0.7568 - val_auc: 0.5000 - val_loss: 0.5562
# Epoch 90/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7256 - auc: 0.7912 - loss: 0.5167
# Epoch 90: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7255 - auc: 0.7913 - loss: 0.5168 - val_acc: 0.7568 - val_auc: 0.4812 - val_loss: 0.7316
# Epoch 91/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7361 - auc: 0.8149 - loss: 0.4984
# Epoch 91: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7355 - auc: 0.8145 - loss: 0.4988 - val_acc: 0.8378 - val_auc: 0.5323 - val_loss: 0.6161
# Epoch 92/100
# 270/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7010 - auc: 0.7708 - loss: 0.5460
# Epoch 92: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7004 - auc: 0.7708 - loss: 0.5459 - val_acc: 0.7568 - val_auc: 0.4597 - val_loss: 0.7297
# Epoch 93/100
# 273/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6771 - auc: 0.7808 - loss: 0.5250
# Epoch 93: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6782 - auc: 0.7811 - loss: 0.5247 - val_acc: 0.7838 - val_auc: 0.5806 - val_loss: 0.7676
# Epoch 94/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6710 - auc: 0.7653 - loss: 0.5430
# Epoch 94: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6723 - auc: 0.7663 - loss: 0.5419 - val_acc: 0.7838 - val_auc: 0.5645 - val_loss: 0.6003
# Epoch 95/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7019 - auc: 0.7940 - loss: 0.5096
# Epoch 95: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7019 - auc: 0.7938 - loss: 0.5101 - val_acc: 0.7568 - val_auc: 0.5618 - val_loss: 0.9043
# Epoch 96/100
# 279/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6956 - auc: 0.7871 - loss: 0.5185
# Epoch 96: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6955 - auc: 0.7869 - loss: 0.5188 - val_acc: 0.8108 - val_auc: 0.3898 - val_loss: 0.5203
# Epoch 97/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7099 - auc: 0.7662 - loss: 0.5450
# Epoch 97: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7097 - auc: 0.7667 - loss: 0.5446 - val_acc: 0.8108 - val_auc: 0.3763 - val_loss: 0.5774
# Epoch 98/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6923 - auc: 0.7828 - loss: 0.5276
# Epoch 98: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6929 - auc: 0.7836 - loss: 0.5270 - val_acc: 0.7568 - val_auc: 0.4677 - val_loss: 0.8805
# Epoch 99/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7146 - auc: 0.7999 - loss: 0.5009
# Epoch 99: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7142 - auc: 0.7995 - loss: 0.5016 - val_acc: 0.8378 - val_auc: 0.5565 - val_loss: 0.6720
# Epoch 100/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7150 - auc: 0.7986 - loss: 0.5125
# Epoch 100: val_loss did not improve from 0.39657
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7148 - auc: 0.7982 - loss: 0.5130 - val_acc: 0.7838 - val_auc: 0.4220 - val_loss: 0.6206
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 7 | TEST@0.5  ACC=0.9323 | PREC=0.0000 | REC=0.0000 | F1=0.0000 | AUC=0.9023 | SPEC=1.0000 | n=133
# Fold 7 | TEST@J    ACC=0.8797 | PREC=0.3600 | REC=1.0000 | F1=0.5294 | AUC=0.9023 | SPEC=0.8710 | thr=0.2211, J=0.8710
# Confusion matrix (@0.5):
#  [[124   0]
#  [  9   0]]
# Classification report (@0.5):
#                precision    recall  f1-score   support
#
#            0      0.932     1.000     0.965       124
#            1      0.000     0.000     0.000         9
#
#     accuracy                          0.932       133
#    macro avg      0.466     0.500     0.482       133
# weighted avg      0.869     0.932     0.900       133
#
#
# === TEST metrics per fold — threshold 0.5 ===
# AUC : [np.float64(0.7848), np.float64(0.3954), np.float64(0.7351), np.float64(0.7918), np.float64(0.7783), np.float64(0.8064), np.float64(0.9023)]
# ACC : [0.6412, 0.5893, 0.5, 0.6608, 0.7063, 0.3822, 0.9323]
# PREC: [0.0, 0.0, 0.0, 0.8, 0.0, 0.0, 0.0]
# REC : [0.0, 0.0, 0.0, 0.1395, 0.0, 0.0, 0.0]
# SPEC: [np.float64(0.9767), np.float64(0.9851), np.float64(1.0), np.float64(0.9787), np.float64(0.8396), np.float64(1.0), np.float64(1.0)]
# F1  : [0.0, 0.0, 0.0, 0.2376, 0.0, 0.0, 0.0]
#
# === TEST metrics per fold — Youden-J (on TEST) ===
# AUC@J : [np.float64(0.7848), np.float64(0.3954), np.float64(0.7351), np.float64(0.7918), np.float64(0.7783), np.float64(0.8064), np.float64(0.9023)]
# ACC@J : [0.7557, 0.4732, 0.6739, 0.674, 0.7857, 0.8025, 0.8797]
# PREC@J: [0.6444, 0.4327, 0.7069, 0.5429, 0.4222, 0.8511, 0.36]
# REC@J : [0.6444, 1.0, 0.5942, 0.8837, 0.95, 0.8247, 1.0]
# SPEC@J: [np.float64(0.814), np.float64(0.1194), np.float64(0.7536), np.float64(0.5461), np.float64(0.7547), np.float64(0.7667), np.float64(0.871)]
# F1@J  : [0.6444, 0.604, 0.6457, 0.6726, 0.5846, 0.8377, 0.5294]
#
# === Mean ± SD across folds (TEST) — 0.5 ===
#          AUC: 0.7420 ± 0.1491
#          ACC: 0.6303 ± 0.1596
#    Precision: 0.1143 ± 0.2799
#       Recall: 0.0199 ± 0.0488
#  Specificity: 0.9686 ± 0.0535
#           F1: 0.0339 ± 0.0832
#
# === Mean ± SD across folds (TEST) — Youden-J (on TEST) ===
#        AUC@J: 0.7420 ± 0.1491
#        ACC@J: 0.7207 ± 0.1213
#  Precision@J: 0.5657 ± 0.1642
#     Recall@J: 0.8424 ± 0.1531
# Specificity@J: 0.6608 ± 0.2398
#         F1@J: 0.6455 ± 0.0899
#
# Saved TEST-only per-fold metrics to cv7_img_fold_metrics.csv
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
