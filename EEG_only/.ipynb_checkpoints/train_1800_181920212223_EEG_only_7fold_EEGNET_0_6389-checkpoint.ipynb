# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.transforms as transforms
import os
import argparse
from pathlib import Path
import re
import random
import math
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
from torch.utils.data import Dataset, DataLoader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### EEGNet-8,2

# %%
from pathlib import Path
import re, random, math, os
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    accuracy_score, roc_auc_score, classification_report, confusion_matrix,
    precision_score, recall_score, f1_score, roc_curve,   # <-- added
)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.constraints import max_norm   # <-- NEW

# =========================
# Config
# =========================
SPLIT_DIR = r"/content/drive/MyDrive/CD/patient_data_clean_1800s_nozero_181920212223_in3days_v2"
POS_PATIENTS = {1, 2, 16, 19, 21, 22, 25, 37, 39, 43, 44, 47, 50, 56, 58, 62, 65, 66, 73, 78}

BATCH_SIZE       = 3
EPOCHS           = 100
LR               = 1e-4
SEED             = 1
K_FOLDS          = 7
BEST_MODEL_TPL   = "best_fold_{:02d}.h5"

# not used for dedup height; kept for reference
TARGET_H = 300

# =========================
# Noise config (train-time augmentation only)
# =========================
TRAIN_ADD_GAUSS_NOISE = True     # training generator only
TRAIN_NOISE_FRAC      = 0.10
TRAIN_NOISE_PROB      = 1.0
EPS_STD               = 1e-8

# =========================
# Repro
# =========================
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
for g in tf.config.list_physical_devices('GPU'):
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception:
        pass

# =========================
# Helpers for ID/labels
# =========================
PATIENT_NUM_RX = re.compile(r'^ID(\d+)')

def patient_num_from_path(pathlike):
    stem = Path(pathlike).stem
    m = PATIENT_NUM_RX.match(stem)
    return int(m.group(1)) if m else None

def label_for_file(p: Path) -> int:
    pnum = patient_num_from_path(p)
    return 1 if (pnum is not None and pnum in POS_PATIENTS) else 0

# =========================
# List files (all) & labels by patient ID
# =========================
split_dir = Path(SPLIT_DIR)
all_csvs = sorted(split_dir.glob("*.csv"))
if not all_csvs:
    raise FileNotFoundError(f"No CSV found in {SPLIT_DIR}")

id_to_files = {}
for f in all_csvs:
    pid = patient_num_from_path(f)
    if pid is None or pid == 12:    # <-- exclude ID 12
        continue
    id_to_files.setdefault(pid, []).append(f)

all_ids = sorted(id_to_files.keys())
id_labels = np.array([1 if pid in POS_PATIENTS else 0 for pid in all_ids], dtype=int)
print("Total IDs:", len(all_ids), "| Pos IDs:", id_labels.sum(), "| Neg IDs:", (1 - id_labels).sum())

# =========================
# Column handling
# =========================
def _drop_time_cols(df: pd.DataFrame) -> pd.DataFrame:
    time_like = [c for c in df.columns if isinstance(c, str) and c.strip().lower() == "time"]
    return df.drop(columns=time_like, errors="ignore")

def _to_numeric_df(df: pd.DataFrame) -> pd.DataFrame:
    df = _drop_time_cols(df)
    return df.apply(pd.to_numeric, errors="coerce").fillna(0.0)

def _pad_crop_2d(x: np.ndarray, H: int, W: int) -> np.ndarray:
    h, w = x.shape
    if h < H:
        pad = np.zeros((H, w), dtype=x.dtype); pad[:h, :] = x; x = pad; h = H
    elif h > H:
        x = x[:H, :]; h = H
    if w < W:
        pad = np.zeros((h, W), dtype=x.dtype); pad[:, :w] = x; x = pad
    elif w > W:
        x = x[:, :W]
    return x

def _infer_target_width(example_csv: Path) -> int:
    df = pd.read_csv(example_csv)
    df2 = _to_numeric_df(df)
    return df2.shape[1]

# Fix width/height ONCE using the whole dataset (so all folds match)
TARGET_W = _infer_target_width(all_csvs[0])
print(f"TARGET_W={TARGET_W} (non-Time columns)")

def _dedupe_consecutive_rows(mat: np.ndarray) -> np.ndarray:
    if mat.size == 0:
        return mat
    if mat.ndim == 1:
        mat = mat[:, None]
    if mat.shape[0] == 1:
        return mat
    diffs = np.any(mat[1:] != mat[:-1], axis=1)
    keep = np.concatenate(([True], diffs))
    return mat[keep]

def _dedup_len_from_csv(p: Path) -> int:
    df = pd.read_csv(p)
    mat = _to_numeric_df(df).to_numpy(dtype=np.float32)
    mat_d = _dedupe_consecutive_rows(mat)
    return int(mat_d.shape[0])

TARGET_H_DEDUP = max(_dedup_len_from_csv(f) for f in all_csvs)
if TARGET_H_DEDUP <= 0:
    raise RuntimeError("After de-dup, zero-length found in data.")
print(f"Fixed input height after de-dup (all IDs): H={TARGET_H_DEDUP}")

def load_csv_as_image_dedup(csv_path: Path) -> np.ndarray:
    df  = pd.read_csv(csv_path)
    df2 = _to_numeric_df(df)
    mat = df2.to_numpy(dtype=np.float32)      # shape ~ (Samples, Chans)
    if mat.ndim != 2:
        mat = mat.reshape(mat.shape[0], -1) if mat.ndim > 2 else mat
    mat = _dedupe_consecutive_rows(mat)
    if mat.shape[0] == 0:
        mat = np.zeros((1, TARGET_W), dtype=np.float32)
    mat = _pad_crop_2d(mat, TARGET_H_DEDUP, TARGET_W)
    # NOTE: keep shape as (Samples, Chans); EEGNet will permute internally
    img = np.expand_dims(mat, axis=-1).astype(np.float32)  # (Samples, Chans, 1)
    if img.shape != (TARGET_H_DEDUP, TARGET_W, 1):
        raise ValueError(f"loader produced {img.shape}, expected {(TARGET_H_DEDUP, TARGET_W, 1)} for {csv_path}")
    return img

# cache
CACHE_DEDUP = {}
def load_csv_as_image_cached(csv_path: Path) -> np.ndarray:
    key = ("dedup", str(csv_path))
    if key in CACHE_DEDUP:
        return CACHE_DEDUP[key]
    img = load_csv_as_image_dedup(csv_path)
    CACHE_DEDUP[key] = img
    return img

print("Normalization: NONE. De-dup: remove consecutive duplicate rows (row-wise).")

# =========================
# Keras Sequence
# =========================
class ImageSequence(keras.utils.Sequence):
    def __init__(self, files, batch_size=BATCH_SIZE, shuffle=True,
                 add_noise=False, noise_frac=TRAIN_NOISE_FRAC, noise_prob=TRAIN_NOISE_PROB):
        super().__init__()
        self.files = list(files)
        self.batch_size = int(batch_size)
        self.shuffle = shuffle
        self.add_noise = add_noise
        self.noise_frac = float(noise_frac)
        self.noise_prob = float(noise_prob)
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.files) / self.batch_size)

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.files))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __getitem__(self, idx):
        idxs = self.indexes[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch_files = [self.files[i] for i in idxs]
        B = len(batch_files)
        X = np.empty((B, TARGET_H_DEDUP, TARGET_W, 1), dtype=np.float32)  # (Samples, Chans, 1)
        y = np.empty((B,), dtype=np.int32)

        for i, f in enumerate(batch_files):
            xi = load_csv_as_image_cached(f)
            if xi.ndim == 2:
                xi = xi[..., None]
            if xi.shape != (TARGET_H_DEDUP, TARGET_W, 1):
                raise ValueError(f"Sample shape {xi.shape} for {f}; expected {(TARGET_H_DEDUP, TARGET_W, 1)}")
            X[i] = xi
            y[i] = label_for_file(f)

        if self.add_noise and self.noise_frac > 0.0 and self.noise_prob > 0.0:
            samp_std = X.reshape(B, -1).std(axis=1).astype(np.float32)
            samp_std = np.maximum(samp_std, EPS_STD).reshape(B, 1, 1, 1)
            noise = np.random.normal(0.0, 1.0, size=X.shape).astype(np.float32)
            noise *= (self.noise_frac * samp_std)
            if self.noise_prob < 1.0:
                mask = (np.random.rand(B, 1, 1, 1) < self.noise_prob).astype(np.float32)
                noise *= mask
            X = X + noise

        if X.shape[1:] != (TARGET_H_DEDUP, TARGET_W, 1):
            raise ValueError(f"Batch X has shape {X.shape}; expected (B, {TARGET_H_DEDUP}, {TARGET_W}, 1)")
        return X, y

# =========================
# EEGNet model (binary head)
# =========================
def build_model(samples=TARGET_H_DEDUP, chans=TARGET_W, lr=LR,
                F1=8, D=2, kernLength=64, dropout=0.5, norm_rate=0.25):
    """
    Input: (Samples, Chans, 1)  e.g., (1800, 6, 1)
    Internally permuted to (Chans, Samples, 1) for EEGNet blocks.
    """
    inputs = keras.Input(shape=(samples, chans, 1))

    # Permute to (Chans, Samples, 1) as in EEGNet
    x = layers.Permute((2, 1, 3))(inputs)

    F2 = F1 * D

    # Block 1: temporal conv
    x = layers.Conv2D(
        F1, (1, kernLength),
        padding="same",
        use_bias=False
    )(x)
    x = layers.BatchNormalization()(x)

    # Depthwise conv over channels
    x = layers.DepthwiseConv2D(
        (chans, 1),
        use_bias=False,
        depth_multiplier=D,
        depthwise_constraint=max_norm(1.)
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("elu")(x)
    x = layers.AveragePooling2D((1, 4))(x)
    x = layers.Dropout(dropout)(x)

    # Block 2: separable conv
    x = layers.SeparableConv2D(
        F2,
        (1, 16),
        use_bias=False,
        padding="same"
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("elu")(x)
    x = layers.AveragePooling2D((1, 8))(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Flatten(name="flatten")(x)
    x = layers.Dense(16, kernel_constraint=max_norm(norm_rate))(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[keras.metrics.BinaryAccuracy(name="acc"),
                 keras.metrics.AUC(name="auc")],
    )
    return model

# =========================
# Metric helpers (for TEST)
# =========================
def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
    return tn / (tn + fp) if (tn + fp) > 0 else 0.0

def youden_threshold_from_probs(y_true, y_prob):
    """Return best threshold and J on this set."""
    if len(np.unique(y_true)) < 2:
        return 0.5, 0.0
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    j = tpr - fpr
    i = int(np.argmax(j))
    return float(thr[i]), float(j[i])

def mean_std(x):
    x = np.asarray(x, dtype=float)
    return np.nanmean(x), np.nanstd(x)

# =========================
# 7-fold CV by patient ID
# =========================
skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

# Lists for TEST metrics (@0.5 and @Youden-J)
AUC_list,  ACC_list,  PREC_list,  REC_list,  F1_list,  SPEC_list  = [], [], [], [], [], []
AUC_J_list, ACC_J_list, PREC_J_list, REC_J_list, F1_J_list, SPEC_J_list = [], [], [], [], [], []

rows = []

print(f"\n=== {K_FOLDS}-Fold CV (by patient ID) ===")
for fold_idx, (train_idx, test_idx) in enumerate(skf.split(all_ids, id_labels), start=1):
    ids_train_full = [all_ids[i] for i in train_idx]
    ids_test       = [all_ids[i] for i in test_idx]

    # small validation split from training IDs (for checkpointing)
    train_labels_full = np.array([1 if pid in POS_PATIENTS else 0 for pid in ids_train_full], dtype=int)
    try:
        ids_tr, ids_val = train_test_split(
            ids_train_full, test_size=0.10, random_state=SEED, stratify=train_labels_full
        )
    except ValueError:
        ids_tr, ids_val = train_test_split(ids_train_full, test_size=0.10, random_state=SEED, shuffle=True)
        print(f"(Fold {fold_idx}) Warning: stratified VAL split failed; using unstratified split.")

    # Files for each split
    train_files = [f for pid in ids_tr  for f in id_to_files[pid]]
    val_files   = [f for pid in ids_val for f in id_to_files[pid]]
    test_files  = [f for pid in ids_test for f in id_to_files[pid]]

    def split_summary(name, ids, files):
        ys = np.array([label_for_file(f) for f in files], dtype=int)
        print(f"{name:>6} | ids: {len(ids):4d} | files: {len(files):5d} | pos files: {(ys==1).sum():4d} | neg files: {(ys==0).sum():4d}")

    print(f"\n--- Fold {fold_idx}/{K_FOLDS} ---")
    split_summary("train", ids_tr,  train_files)
    split_summary("val",   ids_val, val_files)
    split_summary("test",  ids_test, test_files)

    # Generators
    train_gen = ImageSequence(train_files, batch_size=BATCH_SIZE, shuffle=True,
                              add_noise=TRAIN_ADD_GAUSS_NOISE,
                              noise_frac=TRAIN_NOISE_FRAC,
                              noise_prob=TRAIN_NOISE_PROB)
    val_gen   = ImageSequence(val_files,   batch_size=BATCH_SIZE, shuffle=False, add_noise=False)
    test_gen  = ImageSequence(test_files,  batch_size=BATCH_SIZE, shuffle=False, add_noise=False)

    # Train & pick best by val_loss
    model = build_model()
    best_path = BEST_MODEL_TPL.format(fold_idx)
    ckpt = keras.callbacks.ModelCheckpoint(best_path, monitor="val_loss", mode="min",
                                           save_best_only=True, verbose=1)
    _ = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS, callbacks=[ckpt], verbose=1)

    # Evaluate on TEST
    best_model = keras.models.load_model(best_path)
    test_probs = best_model.predict(test_gen, verbose=0).ravel().astype(float)
    test_y     = np.array([label_for_file(f) for f in test_gen.files], dtype=int)

    # AUC (threshold-free)
    try:
        test_auc = roc_auc_score(test_y, test_probs)
    except ValueError:
        test_auc = float('nan')

    # --- Threshold 0.5 ---
    y_pred_05 = (test_probs >= 0.5).astype(int)
    acc_05  = accuracy_score(test_y, y_pred_05)
    prec_05 = precision_score(test_y, y_pred_05, zero_division=0)
    rec_05  = recall_score(test_y, y_pred_05, zero_division=0)
    f1_05   = f1_score(test_y, y_pred_05, zero_division=0)
    spec_05 = specificity_score(test_y, y_pred_05)

    # --- Youden-J threshold on TEST ---
    t_star, J_val = youden_threshold_from_probs(test_y, test_probs)
    y_pred_J = (test_probs >= t_star).astype(int)
    acc_J  = accuracy_score(test_y, y_pred_J)
    prec_J = precision_score(test_y, y_pred_J, zero_division=0)
    rec_J  = recall_score(test_y, y_pred_J, zero_division=0)
    f1_J   = f1_score(test_y, y_pred_J, zero_division=0)
    spec_J = specificity_score(test_y, y_pred_J)

    # collect lists
    AUC_list.append(test_auc); ACC_list.append(acc_05);   PREC_list.append(prec_05)
    REC_list.append(rec_05);   F1_list.append(f1_05);     SPEC_list.append(spec_05)

    AUC_J_list.append(test_auc); ACC_J_list.append(acc_J);   PREC_J_list.append(prec_J)
    REC_J_list.append(rec_J);    F1_J_list.append(f1_J);     SPEC_J_list.append(spec_J)

    print(f"Fold {fold_idx} | TEST@0.5  ACC={acc_05:.4f} | PREC={prec_05:.4f} | "
          f"REC={rec_05:.4f} | F1={f1_05:.4f} | AUC={test_auc:.4f} | SPEC={spec_05:.4f} | n={len(test_y)}")
    print(f"Fold {fold_idx} | TEST@J    ACC={acc_J:.4f} | PREC={prec_J:.4f} | "
          f"REC={rec_J:.4f} | F1={f1_J:.4f} | AUC={test_auc:.4f} | SPEC={spec_J:.4f} | thr={t_star:.4f}, J={J_val:.4f}")
    print("Confusion matrix (@0.5):\n", confusion_matrix(test_y, y_pred_05))
    print("Classification report (@0.5):\n", classification_report(test_y, y_pred_05, digits=3))

    rows.append({
        "fold": fold_idx,
        "train_files": len(train_files),
        "val_files": len(val_files),
        "test_files": len(test_files),

        "ACC_0.5": acc_05,
        "PREC_0.5": prec_05,
        "REC_0.5": rec_05,
        "F1_0.5": f1_05,
        "AUC": test_auc,
        "SPEC_0.5": spec_05,

        "thr_J": t_star,
        "J": J_val,
        "ACC_J": acc_J,
        "PREC_J": prec_J,
        "REC_J": rec_J,
        "F1_J": f1_J,
        "SPEC_J": spec_J,
    })

# =========================
# Summary across folds
# =========================
print("\n=== TEST metrics per fold — threshold 0.5 ===")
print("AUC :", [None if np.isnan(x) else round(x,4) for x in AUC_list])
print("ACC :", [round(x,4) for x in ACC_list])
print("PREC:", [round(x,4) for x in PREC_list])
print("REC :", [round(x,4) for x in REC_list])
print("SPEC:", [round(x,4) for x in SPEC_list])
print("F1  :", [round(x,4) for x in F1_list])

print("\n=== TEST metrics per fold — Youden-J (on TEST) ===")
print("AUC@J :", [None if np.isnan(x) else round(x,4) for x in AUC_J_list])
print("ACC@J :", [round(x,4) for x in ACC_J_list])
print("PREC@J:", [round(x,4) for x in PREC_J_list])
print("REC@J :", [round(x,4) for x in REC_J_list])
print("SPEC@J:", [round(x,4) for x in SPEC_J_list])
print("F1@J  :", [round(x,4) for x in F1_J_list])

mAUC,  sAUC  = mean_std(AUC_list)
mACC,  sACC  = mean_std(ACC_list)
mPREC, sPREC = mean_std(PREC_list)
mREC,  sREC  = mean_std(REC_list)
mF1,   sF1   = mean_std(F1_list)
mSPEC, sSPEC = mean_std(SPEC_list)

print("\n=== Mean ± SD across folds (TEST) — 0.5 ===")
print(f"{'AUC':>12}: {mAUC:.4f} ± {sAUC:.4f}")
print(f"{'ACC':>12}: {mACC:.4f} ± {sACC:.4f}")
print(f"{'Precision':>12}: {mPREC:.4f} ± {sPREC:.4f}")
print(f"{'Recall':>12}: {mREC:.4f} ± {sREC:.4f}")
print(f"{'Specificity':>12}: {mSPEC:.4f} ± {sSPEC:.4f}")
print(f"{'F1':>12}: {mF1:.4f} ± {sF1:.4f}")

mAUC_J,  sAUC_J  = mean_std(AUC_J_list)
mACC_J,  sACC_J  = mean_std(ACC_J_list)
mPREC_J, sPREC_J = mean_std(PREC_J_list)
mREC_J,  sREC_J  = mean_std(REC_J_list)
mF1_J,   sF1_J   = mean_std(F1_J_list)
mSPEC_J, sSPEC_J = mean_std(SPEC_J_list)

print("\n=== Mean ± SD across folds (TEST) — Youden-J (on TEST) ===")
print(f"{'AUC@J':>12}: {mAUC_J:.4f} ± {sAUC_J:.4f}")
print(f"{'ACC@J':>12}: {mACC_J:.4f} ± {sACC_J:.4f}")
print(f"{'Precision@J':>12}: {mPREC_J:.4f} ± {sPREC_J:.4f}")
print(f"{'Recall@J':>12}: {mREC_J:.4f} ± {sREC_J:.4f}")
print(f"{'Specificity@J':>12}: {mSPEC_J:.4f} ± {sSPEC_J:.4f}")
print(f"{'F1@J':>12}: {mF1_J:.4f} ± {sF1_J:.4f}")

metrics_df = pd.DataFrame(rows)
metrics_df.to_csv("cv7_img_fold_metrics.csv", index=False)
print("\nSaved TEST-only per-fold metrics to cv7_img_fold_metrics.csv")
# Out:
# Total IDs: 42 | Pos IDs: 13 | Neg IDs: 29
# TARGET_W=6 (non-Time columns)
# Fixed input height after de-dup (all IDs): H=360
# Normalization: NONE. De-dup: remove consecutive duplicate rows (row-wise).
#
# === 7-Fold CV (by patient ID) ===
#
# --- Fold 1/7 ---
#  train | ids:   32 | files:   808 | pos files:  320 | neg files:  488
#    val | ids:    4 | files:    85 | pos files:    6 | neg files:   79
#   test | ids:    6 | files:   131 | pos files:   45 | neg files:   86
# Epoch 1/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.5763 - auc: 0.5336 - loss: 0.6948
# Epoch 1: val_loss improved from inf to 0.71465, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 23s 51ms/step - acc: 0.5764 - auc: 0.5338 - loss: 0.6947 - val_acc: 0.2235 - val_auc: 0.6055 - val_loss: 0.7146
# Epoch 2/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6301 - auc: 0.6374 - loss: 0.6384
# Epoch 2: val_loss improved from 0.71465 to 0.57984, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6295 - auc: 0.6373 - loss: 0.6386 - val_acc: 0.7294 - val_auc: 0.7838 - val_loss: 0.5798
# Epoch 3/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6280 - auc: 0.6514 - loss: 0.6448
# Epoch 3: val_loss improved from 0.57984 to 0.50722, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6278 - auc: 0.6511 - loss: 0.6447 - val_acc: 0.8941 - val_auc: 0.8671 - val_loss: 0.5072
# Epoch 4/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6512 - auc: 0.6971 - loss: 0.6163
# Epoch 4: val_loss improved from 0.50722 to 0.48236, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6512 - auc: 0.6974 - loss: 0.6157 - val_acc: 0.9412 - val_auc: 0.9631 - val_loss: 0.4824
# Epoch 5/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6529 - auc: 0.6887 - loss: 0.6206
# Epoch 5: val_loss did not improve from 0.48236
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6528 - auc: 0.6883 - loss: 0.6207 - val_acc: 0.9294 - val_auc: 0.9378 - val_loss: 0.4829
# Epoch 6/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6439 - auc: 0.6942 - loss: 0.6097
# Epoch 6: val_loss improved from 0.48236 to 0.47901, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6442 - auc: 0.6941 - loss: 0.6097 - val_acc: 0.9176 - val_auc: 0.9230 - val_loss: 0.4790
# Epoch 7/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6894 - auc: 0.7220 - loss: 0.5910
# Epoch 7: val_loss improved from 0.47901 to 0.31756, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6892 - auc: 0.7219 - loss: 0.5911 - val_acc: 0.9294 - val_auc: 0.4135 - val_loss: 0.3176
# Epoch 8/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7009 - auc: 0.7484 - loss: 0.5743
# Epoch 8: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6991 - auc: 0.7466 - loss: 0.5755 - val_acc: 0.3176 - val_auc: 0.8165 - val_loss: 0.8531
# Epoch 9/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6608 - auc: 0.7079 - loss: 0.5982
# Epoch 9: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6610 - auc: 0.7080 - loss: 0.5982 - val_acc: 0.7294 - val_auc: 0.7595 - val_loss: 0.5719
# Epoch 10/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6918 - auc: 0.7231 - loss: 0.5914
# Epoch 10: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6913 - auc: 0.7234 - loss: 0.5910 - val_acc: 0.8941 - val_auc: 0.3186 - val_loss: 0.4601
# Epoch 11/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6823 - auc: 0.7509 - loss: 0.5699
# Epoch 11: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6822 - auc: 0.7498 - loss: 0.5704 - val_acc: 0.8941 - val_auc: 0.3586 - val_loss: 0.4238
# Epoch 12/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7086 - auc: 0.7554 - loss: 0.5711
# Epoch 12: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7078 - auc: 0.7546 - loss: 0.5714 - val_acc: 0.8471 - val_auc: 0.2932 - val_loss: 0.4280
# Epoch 13/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7005 - auc: 0.7630 - loss: 0.5671
# Epoch 13: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7006 - auc: 0.7619 - loss: 0.5677 - val_acc: 0.7765 - val_auc: 0.2563 - val_loss: 0.4573
# Epoch 14/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6812 - auc: 0.7320 - loss: 0.5894
# Epoch 14: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6814 - auc: 0.7317 - loss: 0.5891 - val_acc: 0.3176 - val_auc: 0.3998 - val_loss: 0.8019
# Epoch 15/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7040 - auc: 0.7339 - loss: 0.5693
# Epoch 15: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7032 - auc: 0.7328 - loss: 0.5704 - val_acc: 0.4235 - val_auc: 0.4072 - val_loss: 0.7086
# Epoch 16/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6964 - auc: 0.7087 - loss: 0.5782
# Epoch 16: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6952 - auc: 0.7094 - loss: 0.5788 - val_acc: 0.3176 - val_auc: 0.5643 - val_loss: 0.8046
# Epoch 17/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6655 - auc: 0.7148 - loss: 0.5938
# Epoch 17: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6656 - auc: 0.7150 - loss: 0.5937 - val_acc: 0.5176 - val_auc: 0.4525 - val_loss: 0.6343
# Epoch 18/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6700 - auc: 0.7313 - loss: 0.5760
# Epoch 18: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6707 - auc: 0.7311 - loss: 0.5761 - val_acc: 0.5529 - val_auc: 0.4599 - val_loss: 0.6417
# Epoch 19/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7013 - auc: 0.7305 - loss: 0.5795
# Epoch 19: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6996 - auc: 0.7303 - loss: 0.5798 - val_acc: 0.2941 - val_auc: 0.5601 - val_loss: 0.8415
# Epoch 20/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7085 - auc: 0.7443 - loss: 0.5608
# Epoch 20: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7079 - auc: 0.7443 - loss: 0.5611 - val_acc: 0.2941 - val_auc: 0.4525 - val_loss: 0.8602
# Epoch 21/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6908 - auc: 0.7311 - loss: 0.5716
# Epoch 21: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6912 - auc: 0.7305 - loss: 0.5724 - val_acc: 0.2118 - val_auc: 0.5338 - val_loss: 1.1471
# Epoch 22/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6613 - auc: 0.7224 - loss: 0.5964
# Epoch 22: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6621 - auc: 0.7221 - loss: 0.5960 - val_acc: 0.5412 - val_auc: 0.3122 - val_loss: 0.6593
# Epoch 23/100
# 251/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6769 - auc: 0.7407 - loss: 0.5751
# Epoch 23: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6763 - auc: 0.7397 - loss: 0.5756 - val_acc: 0.7647 - val_auc: 0.3165 - val_loss: 0.4942
# Epoch 24/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6618 - auc: 0.7175 - loss: 0.5961
# Epoch 24: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6621 - auc: 0.7179 - loss: 0.5951 - val_acc: 0.2941 - val_auc: 0.4557 - val_loss: 0.7946
# Epoch 25/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7007 - auc: 0.7516 - loss: 0.5647
# Epoch 25: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7003 - auc: 0.7510 - loss: 0.5651 - val_acc: 0.7765 - val_auc: 0.2595 - val_loss: 0.5040
# Epoch 26/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6709 - auc: 0.7207 - loss: 0.5950
# Epoch 26: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6713 - auc: 0.7208 - loss: 0.5948 - val_acc: 0.3176 - val_auc: 0.3629 - val_loss: 0.8431
# Epoch 27/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6877 - auc: 0.7083 - loss: 0.5925
# Epoch 27: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6877 - auc: 0.7091 - loss: 0.5919 - val_acc: 0.2118 - val_auc: 0.4167 - val_loss: 1.2815
# Epoch 28/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7139 - auc: 0.7543 - loss: 0.5605
# Epoch 28: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7137 - auc: 0.7543 - loss: 0.5606 - val_acc: 0.2941 - val_auc: 0.5158 - val_loss: 0.8970
# Epoch 29/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7138 - auc: 0.7753 - loss: 0.5373
# Epoch 29: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7130 - auc: 0.7733 - loss: 0.5392 - val_acc: 0.7647 - val_auc: 0.2690 - val_loss: 0.5267
# Epoch 30/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7300 - auc: 0.7891 - loss: 0.5371
# Epoch 30: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7289 - auc: 0.7875 - loss: 0.5384 - val_acc: 0.7529 - val_auc: 0.2426 - val_loss: 0.5975
# Epoch 31/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6912 - auc: 0.7685 - loss: 0.5595
# Epoch 31: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6913 - auc: 0.7678 - loss: 0.5597 - val_acc: 0.2000 - val_auc: 0.5243 - val_loss: 1.4230
# Epoch 32/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6871 - auc: 0.7237 - loss: 0.5857
# Epoch 32: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6872 - auc: 0.7240 - loss: 0.5855 - val_acc: 0.2941 - val_auc: 0.3713 - val_loss: 0.9210
# Epoch 33/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6922 - auc: 0.7352 - loss: 0.5663
# Epoch 33: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6915 - auc: 0.7357 - loss: 0.5663 - val_acc: 0.1765 - val_auc: 0.6055 - val_loss: 1.4785
# Epoch 34/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6628 - auc: 0.7094 - loss: 0.5813
# Epoch 34: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6634 - auc: 0.7110 - loss: 0.5806 - val_acc: 0.4471 - val_auc: 0.3555 - val_loss: 0.7399
# Epoch 35/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6876 - auc: 0.7441 - loss: 0.5606
# Epoch 35: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6876 - auc: 0.7438 - loss: 0.5611 - val_acc: 0.5412 - val_auc: 0.2975 - val_loss: 0.6839
# Epoch 36/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7162 - auc: 0.7769 - loss: 0.5379
# Epoch 36: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7159 - auc: 0.7763 - loss: 0.5384 - val_acc: 0.2706 - val_auc: 0.3460 - val_loss: 1.1472
# Epoch 37/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7157 - auc: 0.7526 - loss: 0.5524
# Epoch 37: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7162 - auc: 0.7530 - loss: 0.5524 - val_acc: 0.2941 - val_auc: 0.3492 - val_loss: 1.0288
# Epoch 38/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7108 - auc: 0.7247 - loss: 0.5885
# Epoch 38: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7113 - auc: 0.7255 - loss: 0.5878 - val_acc: 0.2824 - val_auc: 0.2996 - val_loss: 0.9737
# Epoch 39/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7151 - auc: 0.7828 - loss: 0.5447
# Epoch 39: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7151 - auc: 0.7821 - loss: 0.5447 - val_acc: 0.3412 - val_auc: 0.2996 - val_loss: 0.8692
# Epoch 40/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6771 - auc: 0.7180 - loss: 0.5914
# Epoch 40: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6772 - auc: 0.7181 - loss: 0.5913 - val_acc: 0.2824 - val_auc: 0.3502 - val_loss: 1.1812
# Epoch 41/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7026 - auc: 0.7636 - loss: 0.5464
# Epoch 41: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7027 - auc: 0.7636 - loss: 0.5464 - val_acc: 0.4353 - val_auc: 0.3344 - val_loss: 0.7790
# Epoch 42/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7223 - auc: 0.7662 - loss: 0.5535
# Epoch 42: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7219 - auc: 0.7660 - loss: 0.5536 - val_acc: 0.3647 - val_auc: 0.3038 - val_loss: 0.7983
# Epoch 43/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7017 - auc: 0.7619 - loss: 0.5373
# Epoch 43: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7011 - auc: 0.7608 - loss: 0.5390 - val_acc: 0.3176 - val_auc: 0.4494 - val_loss: 0.8468
# Epoch 44/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7024 - auc: 0.7585 - loss: 0.5560
# Epoch 44: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7023 - auc: 0.7582 - loss: 0.5562 - val_acc: 0.4941 - val_auc: 0.3143 - val_loss: 0.7328
# Epoch 45/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6953 - auc: 0.7612 - loss: 0.5539
# Epoch 45: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6959 - auc: 0.7613 - loss: 0.5537 - val_acc: 0.3176 - val_auc: 0.3175 - val_loss: 0.8863
# Epoch 46/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6747 - auc: 0.7347 - loss: 0.5643
# Epoch 46: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6751 - auc: 0.7351 - loss: 0.5643 - val_acc: 0.4706 - val_auc: 0.3829 - val_loss: 0.7384
# Epoch 47/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6807 - auc: 0.7255 - loss: 0.5892
# Epoch 47: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6809 - auc: 0.7257 - loss: 0.5889 - val_acc: 0.3176 - val_auc: 0.2954 - val_loss: 1.0111
# Epoch 48/100
# 250/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7254 - auc: 0.7836 - loss: 0.5332
# Epoch 48: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7233 - auc: 0.7817 - loss: 0.5349 - val_acc: 0.5294 - val_auc: 0.2943 - val_loss: 0.6848
# Epoch 49/100
# 250/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7337 - auc: 0.7557 - loss: 0.5585
# Epoch 49: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7327 - auc: 0.7554 - loss: 0.5590 - val_acc: 0.3765 - val_auc: 0.2880 - val_loss: 0.7992
# Epoch 50/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7186 - auc: 0.7580 - loss: 0.5471
# Epoch 50: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7184 - auc: 0.7578 - loss: 0.5473 - val_acc: 0.2706 - val_auc: 0.3734 - val_loss: 1.1562
# Epoch 51/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7190 - auc: 0.7574 - loss: 0.5601
# Epoch 51: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7189 - auc: 0.7577 - loss: 0.5599 - val_acc: 0.3059 - val_auc: 0.2700 - val_loss: 0.9819
# Epoch 52/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6917 - auc: 0.7299 - loss: 0.5574
# Epoch 52: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6920 - auc: 0.7304 - loss: 0.5575 - val_acc: 0.4824 - val_auc: 0.2679 - val_loss: 0.7175
# Epoch 53/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6962 - auc: 0.7371 - loss: 0.5639
# Epoch 53: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6962 - auc: 0.7372 - loss: 0.5639 - val_acc: 0.5059 - val_auc: 0.2743 - val_loss: 0.7106
# Epoch 54/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6974 - auc: 0.7318 - loss: 0.5714
# Epoch 54: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6972 - auc: 0.7317 - loss: 0.5715 - val_acc: 0.3647 - val_auc: 0.3080 - val_loss: 0.8575
# Epoch 55/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6990 - auc: 0.7652 - loss: 0.5466
# Epoch 55: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6993 - auc: 0.7651 - loss: 0.5466 - val_acc: 0.2824 - val_auc: 0.2848 - val_loss: 1.1863
# Epoch 56/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6785 - auc: 0.7110 - loss: 0.5886
# Epoch 56: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6790 - auc: 0.7121 - loss: 0.5877 - val_acc: 0.4471 - val_auc: 0.2595 - val_loss: 0.7970
# Epoch 57/100
# 255/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6890 - auc: 0.7458 - loss: 0.5634
# Epoch 57: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6891 - auc: 0.7459 - loss: 0.5631 - val_acc: 0.2706 - val_auc: 0.2785 - val_loss: 0.9562
# Epoch 58/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6946 - auc: 0.7522 - loss: 0.5624
# Epoch 58: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6949 - auc: 0.7526 - loss: 0.5621 - val_acc: 0.2353 - val_auc: 0.3544 - val_loss: 1.2215
# Epoch 59/100
# 251/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7046 - auc: 0.7719 - loss: 0.5326
# Epoch 59: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7041 - auc: 0.7718 - loss: 0.5333 - val_acc: 0.5765 - val_auc: 0.2553 - val_loss: 0.6886
# Epoch 60/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7033 - auc: 0.7656 - loss: 0.5492
# Epoch 60: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7033 - auc: 0.7656 - loss: 0.5492 - val_acc: 0.2824 - val_auc: 0.2732 - val_loss: 1.0018
# Epoch 61/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6975 - auc: 0.7347 - loss: 0.5637
# Epoch 61: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6974 - auc: 0.7350 - loss: 0.5636 - val_acc: 0.5059 - val_auc: 0.2563 - val_loss: 0.7378
# Epoch 62/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7436 - auc: 0.8003 - loss: 0.5216
# Epoch 62: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7431 - auc: 0.7993 - loss: 0.5223 - val_acc: 0.6353 - val_auc: 0.2384 - val_loss: 0.6176
# Epoch 63/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6938 - auc: 0.7613 - loss: 0.5433
# Epoch 63: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6941 - auc: 0.7616 - loss: 0.5431 - val_acc: 0.2353 - val_auc: 0.3228 - val_loss: 1.2821
# Epoch 64/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7435 - auc: 0.7984 - loss: 0.5234
# Epoch 64: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7424 - auc: 0.7974 - loss: 0.5241 - val_acc: 0.1647 - val_auc: 0.3376 - val_loss: 1.4405
# Epoch 65/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7304 - auc: 0.7769 - loss: 0.5280
# Epoch 65: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7299 - auc: 0.7766 - loss: 0.5284 - val_acc: 0.5529 - val_auc: 0.2521 - val_loss: 0.6584
# Epoch 66/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7143 - auc: 0.7691 - loss: 0.5273
# Epoch 66: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7142 - auc: 0.7693 - loss: 0.5275 - val_acc: 0.2706 - val_auc: 0.2911 - val_loss: 1.2113
# Epoch 67/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7303 - auc: 0.7805 - loss: 0.5455
# Epoch 67: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7300 - auc: 0.7801 - loss: 0.5458 - val_acc: 0.2000 - val_auc: 0.3597 - val_loss: 1.3777
# Epoch 68/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6949 - auc: 0.7648 - loss: 0.5538
# Epoch 68: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6953 - auc: 0.7644 - loss: 0.5538 - val_acc: 0.6706 - val_auc: 0.2416 - val_loss: 0.6365
# Epoch 69/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7150 - auc: 0.7495 - loss: 0.5485
# Epoch 69: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7148 - auc: 0.7494 - loss: 0.5486 - val_acc: 0.4706 - val_auc: 0.2574 - val_loss: 0.7808
# Epoch 70/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6925 - auc: 0.7462 - loss: 0.5554
# Epoch 70: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6924 - auc: 0.7461 - loss: 0.5556 - val_acc: 0.2941 - val_auc: 0.2964 - val_loss: 1.0121
# Epoch 71/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7110 - auc: 0.7705 - loss: 0.5402
# Epoch 71: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7099 - auc: 0.7698 - loss: 0.5406 - val_acc: 0.4118 - val_auc: 0.2595 - val_loss: 0.8217
# Epoch 72/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7159 - auc: 0.7545 - loss: 0.5511
# Epoch 72: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7159 - auc: 0.7545 - loss: 0.5511 - val_acc: 0.2941 - val_auc: 0.2648 - val_loss: 0.9790
# Epoch 73/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7062 - auc: 0.7546 - loss: 0.5494
# Epoch 73: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7058 - auc: 0.7552 - loss: 0.5494 - val_acc: 0.3412 - val_auc: 0.2700 - val_loss: 0.8932
# Epoch 74/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6953 - auc: 0.7493 - loss: 0.5567
# Epoch 74: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6954 - auc: 0.7495 - loss: 0.5565 - val_acc: 0.4471 - val_auc: 0.2542 - val_loss: 0.8171
# Epoch 75/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7140 - auc: 0.7728 - loss: 0.5377
# Epoch 75: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7140 - auc: 0.7729 - loss: 0.5377 - val_acc: 0.2000 - val_auc: 0.3428 - val_loss: 1.3259
# Epoch 76/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6894 - auc: 0.7698 - loss: 0.5512
# Epoch 76: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6892 - auc: 0.7686 - loss: 0.5518 - val_acc: 0.3059 - val_auc: 0.2848 - val_loss: 0.9598
# Epoch 77/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6804 - auc: 0.7283 - loss: 0.5657
# Epoch 77: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6804 - auc: 0.7284 - loss: 0.5657 - val_acc: 0.4000 - val_auc: 0.2679 - val_loss: 0.8023
# Epoch 78/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7128 - auc: 0.7701 - loss: 0.5369
# Epoch 78: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7134 - auc: 0.7707 - loss: 0.5365 - val_acc: 0.2706 - val_auc: 0.3112 - val_loss: 1.2472
# Epoch 79/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7259 - auc: 0.7699 - loss: 0.5438
# Epoch 79: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7258 - auc: 0.7700 - loss: 0.5437 - val_acc: 0.4706 - val_auc: 0.2627 - val_loss: 0.7901
# Epoch 80/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7103 - auc: 0.7526 - loss: 0.5549
# Epoch 80: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7104 - auc: 0.7527 - loss: 0.5549 - val_acc: 0.3765 - val_auc: 0.2595 - val_loss: 0.8160
# Epoch 81/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7203 - auc: 0.7832 - loss: 0.5344
# Epoch 81: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7198 - auc: 0.7823 - loss: 0.5349 - val_acc: 0.3059 - val_auc: 0.2922 - val_loss: 1.0425
# Epoch 82/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7183 - auc: 0.7743 - loss: 0.5381
# Epoch 82: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7177 - auc: 0.7739 - loss: 0.5384 - val_acc: 0.3059 - val_auc: 0.2658 - val_loss: 0.8903
# Epoch 83/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6963 - auc: 0.7512 - loss: 0.5488
# Epoch 83: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6974 - auc: 0.7523 - loss: 0.5484 - val_acc: 0.3412 - val_auc: 0.2859 - val_loss: 0.8648
# Epoch 84/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7193 - auc: 0.7834 - loss: 0.5337
# Epoch 84: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7189 - auc: 0.7835 - loss: 0.5333 - val_acc: 0.3059 - val_auc: 0.2711 - val_loss: 0.8997
# Epoch 85/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7088 - auc: 0.7841 - loss: 0.5260
# Epoch 85: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7089 - auc: 0.7842 - loss: 0.5259 - val_acc: 0.2824 - val_auc: 0.2806 - val_loss: 0.9662
# Epoch 86/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7368 - auc: 0.7747 - loss: 0.5376
# Epoch 86: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7369 - auc: 0.7751 - loss: 0.5372 - val_acc: 0.2706 - val_auc: 0.4135 - val_loss: 1.2800
# Epoch 87/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7111 - auc: 0.7810 - loss: 0.5262
# Epoch 87: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7106 - auc: 0.7801 - loss: 0.5271 - val_acc: 0.4941 - val_auc: 0.2458 - val_loss: 0.7161
# Epoch 88/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7288 - auc: 0.7554 - loss: 0.5498
# Epoch 88: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7286 - auc: 0.7564 - loss: 0.5491 - val_acc: 0.4941 - val_auc: 0.2542 - val_loss: 0.7225
# Epoch 89/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7223 - auc: 0.7582 - loss: 0.5456
# Epoch 89: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7223 - auc: 0.7586 - loss: 0.5453 - val_acc: 0.2118 - val_auc: 0.3291 - val_loss: 1.4426
# Epoch 90/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6885 - auc: 0.7702 - loss: 0.5381
# Epoch 90: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6892 - auc: 0.7705 - loss: 0.5379 - val_acc: 0.3412 - val_auc: 0.3186 - val_loss: 0.9426
# Epoch 91/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7170 - auc: 0.7890 - loss: 0.5139
# Epoch 91: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7170 - auc: 0.7891 - loss: 0.5140 - val_acc: 0.3412 - val_auc: 0.3070 - val_loss: 0.9661
# Epoch 92/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7886 - auc: 0.8415 - loss: 0.4743
# Epoch 92: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7858 - auc: 0.8390 - loss: 0.4766 - val_acc: 0.4118 - val_auc: 0.2405 - val_loss: 0.8623
# Epoch 93/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7232 - auc: 0.7713 - loss: 0.5530
# Epoch 93: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7232 - auc: 0.7715 - loss: 0.5524 - val_acc: 0.2824 - val_auc: 0.2627 - val_loss: 0.9837
# Epoch 94/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6973 - auc: 0.7613 - loss: 0.5471
# Epoch 94: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6976 - auc: 0.7616 - loss: 0.5469 - val_acc: 0.3176 - val_auc: 0.2890 - val_loss: 1.0892
# Epoch 95/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7336 - auc: 0.7688 - loss: 0.5318
# Epoch 95: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7316 - auc: 0.7683 - loss: 0.5326 - val_acc: 0.3294 - val_auc: 0.2616 - val_loss: 0.8962
# Epoch 96/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7611 - auc: 0.8180 - loss: 0.4886
# Epoch 96: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7597 - auc: 0.8165 - loss: 0.4904 - val_acc: 0.3412 - val_auc: 0.2584 - val_loss: 0.9256
# Epoch 97/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6875 - auc: 0.7663 - loss: 0.5575
# Epoch 97: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6900 - auc: 0.7678 - loss: 0.5556 - val_acc: 0.3059 - val_auc: 0.2627 - val_loss: 1.1349
# Epoch 98/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6969 - auc: 0.7528 - loss: 0.5459
# Epoch 98: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6975 - auc: 0.7536 - loss: 0.5457 - val_acc: 0.3294 - val_auc: 0.2753 - val_loss: 0.8818
# Epoch 99/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7234 - auc: 0.7560 - loss: 0.5508
# Epoch 99: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7235 - auc: 0.7567 - loss: 0.5504 - val_acc: 0.5882 - val_auc: 0.2416 - val_loss: 0.6653
# Epoch 100/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7338 - auc: 0.7866 - loss: 0.5230
# Epoch 100: val_loss did not improve from 0.31756
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7334 - auc: 0.7867 - loss: 0.5231 - val_acc: 0.2941 - val_auc: 0.2722 - val_loss: 0.9423
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 1 | TEST@0.5  ACC=0.6565 | PREC=0.0000 | REC=0.0000 | F1=0.0000 | AUC=0.8302 | SPEC=1.0000 | n=131
# Fold 1 | TEST@J    ACC=0.7863 | PREC=0.6545 | REC=0.8000 | F1=0.7200 | AUC=0.8302 | SPEC=0.7791 | thr=0.2276, J=0.5791
# Confusion matrix (@0.5):
#  [[86  0]
#  [45  0]]
# Classification report (@0.5):
#                precision    recall  f1-score   support
#
#            0      0.656     1.000     0.793        86
#            1      0.000     0.000     0.000        45
#
#     accuracy                          0.656       131
#    macro avg      0.328     0.500     0.396       131
# weighted avg      0.431     0.656     0.520       131
#
#
# --- Fold 2/7 ---
#  train | ids:   32 | files:   763 | pos files:  322 | neg files:  441
#    val | ids:    4 | files:   149 | pos files:    4 | neg files:  145
#   test | ids:    6 | files:   112 | pos files:   45 | neg files:   67
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.4919 - auc: 0.4892 - loss: 0.7009
# Epoch 1: val_loss improved from inf to 0.78637, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - acc: 0.4925 - auc: 0.4894 - loss: 0.7007 - val_acc: 0.0268 - val_auc: 0.0138 - val_loss: 0.7864
# Epoch 2/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5210 - auc: 0.4968 - loss: 0.6863
# Epoch 2: val_loss improved from 0.78637 to 0.58805, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5220 - auc: 0.4997 - loss: 0.6859 - val_acc: 0.7517 - val_auc: 0.9448 - val_loss: 0.5881
# Epoch 3/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5886 - auc: 0.5978 - loss: 0.6676
# Epoch 3: val_loss improved from 0.58805 to 0.42476, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5889 - auc: 0.5986 - loss: 0.6673 - val_acc: 0.9463 - val_auc: 0.9655 - val_loss: 0.4248
# Epoch 4/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5920 - auc: 0.6403 - loss: 0.6618
# Epoch 4: val_loss improved from 0.42476 to 0.29952, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5929 - auc: 0.6402 - loss: 0.6615 - val_acc: 0.9732 - val_auc: 0.9690 - val_loss: 0.2995
# Epoch 5/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6194 - auc: 0.6261 - loss: 0.6573
# Epoch 5: val_loss improved from 0.29952 to 0.27667, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6190 - auc: 0.6261 - loss: 0.6569 - val_acc: 0.9664 - val_auc: 0.9138 - val_loss: 0.2767
# Epoch 6/100
# 238/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6009 - auc: 0.6283 - loss: 0.6647
# Epoch 6: val_loss did not improve from 0.27667
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6023 - auc: 0.6292 - loss: 0.6632 - val_acc: 0.8591 - val_auc: 0.7414 - val_loss: 0.3892
# Epoch 7/100
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6215 - auc: 0.6480 - loss: 0.6492
# Epoch 7: val_loss did not improve from 0.27667
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6214 - auc: 0.6480 - loss: 0.6492 - val_acc: 0.8926 - val_auc: 0.6966 - val_loss: 0.3643
# Epoch 8/100
# 238/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6488 - auc: 0.6680 - loss: 0.6379
# Epoch 8: val_loss did not improve from 0.27667
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6481 - auc: 0.6670 - loss: 0.6382 - val_acc: 0.9664 - val_auc: 0.8155 - val_loss: 0.2793
# Epoch 9/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5971 - auc: 0.6160 - loss: 0.6725
# Epoch 9: val_loss improved from 0.27667 to 0.27207, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5974 - auc: 0.6164 - loss: 0.6721 - val_acc: 0.9664 - val_auc: 0.8957 - val_loss: 0.2721
# Epoch 10/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6271 - auc: 0.6695 - loss: 0.6261
# Epoch 10: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6274 - auc: 0.6698 - loss: 0.6262 - val_acc: 0.8658 - val_auc: 0.8224 - val_loss: 0.3655
# Epoch 11/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6427 - auc: 0.6598 - loss: 0.6375
# Epoch 11: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6420 - auc: 0.6594 - loss: 0.6377 - val_acc: 0.8389 - val_auc: 0.6707 - val_loss: 0.4021
# Epoch 12/100
# 240/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5935 - auc: 0.6339 - loss: 0.6503
# Epoch 12: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5953 - auc: 0.6364 - loss: 0.6489 - val_acc: 0.9060 - val_auc: 0.7216 - val_loss: 0.3313
# Epoch 13/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6483 - auc: 0.6688 - loss: 0.6377
# Epoch 13: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6478 - auc: 0.6681 - loss: 0.6380 - val_acc: 0.8859 - val_auc: 0.7052 - val_loss: 0.3489
# Epoch 14/100
# 238/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6620 - auc: 0.6852 - loss: 0.6221
# Epoch 14: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6596 - auc: 0.6837 - loss: 0.6230 - val_acc: 0.9195 - val_auc: 0.7310 - val_loss: 0.3380
# Epoch 15/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6052 - auc: 0.6293 - loss: 0.6475
# Epoch 15: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6055 - auc: 0.6298 - loss: 0.6474 - val_acc: 0.8859 - val_auc: 0.7259 - val_loss: 0.3698
# Epoch 16/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6546 - auc: 0.6967 - loss: 0.6216
# Epoch 16: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6542 - auc: 0.6962 - loss: 0.6219 - val_acc: 0.8523 - val_auc: 0.7293 - val_loss: 0.3974
# Epoch 17/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6097 - auc: 0.6193 - loss: 0.6596
# Epoch 17: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6098 - auc: 0.6197 - loss: 0.6593 - val_acc: 0.8792 - val_auc: 0.7086 - val_loss: 0.3620
# Epoch 18/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6349 - auc: 0.6685 - loss: 0.6397
# Epoch 18: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6351 - auc: 0.6687 - loss: 0.6394 - val_acc: 0.9195 - val_auc: 0.6483 - val_loss: 0.3122
# Epoch 19/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6370 - auc: 0.6974 - loss: 0.6227
# Epoch 19: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6375 - auc: 0.6971 - loss: 0.6227 - val_acc: 0.9060 - val_auc: 0.7414 - val_loss: 0.3067
# Epoch 20/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6248 - auc: 0.7011 - loss: 0.6250
# Epoch 20: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6251 - auc: 0.7000 - loss: 0.6250 - val_acc: 0.8188 - val_auc: 0.7698 - val_loss: 0.3952
# Epoch 21/100
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6158 - auc: 0.6416 - loss: 0.6499
# Epoch 21: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6164 - auc: 0.6421 - loss: 0.6496 - val_acc: 0.8591 - val_auc: 0.5379 - val_loss: 0.3837
# Epoch 22/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5809 - auc: 0.6368 - loss: 0.6498
# Epoch 22: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5819 - auc: 0.6377 - loss: 0.6491 - val_acc: 0.9128 - val_auc: 0.5664 - val_loss: 0.3329
# Epoch 23/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6179 - auc: 0.6466 - loss: 0.6527
# Epoch 23: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6187 - auc: 0.6476 - loss: 0.6515 - val_acc: 0.9128 - val_auc: 0.5362 - val_loss: 0.3231
# Epoch 24/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6477 - auc: 0.6803 - loss: 0.6126
# Epoch 24: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6476 - auc: 0.6799 - loss: 0.6131 - val_acc: 0.8255 - val_auc: 0.6052 - val_loss: 0.4234
# Epoch 25/100
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6259 - auc: 0.6419 - loss: 0.6515
# Epoch 25: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6259 - auc: 0.6420 - loss: 0.6514 - val_acc: 0.8121 - val_auc: 0.7690 - val_loss: 0.4096
# Epoch 26/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6452 - auc: 0.6905 - loss: 0.6208
# Epoch 26: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6452 - auc: 0.6905 - loss: 0.6208 - val_acc: 0.7651 - val_auc: 0.6009 - val_loss: 0.4392
# Epoch 27/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6334 - auc: 0.6709 - loss: 0.6240
# Epoch 27: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6333 - auc: 0.6709 - loss: 0.6242 - val_acc: 0.7919 - val_auc: 0.5388 - val_loss: 0.4454
# Epoch 28/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6169 - auc: 0.6737 - loss: 0.6291
# Epoch 28: val_loss did not improve from 0.27207
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6169 - auc: 0.6727 - loss: 0.6295 - val_acc: 0.8725 - val_auc: 0.6164 - val_loss: 0.3544
# Epoch 29/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6042 - auc: 0.6910 - loss: 0.6236
# Epoch 29: val_loss improved from 0.27207 to 0.26332, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6055 - auc: 0.6902 - loss: 0.6238 - val_acc: 0.9732 - val_auc: 0.6043 - val_loss: 0.2633
# Epoch 30/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6352 - auc: 0.6309 - loss: 0.6433
# Epoch 30: val_loss did not improve from 0.26332
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6354 - auc: 0.6326 - loss: 0.6428 - val_acc: 0.7718 - val_auc: 0.5784 - val_loss: 0.4505
# Epoch 31/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6191 - auc: 0.6604 - loss: 0.6291
# Epoch 31: val_loss did not improve from 0.26332
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6196 - auc: 0.6606 - loss: 0.6290 - val_acc: 0.9597 - val_auc: 0.5862 - val_loss: 0.2895
# Epoch 32/100
# 242/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6190 - auc: 0.6664 - loss: 0.6317
# Epoch 32: val_loss did not improve from 0.26332
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6193 - auc: 0.6661 - loss: 0.6317 - val_acc: 0.9128 - val_auc: 0.5440 - val_loss: 0.3517
# Epoch 33/100
# 248/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6090 - auc: 0.6400 - loss: 0.6457
# Epoch 33: val_loss did not improve from 0.26332
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6093 - auc: 0.6408 - loss: 0.6452 - val_acc: 0.8188 - val_auc: 0.7259 - val_loss: 0.4057
# Epoch 34/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6142 - auc: 0.6660 - loss: 0.6316
# Epoch 34: val_loss did not improve from 0.26332
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6152 - auc: 0.6671 - loss: 0.6309 - val_acc: 0.8054 - val_auc: 0.6802 - val_loss: 0.3908
# Epoch 35/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6640 - auc: 0.7051 - loss: 0.6035
# Epoch 35: val_loss did not improve from 0.26332
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6634 - auc: 0.7052 - loss: 0.6038 - val_acc: 0.7181 - val_auc: 0.8060 - val_loss: 0.4932
# Epoch 36/100
# 248/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6339 - auc: 0.6677 - loss: 0.6390
# Epoch 36: val_loss did not improve from 0.26332
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6346 - auc: 0.6686 - loss: 0.6383 - val_acc: 0.7718 - val_auc: 0.6414 - val_loss: 0.4419
# Epoch 37/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6713 - auc: 0.7043 - loss: 0.6092
# Epoch 37: val_loss did not improve from 0.26332
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6707 - auc: 0.7042 - loss: 0.6093 - val_acc: 0.6510 - val_auc: 0.8302 - val_loss: 0.6837
# Epoch 38/100
# 238/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6785 - auc: 0.7087 - loss: 0.6051
# Epoch 38: val_loss improved from 0.26332 to 0.24337, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6772 - auc: 0.7066 - loss: 0.6062 - val_acc: 0.9597 - val_auc: 0.8517 - val_loss: 0.2434
# Epoch 39/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6745 - auc: 0.6887 - loss: 0.5976
# Epoch 39: val_loss did not improve from 0.24337
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6718 - auc: 0.6881 - loss: 0.5994 - val_acc: 0.7181 - val_auc: 0.7888 - val_loss: 0.6029
# Epoch 40/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6903 - auc: 0.7061 - loss: 0.6092
# Epoch 40: val_loss did not improve from 0.24337
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6889 - auc: 0.7061 - loss: 0.6093 - val_acc: 0.9396 - val_auc: 0.5586 - val_loss: 0.2582
# Epoch 41/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6053 - auc: 0.6562 - loss: 0.6385
# Epoch 41: val_loss did not improve from 0.24337
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6058 - auc: 0.6566 - loss: 0.6383 - val_acc: 0.7852 - val_auc: 0.8379 - val_loss: 0.4737
# Epoch 42/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6244 - auc: 0.6703 - loss: 0.6199
# Epoch 42: val_loss did not improve from 0.24337
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6250 - auc: 0.6709 - loss: 0.6198 - val_acc: 0.8859 - val_auc: 0.6629 - val_loss: 0.3600
# Epoch 43/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6409 - auc: 0.6650 - loss: 0.6293
# Epoch 43: val_loss did not improve from 0.24337
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6412 - auc: 0.6656 - loss: 0.6291 - val_acc: 0.8792 - val_auc: 0.6466 - val_loss: 0.3725
# Epoch 44/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6510 - auc: 0.6973 - loss: 0.6172
# Epoch 44: val_loss did not improve from 0.24337
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6505 - auc: 0.6970 - loss: 0.6173 - val_acc: 0.7718 - val_auc: 0.6983 - val_loss: 0.5214
# Epoch 45/100
# ...
# Epoch 59: val_loss improved from 0.46111 to 0.45420, saving model to best_fold_07.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6398 - auc: 0.7090 - loss: 0.5884 - val_acc: 0.7568 - val_auc: 0.7124 - val_loss: 0.4542
# Epoch 60/100
# 281/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6804 - auc: 0.7165 - loss: 0.5802
# Epoch 60: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6801 - auc: 0.7165 - loss: 0.5802 - val_acc: 0.4865 - val_auc: 0.7366 - val_loss: 0.8777
# Epoch 61/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6395 - auc: 0.6908 - loss: 0.5982
# Epoch 61: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6395 - auc: 0.6909 - loss: 0.5981 - val_acc: 0.6757 - val_auc: 0.6882 - val_loss: 0.5925
# Epoch 62/100
# 271/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6643 - auc: 0.7337 - loss: 0.5678
# Epoch 62: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6645 - auc: 0.7340 - loss: 0.5679 - val_acc: 0.5135 - val_auc: 0.7419 - val_loss: 0.7933
# Epoch 63/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6458 - auc: 0.7124 - loss: 0.5823
# Epoch 63: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6456 - auc: 0.7120 - loss: 0.5825 - val_acc: 0.6757 - val_auc: 0.7392 - val_loss: 0.6104
# Epoch 64/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6766 - auc: 0.7436 - loss: 0.5777
# Epoch 64: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6766 - auc: 0.7436 - loss: 0.5777 - val_acc: 0.7027 - val_auc: 0.7339 - val_loss: 0.5492
# Epoch 65/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6373 - auc: 0.6930 - loss: 0.5881
# Epoch 65: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6378 - auc: 0.6937 - loss: 0.5880 - val_acc: 0.7568 - val_auc: 0.7177 - val_loss: 0.5329
# Epoch 66/100
# 269/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6823 - auc: 0.7525 - loss: 0.5706
# Epoch 66: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6822 - auc: 0.7518 - loss: 0.5706 - val_acc: 0.7568 - val_auc: 0.6586 - val_loss: 0.4721
# Epoch 67/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6760 - auc: 0.7178 - loss: 0.5780
# Epoch 67: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6756 - auc: 0.7182 - loss: 0.5780 - val_acc: 0.5135 - val_auc: 0.6909 - val_loss: 0.8488
# Epoch 68/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6454 - auc: 0.6898 - loss: 0.5982
# Epoch 68: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6463 - auc: 0.6909 - loss: 0.5975 - val_acc: 0.5135 - val_auc: 0.7231 - val_loss: 0.7874
# Epoch 69/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6890 - auc: 0.7365 - loss: 0.5729
# Epoch 69: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6886 - auc: 0.7361 - loss: 0.5732 - val_acc: 0.6757 - val_auc: 0.6962 - val_loss: 0.5840
# Epoch 70/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6341 - auc: 0.7008 - loss: 0.5924
# Epoch 70: val_loss did not improve from 0.45420
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6342 - auc: 0.7008 - loss: 0.5924 - val_acc: 0.6757 - val_auc: 0.6828 - val_loss: 0.5818
# Epoch 71/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6337 - auc: 0.6989 - loss: 0.6001
# Epoch 71: val_loss improved from 0.45420 to 0.44161, saving model to best_fold_07.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6339 - auc: 0.6990 - loss: 0.6000 - val_acc: 0.7838 - val_auc: 0.7016 - val_loss: 0.4416
# Epoch 72/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6346 - auc: 0.6982 - loss: 0.6057
# Epoch 72: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6346 - auc: 0.6982 - loss: 0.6056 - val_acc: 0.6486 - val_auc: 0.7043 - val_loss: 0.5230
# Epoch 73/100
# 279/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6817 - auc: 0.7423 - loss: 0.5657
# Epoch 73: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6814 - auc: 0.7418 - loss: 0.5660 - val_acc: 0.7568 - val_auc: 0.7043 - val_loss: 0.5074
# Epoch 74/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6921 - auc: 0.7371 - loss: 0.5586
# Epoch 74: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6921 - auc: 0.7372 - loss: 0.5586 - val_acc: 0.6486 - val_auc: 0.6452 - val_loss: 0.6758
# Epoch 75/100
# 268/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6634 - auc: 0.7486 - loss: 0.5534
# Epoch 75: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6627 - auc: 0.7472 - loss: 0.5549 - val_acc: 0.7297 - val_auc: 0.7258 - val_loss: 0.5418
# Epoch 76/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6566 - auc: 0.7286 - loss: 0.5681
# Epoch 76: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6568 - auc: 0.7287 - loss: 0.5680 - val_acc: 0.5135 - val_auc: 0.7070 - val_loss: 0.7986
# Epoch 77/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6526 - auc: 0.7001 - loss: 0.6022
# Epoch 77: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6527 - auc: 0.7003 - loss: 0.6020 - val_acc: 0.8108 - val_auc: 0.6828 - val_loss: 0.4418
# Epoch 78/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6594 - auc: 0.7331 - loss: 0.5757
# Epoch 78: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6596 - auc: 0.7333 - loss: 0.5756 - val_acc: 0.6486 - val_auc: 0.7258 - val_loss: 0.6659
# Epoch 79/100
# 272/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6289 - auc: 0.6645 - loss: 0.6073
# Epoch 79: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6307 - auc: 0.6673 - loss: 0.6060 - val_acc: 0.5135 - val_auc: 0.6935 - val_loss: 0.8744
# Epoch 80/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6784 - auc: 0.7430 - loss: 0.5719
# Epoch 80: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6784 - auc: 0.7430 - loss: 0.5719 - val_acc: 0.6486 - val_auc: 0.6801 - val_loss: 0.6472
# Epoch 81/100
# 269/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6523 - auc: 0.6950 - loss: 0.6017
# Epoch 81: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6531 - auc: 0.6972 - loss: 0.5999 - val_acc: 0.4865 - val_auc: 0.7366 - val_loss: 0.9894
# Epoch 82/100
# 269/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6662 - auc: 0.7061 - loss: 0.5888
# Epoch 82: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6679 - auc: 0.7087 - loss: 0.5872 - val_acc: 0.5676 - val_auc: 0.6935 - val_loss: 0.7929
# Epoch 83/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6751 - auc: 0.7374 - loss: 0.5574
# Epoch 83: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6748 - auc: 0.7372 - loss: 0.5578 - val_acc: 0.6486 - val_auc: 0.6855 - val_loss: 0.6373
# Epoch 84/100
# 272/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6588 - auc: 0.7342 - loss: 0.5687
# Epoch 84: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6588 - auc: 0.7341 - loss: 0.5689 - val_acc: 0.6486 - val_auc: 0.6747 - val_loss: 0.6675
# Epoch 85/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6242 - auc: 0.7101 - loss: 0.5924
# Epoch 85: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6242 - auc: 0.7101 - loss: 0.5924 - val_acc: 0.6757 - val_auc: 0.7016 - val_loss: 0.5766
# Epoch 86/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6609 - auc: 0.7518 - loss: 0.5647
# Epoch 86: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6609 - auc: 0.7518 - loss: 0.5646 - val_acc: 0.7297 - val_auc: 0.6694 - val_loss: 0.5066
# Epoch 87/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6777 - auc: 0.7560 - loss: 0.5576
# Epoch 87: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6776 - auc: 0.7559 - loss: 0.5577 - val_acc: 0.6486 - val_auc: 0.6398 - val_loss: 0.6479
# Epoch 88/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6888 - auc: 0.7535 - loss: 0.5610
# Epoch 88: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6886 - auc: 0.7533 - loss: 0.5611 - val_acc: 0.5135 - val_auc: 0.6290 - val_loss: 0.9533
# Epoch 89/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6940 - auc: 0.7326 - loss: 0.5641
# Epoch 89: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6939 - auc: 0.7326 - loss: 0.5641 - val_acc: 0.5135 - val_auc: 0.6586 - val_loss: 0.9292
# Epoch 90/100
# 269/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6883 - auc: 0.7378 - loss: 0.5693
# Epoch 90: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6877 - auc: 0.7373 - loss: 0.5698 - val_acc: 0.6486 - val_auc: 0.6855 - val_loss: 0.6194
# Epoch 91/100
# 276/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7066 - auc: 0.7633 - loss: 0.5550
# Epoch 91: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7056 - auc: 0.7624 - loss: 0.5555 - val_acc: 0.7568 - val_auc: 0.6532 - val_loss: 0.4527
# Epoch 92/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6828 - auc: 0.7265 - loss: 0.5820
# Epoch 92: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6821 - auc: 0.7260 - loss: 0.5821 - val_acc: 0.8108 - val_auc: 0.6747 - val_loss: 0.4430
# Epoch 93/100
# 272/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6797 - auc: 0.7527 - loss: 0.5735
# Epoch 93: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6795 - auc: 0.7519 - loss: 0.5737 - val_acc: 0.7027 - val_auc: 0.6828 - val_loss: 0.5131
# Epoch 94/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6403 - auc: 0.7103 - loss: 0.5898
# Epoch 94: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6416 - auc: 0.7114 - loss: 0.5889 - val_acc: 0.6757 - val_auc: 0.7366 - val_loss: 0.6036
# Epoch 95/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6428 - auc: 0.7279 - loss: 0.5750
# Epoch 95: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6431 - auc: 0.7280 - loss: 0.5750 - val_acc: 0.5405 - val_auc: 0.6989 - val_loss: 0.7535
# Epoch 96/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6808 - auc: 0.7381 - loss: 0.5663
# Epoch 96: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6807 - auc: 0.7381 - loss: 0.5664 - val_acc: 0.5676 - val_auc: 0.7446 - val_loss: 0.7177
# Epoch 97/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6746 - auc: 0.7170 - loss: 0.5813
# Epoch 97: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6746 - auc: 0.7171 - loss: 0.5813 - val_acc: 0.6757 - val_auc: 0.7339 - val_loss: 0.6171
# Epoch 98/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6707 - auc: 0.7152 - loss: 0.5820
# Epoch 98: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6708 - auc: 0.7152 - loss: 0.5820 - val_acc: 0.6486 - val_auc: 0.7366 - val_loss: 0.6308
# Epoch 99/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6660 - auc: 0.7119 - loss: 0.5773
# Epoch 99: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6660 - auc: 0.7119 - loss: 0.5774 - val_acc: 0.6757 - val_auc: 0.7097 - val_loss: 0.5553
# Epoch 100/100
# 267/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6563 - auc: 0.7202 - loss: 0.5768
# Epoch 100: val_loss did not improve from 0.44161
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6563 - auc: 0.7203 - loss: 0.5770 - val_acc: 0.6486 - val_auc: 0.6613 - val_loss: 0.6614
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 7 | TEST@0.5  ACC=0.9323 | PREC=0.0000 | REC=0.0000 | F1=0.0000 | AUC=0.9023 | SPEC=1.0000 | n=133
# Fold 7 | TEST@J    ACC=0.8647 | PREC=0.3200 | REC=0.8889 | F1=0.4706 | AUC=0.9023 | SPEC=0.8629 | thr=0.2531, J=0.7518
# Confusion matrix (@0.5):
#  [[124   0]
#  [  9   0]]
# Classification report (@0.5):
#                precision    recall  f1-score   support
#
#            0      0.932     1.000     0.965       124
#            1      0.000     0.000     0.000         9
#
#     accuracy                          0.932       133
#    macro avg      0.466     0.500     0.482       133
# weighted avg      0.869     0.932     0.900       133
#
#
# === TEST metrics per fold — threshold 0.5 ===
# AUC : [np.float64(0.8302), np.float64(0.7274), np.float64(0.6971), np.float64(0.5454), np.float64(0.0835), np.float64(0.6863), np.float64(0.9023)]
# ACC : [0.6565, 0.6071, 0.6449, 0.4934, 0.3571, 0.4076, 0.9323]
# PREC: [0.0, 1.0, 0.5877, 0.0606, 0.0159, 0.8333, 0.0]
# REC : [0.0, 0.0222, 0.971, 0.0233, 0.05, 0.0515, 0.0]
# SPEC: [np.float64(1.0), np.float64(1.0), np.float64(0.3188), np.float64(0.7801), np.float64(0.4151), np.float64(0.9833), np.float64(1.0)]
# F1  : [0.0, 0.0435, 0.7322, 0.0336, 0.0241, 0.0971, 0.0]
#
# === TEST metrics per fold — Youden-J (on TEST) ===
# AUC@J : [np.float64(0.8302), np.float64(0.7274), np.float64(0.6971), np.float64(0.5454), np.float64(0.0835), np.float64(0.6863), np.float64(0.9023)]
# ACC@J : [0.7863, 0.75, 0.6522, 0.6079, 0.1905, 0.8089, 0.8647]
# PREC@J: [0.6545, 0.7742, 0.5929, 0.4909, 0.1639, 0.7638, 0.32]
# REC@J : [0.8, 0.5333, 0.971, 0.9419, 1.0, 1.0, 0.8889]
# SPEC@J: [np.float64(0.7791), np.float64(0.8955), np.float64(0.3333), np.float64(0.4043), np.float64(0.0377), np.float64(0.5), np.float64(0.8629)]
# F1@J  : [0.72, 0.6316, 0.7363, 0.6454, 0.2817, 0.8661, 0.4706]
#
# === Mean ± SD across folds (TEST) — 0.5 ===
#          AUC: 0.6389 ± 0.2498
#          ACC: 0.5856 ± 0.1779
#    Precision: 0.3568 ± 0.4058
#       Recall: 0.1597 ± 0.3318
#  Specificity: 0.7853 ± 0.2757
#           F1: 0.1329 ± 0.2466
#
# === Mean ± SD across folds (TEST) — Youden-J (on TEST) ===
#        AUC@J: 0.6389 ± 0.2498
#        ACC@J: 0.6658 ± 0.2108
#  Precision@J: 0.5372 ± 0.2115
#     Recall@J: 0.8764 ± 0.1547
# Specificity@J: 0.5447 ± 0.2934
#         F1@J: 0.6217 ± 0.1779
#
# Saved TEST-only per-fold metrics to cv7_img_fold_metrics.csv
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
