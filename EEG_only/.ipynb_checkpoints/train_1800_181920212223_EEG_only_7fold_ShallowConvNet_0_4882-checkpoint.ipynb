# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.transforms as transforms
import os
import argparse
from pathlib import Path
import re
import random
import math
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
from torch.utils.data import Dataset, DataLoader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### EEGNet-8,2

# %%
from pathlib import Path
import re, random, math, os
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    accuracy_score, roc_auc_score, classification_report, confusion_matrix,
    precision_score, recall_score, f1_score, roc_curve,
)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.constraints import max_norm   # used in ShallowConvNet

# =========================
# Config
# =========================
SPLIT_DIR = r"/content/drive/MyDrive/CD/patient_data_clean_1800s_nozero_181920212223_in3days_v2"
POS_PATIENTS = {1, 2, 16, 19, 21, 22, 25, 37, 39, 43, 44, 47, 50, 56, 58, 62, 65, 66, 73, 78}

BATCH_SIZE       = 3
EPOCHS           = 100
LR               = 1e-4
SEED             = 1
K_FOLDS          = 7
BEST_MODEL_TPL   = "best_fold_{:02d}.h5"

# not used for dedup height; kept for reference
TARGET_H = 300

# =========================
# Noise config (train-time augmentation only)
# =========================
TRAIN_ADD_GAUSS_NOISE = True     # training generator only
TRAIN_NOISE_FRAC      = 0.10
TRAIN_NOISE_PROB      = 1.0
EPS_STD               = 1e-8

# =========================
# Repro
# =========================
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
for g in tf.config.list_physical_devices('GPU'):
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception:
        pass

# =========================
# Helpers for ID/labels
# =========================
PATIENT_NUM_RX = re.compile(r'^ID(\d+)')

def patient_num_from_path(pathlike):
    stem = Path(pathlike).stem
    m = PATIENT_NUM_RX.match(stem)
    return int(m.group(1)) if m else None

def label_for_file(p: Path) -> int:
    pnum = patient_num_from_path(p)
    return 1 if (pnum is not None and pnum in POS_PATIENTS) else 0

# =========================
# List files (all) & labels by patient ID
# =========================
split_dir = Path(SPLIT_DIR)
all_csvs = sorted(split_dir.glob("*.csv"))
if not all_csvs:
    raise FileNotFoundError(f"No CSV found in {SPLIT_DIR}")

id_to_files = {}
for f in all_csvs:
    pid = patient_num_from_path(f)
    if pid is None or pid == 12:    # exclude ID 12
        continue
    id_to_files.setdefault(pid, []).append(f)

all_ids = sorted(id_to_files.keys())
id_labels = np.array([1 if pid in POS_PATIENTS else 0 for pid in all_ids], dtype=int)
print("Total IDs:", len(all_ids), "| Pos IDs:", id_labels.sum(), "| Neg IDs:", (1 - id_labels).sum())

# =========================
# Column handling
# =========================
def _drop_time_cols(df: pd.DataFrame) -> pd.DataFrame:
    time_like = [c for c in df.columns if isinstance(c, str) and c.strip().lower() == "time"]
    return df.drop(columns=time_like, errors="ignore")

def _to_numeric_df(df: pd.DataFrame) -> pd.DataFrame:
    df = _drop_time_cols(df)
    return df.apply(pd.to_numeric, errors="coerce").fillna(0.0)

def _pad_crop_2d(x: np.ndarray, H: int, W: int) -> np.ndarray:
    h, w = x.shape
    if h < H:
        pad = np.zeros((H, w), dtype=x.dtype); pad[:h, :] = x; x = pad; h = H
    elif h > H:
        x = x[:H, :]; h = H
    if w < W:
        pad = np.zeros((h, W), dtype=x.dtype); pad[:, :w] = x; x = pad
    elif w > W:
        x = x[:, :W]
    return x

def _infer_target_width(example_csv: Path) -> int:
    df = pd.read_csv(example_csv)
    df2 = _to_numeric_df(df)
    return df2.shape[1]

# Fix width/height ONCE using the whole dataset (so all folds match)
TARGET_W = _infer_target_width(all_csvs[0])
print(f"TARGET_W={TARGET_W} (non-Time columns)")

def _dedupe_consecutive_rows(mat: np.ndarray) -> np.ndarray:
    if mat.size == 0:
        return mat
    if mat.ndim == 1:
        mat = mat[:, None]
    if mat.shape[0] == 1:
        return mat
    diffs = np.any(mat[1:] != mat[:-1], axis=1)
    keep = np.concatenate(([True], diffs))
    return mat[keep]

def _dedup_len_from_csv(p: Path) -> int:
    df = pd.read_csv(p)
    mat = _to_numeric_df(df).to_numpy(dtype=np.float32)
    mat_d = _dedupe_consecutive_rows(mat)
    return int(mat_d.shape[0])

TARGET_H_DEDUP = max(_dedup_len_from_csv(f) for f in all_csvs)
if TARGET_H_DEDUP <= 0:
    raise RuntimeError("After de-dup, zero-length found in data.")
print(f"Fixed input height after de-dup (all IDs): H={TARGET_H_DEDUP}")

def load_csv_as_image_dedup(csv_path: Path) -> np.ndarray:
    df  = pd.read_csv(csv_path)
    df2 = _to_numeric_df(df)
    mat = df2.to_numpy(dtype=np.float32)      # shape ~ (Samples, Chans)
    if mat.ndim != 2:
        mat = mat.reshape(mat.shape[0], -1) if mat.ndim > 2 else mat
    mat = _dedupe_consecutive_rows(mat)
    if mat.shape[0] == 0:
        mat = np.zeros((1, TARGET_W), dtype=np.float32)
    mat = _pad_crop_2d(mat, TARGET_H_DEDUP, TARGET_W)
    img = np.expand_dims(mat, axis=-1).astype(np.float32)  # (Samples, Chans, 1)
    if img.shape != (TARGET_H_DEDUP, TARGET_W, 1):
        raise ValueError(f"loader produced {img.shape}, expected {(TARGET_H_DEDUP, TARGET_W, 1)} for {csv_path}")
    return img

# cache
CACHE_DEDUP = {}
def load_csv_as_image_cached(csv_path: Path) -> np.ndarray:
    key = ("dedup", str(csv_path))
    if key in CACHE_DEDUP:
        return CACHE_DEDUP[key]
    img = load_csv_as_image_dedup(csv_path)
    CACHE_DEDUP[key] = img
    return img

print("Normalization: NONE. De-dup: remove consecutive duplicate rows (row-wise).")

# =========================
# Keras Sequence
# =========================
class ImageSequence(keras.utils.Sequence):
    def __init__(self, files, batch_size=BATCH_SIZE, shuffle=True,
                 add_noise=False, noise_frac=TRAIN_NOISE_FRAC, noise_prob=TRAIN_NOISE_PROB):
        super().__init__()
        self.files = list(files)
        self.batch_size = int(batch_size)
        self.shuffle = shuffle
        self.add_noise = add_noise
        self.noise_frac = float(noise_frac)
        self.noise_prob = float(noise_prob)
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.files) / self.batch_size)

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.files))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __getitem__(self, idx):
        idxs = self.indexes[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch_files = [self.files[i] for i in idxs]
        B = len(batch_files)
        X = np.empty((B, TARGET_H_DEDUP, TARGET_W, 1), dtype=np.float32)  # (Samples, Chans, 1)
        y = np.empty((B,), dtype=np.int32)

        for i, f in enumerate(batch_files):
            xi = load_csv_as_image_cached(f)
            if xi.ndim == 2:
                xi = xi[..., None]
            if xi.shape != (TARGET_H_DEDUP, TARGET_W, 1):
                raise ValueError(f"Sample shape {xi.shape} for {f}; expected {(TARGET_H_DEDUP, TARGET_W, 1)}")
            X[i] = xi
            y[i] = label_for_file(f)

        if self.add_noise and self.noise_frac > 0.0 and self.noise_prob > 0.0:
            samp_std = X.reshape(B, -1).std(axis=1).astype(np.float32)
            samp_std = np.maximum(samp_std, EPS_STD).reshape(B, 1, 1, 1)
            noise = np.random.normal(0.0, 1.0, size=X.shape).astype(np.float32)
            noise *= (self.noise_frac * samp_std)
            if self.noise_prob < 1.0:
                mask = (np.random.rand(B, 1, 1, 1) < self.noise_prob).astype(np.float32)
                noise *= mask
            X = X + noise

        if X.shape[1:] != (TARGET_H_DEDUP, TARGET_W, 1):
            raise ValueError(f"Batch X has shape {X.shape}; expected (B, {TARGET_H_DEDUP}, {TARGET_W}, 1)")
        return X, y

# =========================
# Custom layers to replace Lambda (fix load_model bug)
# =========================
class SquareLayer(layers.Layer):
    def call(self, inputs):
        return tf.square(inputs)

class LogLayer(layers.Layer):
    def __init__(self, eps=1e-6, **kwargs):
        super().__init__(**kwargs)
        self.eps = eps

    def call(self, inputs):
        clipped = tf.clip_by_value(inputs, self.eps, tf.float32.max)
        return tf.math.log(clipped)

# =========================
# ShallowConvNet model (binary head)
# =========================
def build_model(samples=TARGET_H_DEDUP, chans=TARGET_W, lr=LR,
                F1=40, pool_size=75, pool_stride=15, dropout=0.5):
    """
    ShallowConvNet (Schirrmeister et al. 2017) adapted for binary classification.
    Input: (Samples, Chans, 1), internally permuted to (Chans, Samples, 1).
    """
    inputs = keras.Input(shape=(samples, chans, 1))  # (T, C, 1)

    # Permute to (Chans, Samples, 1)
    x = layers.Permute((2, 1, 3))(inputs)  # (C, T, 1)

    # Block: temporal conv then spatial filtering across channels
    x = layers.Conv2D(
        F1, (1, 25),
        padding="same",
        use_bias=False
    )(x)
    x = layers.Conv2D(
        F1, (chans, 1),
        padding="valid",
        use_bias=False,
        kernel_constraint=max_norm(1.)
    )(x)
    x = layers.BatchNormalization()(x)

    # Squared nonlinearity
    x = SquareLayer(name="square_layer")(x)

    # Average pooling
    x = layers.AveragePooling2D(pool_size=(1, pool_size), strides=(1, pool_stride))(x)

    # Log nonlinearity
    x = LogLayer(name="log_layer")(x)

    x = layers.Dropout(dropout)(x)
    x = layers.Flatten()(x)

    # Output layer for binary classification
    outputs = layers.Dense(1, activation="sigmoid",
                           kernel_constraint=max_norm(0.5))(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[keras.metrics.BinaryAccuracy(name="acc"),
                 keras.metrics.AUC(name="auc")],
    )
    return model

# =========================
# Metric helpers (for TEST)
# =========================
def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
    return tn / (tn + fp) if (tn + fp) > 0 else 0.0

def youden_threshold_from_probs(y_true, y_prob):
    """Return best threshold and J on this set."""
    if len(np.unique(y_true)) < 2:
        return 0.5, 0.0
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    j = tpr - fpr
    i = int(np.argmax(j))
    return float(thr[i]), float(j[i])

def mean_std(x):
    x = np.asarray(x, dtype=float)
    return np.nanmean(x), np.nanstd(x)

# =========================
# 7-fold CV by patient ID
# =========================
skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

# Lists for TEST metrics (@0.5 and @Youden-J)
AUC_list,  ACC_list,  PREC_list,  REC_list,  F1_list,  SPEC_list  = [], [], [], [], [], []
AUC_J_list, ACC_J_list, PREC_J_list, REC_J_list, F1_J_list, SPEC_J_list = [], [], [], [], [], []

rows = []

print(f"\n=== {K_FOLDS}-Fold CV (by patient ID) ===")
for fold_idx, (train_idx, test_idx) in enumerate(skf.split(all_ids, id_labels), start=1):
    ids_train_full = [all_ids[i] for i in train_idx]
    ids_test       = [all_ids[i] for i in test_idx]

    # small validation split from training IDs (for checkpointing)
    train_labels_full = np.array([1 if pid in POS_PATIENTS else 0 for pid in ids_train_full], dtype=int)
    try:
        ids_tr, ids_val = train_test_split(
            ids_train_full, test_size=0.10, random_state=SEED, stratify=train_labels_full
        )
    except ValueError:
        ids_tr, ids_val = train_test_split(ids_train_full, test_size=0.10, random_state=SEED, shuffle=True)
        print(f"(Fold {fold_idx}) Warning: stratified VAL split failed; using unstratified split.")

    # Files for each split
    train_files = [f for pid in ids_tr  for f in id_to_files[pid]]
    val_files   = [f for pid in ids_val for f in id_to_files[pid]]
    test_files  = [f for pid in ids_test for f in id_to_files[pid]]

    def split_summary(name, ids, files):
        ys = np.array([label_for_file(f) for f in files], dtype=int)
        print(f"{name:>6} | ids: {len(ids):4d} | files: {len(files):5d} | pos files: {(ys==1).sum():4d} | neg files: {(ys==0).sum():4d}")

    print(f"\n--- Fold {fold_idx}/{K_FOLDS} ---")
    split_summary("train", ids_tr,  train_files)
    split_summary("val",   ids_val, val_files)
    split_summary("test",  ids_test, test_files)

    # Generators
    train_gen = ImageSequence(train_files, batch_size=BATCH_SIZE, shuffle=True,
                              add_noise=TRAIN_ADD_GAUSS_NOISE,
                              noise_frac=TRAIN_NOISE_FRAC,
                              noise_prob=TRAIN_NOISE_PROB)
    val_gen   = ImageSequence(val_files,   batch_size=BATCH_SIZE, shuffle=False, add_noise=False)
    test_gen  = ImageSequence(test_files,  batch_size=BATCH_SIZE, shuffle=False, add_noise=False)

    # Train & pick best by val_loss
    model = build_model()
    best_path = BEST_MODEL_TPL.format(fold_idx)
    ckpt = keras.callbacks.ModelCheckpoint(best_path, monitor="val_loss", mode="min",
                                           save_best_only=True, verbose=1)
    _ = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS, callbacks=[ckpt], verbose=1)

    # Evaluate on TEST
    best_model = keras.models.load_model(
        best_path,
        custom_objects={"SquareLayer": SquareLayer, "LogLayer": LogLayer}
    )
    test_probs = best_model.predict(test_gen, verbose=0).ravel().astype(float)
    test_y     = np.array([label_for_file(f) for f in test_gen.files], dtype=int)

    # AUC (threshold-free)
    try:
        test_auc = roc_auc_score(test_y, test_probs)
    except ValueError:
        test_auc = float('nan')

    # --- Threshold 0.5 ---
    y_pred_05 = (test_probs >= 0.5).astype(int)
    acc_05  = accuracy_score(test_y, y_pred_05)
    prec_05 = precision_score(test_y, y_pred_05, zero_division=0)
    rec_05  = recall_score(test_y, y_pred_05, zero_division=0)
    f1_05   = f1_score(test_y, y_pred_05, zero_division=0)
    spec_05 = specificity_score(test_y, y_pred_05)

    # --- Youden-J threshold on TEST ---
    t_star, J_val = youden_threshold_from_probs(test_y, test_probs)
    y_pred_J = (test_probs >= t_star).astype(int)
    acc_J  = accuracy_score(test_y, y_pred_J)
    prec_J = precision_score(test_y, y_pred_J, zero_division=0)
    rec_J  = recall_score(test_y, y_pred_J, zero_division=0)
    f1_J   = f1_score(test_y, y_pred_J, zero_division=0)
    spec_J = specificity_score(test_y, y_pred_J)

    # collect lists
    AUC_list.append(test_auc); ACC_list.append(acc_05);   PREC_list.append(prec_05)
    REC_list.append(rec_05);   F1_list.append(f1_05);     SPEC_list.append(spec_05)

    AUC_J_list.append(test_auc); ACC_J_list.append(acc_J);   PREC_J_list.append(prec_J)
    REC_J_list.append(rec_J);    F1_J_list.append(f1_J);     SPEC_J_list.append(spec_J)

    print(f"Fold {fold_idx} | TEST@0.5  ACC={acc_05:.4f} | PREC={prec_05:.4f} | "
          f"REC={rec_05:.4f} | F1={f1_05:.4f} | AUC={test_auc:.4f} | SPEC={spec_05:.4f} | n={len(test_y)}")
    print(f"Fold {fold_idx} | TEST@J    ACC={acc_J:.4f} | PREC={prec_J:.4f} | "
          f"REC={rec_J:.4f} | F1={f1_J:.4f} | AUC={test_auc:.4f} | SPEC={spec_J:.4f} | thr={t_star:.4f}, J={J_val:.4f}")
    print("Confusion matrix (@0.5):\n", confusion_matrix(test_y, y_pred_05))
    print("Classification report (@0.5):\n", classification_report(test_y, y_pred_05, digits=3))

    rows.append({
        "fold": fold_idx,
        "train_files": len(train_files),
        "val_files": len(val_files),
        "test_files": len(test_files),

        "ACC_0.5": acc_05,
        "PREC_0.5": prec_05,
        "REC_0.5": rec_05,
        "F1_0.5": f1_05,
        "AUC": test_auc,
        "SPEC_0.5": spec_05,

        "thr_J": t_star,
        "J": J_val,
        "ACC_J": acc_J,
        "PREC_J": prec_J,
        "REC_J": rec_J,
        "F1_J": f1_J,
        "SPEC_J": spec_J,
    })

# =========================
# Summary across folds
# =========================
print("\n=== TEST metrics per fold — threshold 0.5 ===")
print("AUC :", [None if np.isnan(x) else round(x,4) for x in AUC_list])
print("ACC :", [round(x,4) for x in ACC_list])
print("PREC:", [round(x,4) for x in PREC_list])
print("REC :", [round(x,4) for x in REC_list])
print("SPEC:", [round(x,4) for x in SPEC_list])
print("F1  :", [round(x,4) for x in F1_list])

print("\n=== TEST metrics per fold — Youden-J (on TEST) ===")
print("AUC@J :", [None if np.isnan(x) else round(x,4) for x in AUC_J_list])
print("ACC@J :", [round(x,4) for x in ACC_J_list])
print("PREC@J:", [round(x,4) for x in PREC_J_list])
print("REC@J :", [round(x,4) for x in REC_J_list])
print("SPEC@J:", [round(x,4) for x in SPEC_J_list])
print("F1@J  :", [round(x,4) for x in F1_J_list])

mAUC,  sAUC  = mean_std(AUC_list)
mACC,  sACC  = mean_std(ACC_list)
mPREC, sPREC = mean_std(PREC_list)
mREC,  sREC  = mean_std(REC_list)
mF1,   sF1   = mean_std(F1_list)
mSPEC, sSPEC = mean_std(SPEC_list)

print("\n=== Mean ± SD across folds (TEST) — 0.5 ===")
print(f"{'AUC':>12}: {mAUC:.4f} ± {sAUC:.4f}")
print(f"{'ACC':>12}: {mACC:.4f} ± {sACC:.4f}")
print(f"{'Precision':>12}: {mPREC:.4f} ± {sPREC:.4f}")
print(f"{'Recall':>12}: {mREC:.4f} ± {sREC:.4f}")
print(f"{'Specificity':>12}: {mSPEC:.4f} ± {sSPEC:.4f}")
print(f"{'F1':>12}: {mF1:.4f} ± {sF1:.4f}")

mAUC_J,  sAUC_J  = mean_std(AUC_J_list)
mACC_J,  sACC_J  = mean_std(ACC_J_list)
mPREC_J, sPREC_J = mean_std(PREC_J_list)
mREC_J,  sREC_J  = mean_std(REC_J_list)
mF1_J,   sF1_J   = mean_std(F1_J_list)
mSPEC_J, sSPEC_J = mean_std(SPEC_J_list)

print("\n=== Mean ± SD across folds (TEST) — Youden-J (on TEST) ===")
print(f"{'AUC@J':>12}: {mAUC_J:.4f} ± {sAUC_J:.4f}")
print(f"{'ACC@J':>12}: {mACC_J:.4f} ± {sACC_J:.4f}")
print(f"{'Precision@J':>12}: {mPREC_J:.4f} ± {sPREC_J:.4f}")
print(f"{'Recall@J':>12}: {mREC_J:.4f} ± {sREC_J:.4f}")
print(f"{'Specificity@J':>12}: {mSPEC_J:.4f} ± {sSPEC_J:.4f}")
print(f"{'F1@J':>12}: {mF1_J:.4f} ± {sF1_J:.4f}")

metrics_df = pd.DataFrame(rows)
metrics_df.to_csv("cv7_img_fold_metrics.csv", index=False)
print("\nSaved TEST-only per-fold metrics to cv7_img_fold_metrics.csv")
# Out:
# Total IDs: 42 | Pos IDs: 13 | Neg IDs: 29
# TARGET_W=6 (non-Time columns)
# Fixed input height after de-dup (all IDs): H=360
# Normalization: NONE. De-dup: remove consecutive duplicate rows (row-wise).
#
# === 7-Fold CV (by patient ID) ===
#
# --- Fold 1/7 ---
#  train | ids:   32 | files:   808 | pos files:  320 | neg files:  488
#    val | ids:    4 | files:    85 | pos files:    6 | neg files:   79
#   test | ids:    6 | files:   131 | pos files:   45 | neg files:   86
# Epoch 1/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.5425 - auc: 0.4913 - loss: 0.8586
# Epoch 1: val_loss improved from inf to 0.26820, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - acc: 0.5425 - auc: 0.4913 - loss: 0.8583 - val_acc: 0.9294 - val_auc: 0.6793 - val_loss: 0.2682
# Epoch 2/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5852 - auc: 0.5621 - loss: 0.7337
# Epoch 2: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5848 - auc: 0.5618 - loss: 0.7345 - val_acc: 0.9294 - val_auc: 0.6392 - val_loss: 0.4015
# Epoch 3/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6117 - auc: 0.5746 - loss: 0.7261
# Epoch 3: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6104 - auc: 0.5741 - loss: 0.7268 - val_acc: 0.9059 - val_auc: 0.6044 - val_loss: 0.4503
# Epoch 4/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.
val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6263 - auc: 0.7064 - loss: 0.6096 - val_acc: 0.4941 - val_auc: 0.6540 - val_loss: 0.6463
# Epoch 19/100
# 253/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6559 - auc: 0.7149 - loss: 0.6035
# Epoch 19: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6568 - auc: 0.7151 - loss: 0.6035 - val_acc: 0.8118 - val_auc: 0.7637 - val_loss: 0.4939
# Epoch 20/100
# 252/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6816 - auc: 0.7108 - loss: 0.5985
# Epoch 20: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6816 - auc: 0.7113 - loss: 0.5989 - val_acc: 0.2706 - val_auc: 0.6519 - val_loss: 0.8362
# Epoch 21/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6607 - auc: 0.6839 - loss: 0.6311
# Epoch 21: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6613 - auc: 0.6861 - loss: 0.6290 - val_acc: 0.8353 - val_auc: 0.5728 - val_loss: 0.4384
# Epoch 22/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6525 - auc: 0.7115 - loss: 0.6094
# Epoch 22: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6525 - auc: 0.7110 - loss: 0.6094 - val_acc: 0.4941 - val_auc: 0.8186 - val_loss: 0.9010
# Epoch 23/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6729 - auc: 0.6957 - loss: 0.6134
# Epoch 23: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6726 - auc: 0.6969 - loss: 0.6126 - val_acc: 0.7882 - val_auc: 0.4768 - val_loss: 0.5392
# Epoch 24/100
# 254/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6592 - auc: 0.7347 - loss: 0.5842
# Epoch 24: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6606 - auc: 0.7347 - loss: 0.5843 - val_acc: 0.2353 - val_auc: 0.5454 - val_loss: 0.9229
# Epoch 25/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6829 - auc: 0.7261 - loss: 0.5838
# Epoch 25: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6825 - auc: 0.7259 - loss: 0.5842 - val_acc: 0.9176 - val_auc: 0.4462 - val_loss: 0.3508
# Epoch 26/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6757 - auc: 0.7389 - loss: 0.5902
# Epoch 26: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6760 - auc: 0.7389 - loss: 0.5899 - val_acc: 0.8118 - val_auc: 0.5380 - val_loss: 0.5086
# Epoch 27/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6543 - auc: 0.6910 - loss: 0.6175
# Epoch 27: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6553 - auc: 0.6921 - loss: 0.6168 - val_acc: 0.6941 - val_auc: 0.6762 - val_loss: 0.5631
# Epoch 28/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6880 - auc: 0.7607 - loss: 0.5540
# Epoch 28: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6866 - auc: 0.7598 - loss: 0.5549 - val_acc: 0.3176 - val_auc: 0.7036 - val_loss: 1.3090
# Epoch 29/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6717 - auc: 0.7704 - loss: 0.5536
# Epoch 29: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6719 - auc: 0.7698 - loss: 0.5542 - val_acc: 0.4941 - val_auc: 0.6192 - val_loss: 0.6863
# Epoch 30/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7133 - auc: 0.7578 - loss: 0.5650
# Epoch 30: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7113 - auc: 0.7565 - loss: 0.5663 - val_acc: 0.9412 - val_auc: 0.7162 - val_loss: 0.4282
# Epoch 31/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6826 - auc: 0.7337 - loss: 0.5835
# Epoch 31: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6825 - auc: 0.7337 - loss: 0.5835 - val_acc: 0.3412 - val_auc: 0.6878 - val_loss: 1.0978
# Epoch 32/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6887 - auc: 0.7538 - loss: 0.5625
# Epoch 32: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6886 - auc: 0.7537 - loss: 0.5626 - val_acc: 0.4588 - val_auc: 0.8080 - val_loss: 1.0070
# Epoch 33/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.
270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7374 - auc: 0.8230 - loss: 0.5039
# Epoch 93: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7376 - auc: 0.8230 - loss: 0.5035 - val_acc: 0.5647 - val_auc: 0.3903 - val_loss: 0.6281
# Epoch 94/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7304 - auc: 0.8041 - loss: 0.5113
# Epoch 94: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7306 - auc: 0.8041 - loss: 0.5115 - val_acc: 0.3882 - val_auc: 0.5169 - val_loss: 0.9190
# Epoch 95/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7486 - auc: 0.8105 - loss: 0.4862
# Epoch 95: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7483 - auc: 0.8103 - loss: 0.4867 - val_acc: 0.4941 - val_auc: 0.5327 - val_loss: 0.6734
# Epoch 96/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7668 - auc: 0.8329 - loss: 0.4691
# Epoch 96: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7665 - auc: 0.8327 - loss: 0.4697 - val_acc: 0.3529 - val_auc: 0.4462 - val_loss: 1.2661
# Epoch 97/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7312 - auc: 0.8209 - loss: 0.4999
# Epoch 97: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7322 - auc: 0.8217 - loss: 0.4987 - val_acc: 0.8471 - val_auc: 0.4008 - val_loss: 0.5305
# Epoch 98/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6971 - auc: 0.7809 - loss: 0.5214
# Epoch 98: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6981 - auc: 0.7819 - loss: 0.5206 - val_acc: 0.2706 - val_auc: 0.3133 - val_loss: 1.3939
# Epoch 99/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7229 - auc: 0.7895 - loss: 0.5216
# Epoch 99: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7240 - auc: 0.7908 - loss: 0.5206 - val_acc: 0.8353 - val_auc: 0.1793 - val_loss: 0.5118
# Epoch 100/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7625 - auc: 0.8393 - loss: 0.4658
# Epoch 100: val_loss did not improve from 0.26820
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7621 - auc: 0.8389 - loss: 0.4665 - val_acc: 0.5412 - val_auc: 0.5749 - val_loss: 0.7504
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 1 | TEST@0.5  ACC=0.6565 | PREC=0.0000 | REC=0.0000 | F1=0.0000 | AUC=0.4016 | SPEC=1.0000 | n=131
# Fold 1 | TEST@J    ACC=0.4351 | PREC=0.3761 | REC=0.9778 | F1=0.5432 | AUC=0.4016 | SPEC=0.1512 | thr=0.0970, J=0.1289
# Confusion matrix (@0.5):
#  [[86  0]
#  [45  0]]
# Classification report (@0.5):
#                precision    recall  f1-score   support
#
#            0      0.656     1.000     0.793        86
#            1      0.000     0.000     0.000        45
#
#     accuracy                          0.656       131
#    macro avg      0.328     0.500     0.396       131
# weighted avg      0.431     0.656     0.520       131
#
#
# --- Fold 2/7 ---
#  train | ids:   32 | files:   763 | pos files:  322 | neg files:  441
#    val | ids:    4 | files:   149 | pos files:    4 | neg files:  145
#   test | ids:    6 | files:   112 | pos files:   45 | neg files:   67
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.5952 - auc: 0.5449 - loss: 0.7904
# Epoch 1: val_loss improved from inf to 0.38139, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - acc: 0.5949 - auc: 0.5462 - loss: 0.7895 - val_acc: 0.9195 - val_auc: 0.5414 - val_loss: 0.3814
# Epoch 2/100
# 238/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5975 - auc: 0.5742 - loss: 0.7305
# Epoch 2: val_loss improved from 0.38139 to 0.21551, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.5971 - auc: 0.5748 - loss: 0.7307 - val_acc: 0.9732 - val_auc: 0.9328 - val_loss: 0.2155
# Epoch 3/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.
100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6261 - auc: 0.6797 - loss: 0.6350
# Epoch 32: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6264 - auc: 0.6800 - loss: 0.6344 - val_acc: 0.6846 - val_auc: 0.6810 - val_loss: 0.4545
# Epoch 33/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6791 - auc: 0.7341 - loss: 0.5939
# Epoch 33: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6778 - auc: 0.7324 - loss: 0.5951 - val_acc: 0.7785 - val_auc: 0.7983 - val_loss: 0.3634
# Epoch 34/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6738 - auc: 0.7353 - loss: 0.6099
# Epoch 34: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6727 - auc: 0.7345 - loss: 0.6098 - val_acc: 0.8121 - val_auc: 0.6009 - val_loss: 0.3346
# Epoch 35/100
# 236/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6783 - auc: 0.7490 - loss: 0.5772
# Epoch 35: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6771 - auc: 0.7469 - loss: 0.5792 - val_acc: 0.5436 - val_auc: 0.8103 - val_loss: 0.6537
# Epoch 36/100
# 248/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6454 - auc: 0.7181 - loss: 0.5947
# Epoch 36: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6460 - auc: 0.7189 - loss: 0.5942 - val_acc: 0.7517 - val_auc: 0.7784 - val_loss: 0.4849
# Epoch 37/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6636 - auc: 0.7226 - loss: 0.6042
# Epoch 37: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6640 - auc: 0.7230 - loss: 0.6037 - val_acc: 0.8658 - val_auc: 0.9578 - val_loss: 0.2538
# Epoch 38/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6735 - auc: 0.7545 - loss: 0.5776
# Epoch 38: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6733 - auc: 0.7542 - loss: 0.5776 - val_acc: 0.7919 - val_auc: 0.5440 - val_loss: 0.3762
# Epoch 39/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6764 - auc: 0.6735 - loss: 0.6135
# Epoch 39: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6755 - auc: 0.6752 - loss: 0.6133 - val_acc: 0.7181 - val_auc: 0.7931 - val_loss: 0.5625
# Epoch 40/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6525 - auc: 0.7345 - loss: 0.5921
# Epoch 40: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6533 - auc: 0.7345 - loss: 0.5920 - val_acc: 0.8658 - val_auc: 0.8483 - val_loss: 0.3277
# Epoch 41/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6440 - auc: 0.7216 - loss: 0.6080
# Epoch 41: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6450 - auc: 0.7218 - loss: 0.6076 - val_acc: 0.8121 - val_auc: 0.9897 - val_loss: 0.3681
# Epoch 42/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6565 - auc: 0.6868 - loss: 0.6129
# Epoch 42: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6570 - auc: 0.6878 - loss: 0.6124 - val_acc: 0.8859 - val_auc: 0.4879 - val_loss: 0.2860
# Epoch 43/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6635 - auc: 0.7314 - loss: 0.5915
# Epoch 43: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6641 - auc: 0.7324 - loss: 0.5908 - val_acc: 0.6376 - val_auc: 0.2664 - val_loss: 0.5932
# Epoch 44/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6458 - auc: 0.7201 - loss: 0.6022
# Epoch 44: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6459 - auc: 0.7200 - loss: 0.6022 - val_acc: 0.7047 - val_auc: 0.5224 - val_loss: 0.4276
# Epoch 45/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6706 - auc: 0.7634 - loss: 0.5599
# Epoch 45: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6707 - auc: 0.7627 - loss: 0.5607 - val_acc: 0.7047 - val_auc: 0.2103 - val_loss: 0.5113
# Epoch 46/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6665 - auc: 0.7205 - loss: 0.6082
# Epoch 46: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6662 - auc: 0.7207 - loss: 0.6076 - val_acc: 0.7651 - val_auc: 0.7750 - val_loss: 0.3428
# Epoch 47/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6508 - auc: 0.7053 - loss: 0.6091
# Epoch 47: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6514 - auc: 0.7062 - loss: 0.6087 - val_acc: 0.7987 - val_auc: 0.4897 - val_loss: 0.3949
# Epoch 48/100
# 248/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6574 - auc: 0.7270 - loss: 0.5943
# Epoch 48: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6570 - auc: 0.7269 - loss: 0.5944 - val_acc: 0.6779 - val_auc: 0.4733 - val_loss: 0.4724
# Epoch 49/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6878 - auc: 0.7503 - loss: 0.5693
# Epoch 49: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6879 - auc: 0.7501 - loss: 0.5697 - val_acc: 0.6443 - val_auc: 0.6353 - val_loss: 0.4665
# Epoch 50/100
# 240/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7446 - auc: 0.7833 - loss: 0.5462
# Epoch 50: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7431 - auc: 0.7825 - loss: 0.5471 - val_acc: 0.8658 - val_auc: 0.2991 - val_loss: 0.3893
# Epoch 51/100
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6894 - auc: 0.7578 - loss: 0.5538
# Epoch 51: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6893 - auc: 0.7578 - loss: 0.5539 - val_acc: 0.6174 - val_auc: 0.4379 - val_loss: 0.6281
# Epoch 52/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6834 - auc: 0.7611 - loss: 0.5710
# Epoch 52: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6840 - auc: 0.7613 - loss: 0.5706 - val_acc: 0.6174 - val_auc: 0.0078 - val_loss: 0.6585
# Epoch 53/100
# 242/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6624 - auc: 0.7121 - loss: 0.6076
# Epoch 53: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6630 - auc: 0.7133 - loss: 0.6063 - val_acc: 0.7718 - val_auc: 0.4957 - val_loss: 0.3693
# Epoch 54/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6539 - auc: 0.7395 - loss: 0.5874
# Epoch 54: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6549 - auc: 0.7397 - loss: 0.5868 - val_acc: 0.7517 - val_auc: 0.6819 - val_loss: 0.3826
# Epoch 55/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6848 - auc: 0.7594 - loss: 0.5687
# Epoch 55: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6842 - auc: 0.7587 - loss: 0.5692 - val_acc: 0.7785 - val_auc: 0.8552 - val_loss: 0.4286
# Epoch 56/100
# 239/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6496 - auc: 0.7290 - loss: 0.5884
# Epoch 56: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6505 - auc: 0.7303 - loss: 0.5876 - val_acc: 0.8859 - val_auc: 0.6991 - val_loss: 0.2478
# Epoch 57/100
# 241/255 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7169 - auc: 0.7724 - loss: 0.5583
# Epoch 57: val_loss did not improve from 0.21551
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7158 - auc: 0.7723 - loss: 0.5582 - val_acc: 0.7785 - val_auc: 0.5983 - val_loss: 0.4038
# Epoch 58/100
# ...
# Epoch 53: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6690 - auc: 0.7568 - loss: 0.5687 - val_acc: 0.4865 - val_auc: 0.7392 - val_loss: 0.9026
# Epoch 54/100
# 266/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7182 - auc: 0.7910 - loss: 0.5320
# Epoch 54: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7171 - auc: 0.7903 - loss: 0.5325 - val_acc: 0.3514 - val_auc: 0.8683 - val_loss: 1.5250
# Epoch 55/100
# 263/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6649 - auc: 0.7328 - loss: 0.5787
# Epoch 55: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6665 - auc: 0.7350 - loss: 0.5770 - val_acc: 0.4595 - val_auc: 0.7930 - val_loss: 0.9018
# Epoch 56/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7097 - auc: 0.7896 - loss: 0.5318
# Epoch 56: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7095 - auc: 0.7894 - loss: 0.5319 - val_acc: 0.5946 - val_auc: 0.5430 - val_loss: 0.7378
# Epoch 57/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7321 - auc: 0.7939 - loss: 0.5367
# Epoch 57: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7320 - auc: 0.7938 - loss: 0.5368 - val_acc: 0.5405 - val_auc: 0.1613 - val_loss: 0.9227
# Epoch 58/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6543 - auc: 0.7477 - loss: 0.5713
# Epoch 58: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6544 - auc: 0.7477 - loss: 0.5712 - val_acc: 0.2973 - val_auc: 0.6371 - val_loss: 1.0470
# Epoch 59/100
# 264/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7440 - auc: 0.8054 - loss: 0.5203
# Epoch 59: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7435 - auc: 0.8055 - loss: 0.5202 - val_acc: 0.7297 - val_auc: 0.7285 - val_loss: 0.5756
# Epoch 60/100
# 281/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7155 - auc: 0.7931 - loss: 0.5371
# Epoch 60: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7152 - auc: 0.7928 - loss: 0.5372 - val_acc: 0.1351 - val_auc: 0.0645 - val_loss: 1.2343
# Epoch 61/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6879 - auc: 0.7541 - loss: 0.5591
# Epoch 61: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6881 - auc: 0.7543 - loss: 0.5590 - val_acc: 0.6757 - val_auc: 0.6882 - val_loss: 0.6049
# Epoch 62/100
# 265/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7048 - auc: 0.7983 - loss: 0.5191
# Epoch 62: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7050 - auc: 0.7982 - loss: 0.5195 - val_acc: 0.7027 - val_auc: 0.3871 - val_loss: 0.7387
# Epoch 63/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7214 - auc: 0.7997 - loss: 0.5204
# Epoch 63: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7213 - auc: 0.7996 - loss: 0.5204 - val_acc: 0.7297 - val_auc: 0.3602 - val_loss: 0.7360
# Epoch 64/100
# 266/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6865 - auc: 0.7626 - loss: 0.5619
# Epoch 64: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6866 - auc: 0.7633 - loss: 0.5613 - val_acc: 0.6216 - val_auc: 0.3737 - val_loss: 0.7400
# Epoch 65/100
# 281/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7010 - auc: 0.7807 - loss: 0.5388
# Epoch 65: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7011 - auc: 0.7806 - loss: 0.5390 - val_acc: 0.4595 - val_auc: 0.6263 - val_loss: 1.0471
# Epoch 66/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7001 - auc: 0.7740 - loss: 0.5473
# Epoch 66: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7001 - auc: 0.7740 - loss: 0.5473 - val_acc: 0.7027 - val_auc: 0.6156 - val_loss: 0.6344
# Epoch 67/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6908 - auc: 0.7631 - loss: 0.5399
# Epoch 67: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6908 - auc: 0.7631 - loss: 0.5399 - val_acc: 0.5946 - val_auc: 0.4973 - val_loss: 0.7684
# Epoch 68/100
# 279/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7359 - auc: 0.8164 - loss: 0.5034
# Epoch 68: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7354 - auc: 0.8158 - loss: 0.5041 - val_acc: 0.6757 - val_auc: 0.6882 - val_loss: 0.7439
# Epoch 69/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7234 - auc: 0.7780 - loss: 0.5388
# Epoch 69: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7235 - auc: 0.7781 - loss: 0.5390 - val_acc: 0.4595 - val_auc: 0.7043 - val_loss: 0.9910
# Epoch 70/100
# 264/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6932 - auc: 0.7562 - loss: 0.5713
# Epoch 70: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6944 - auc: 0.7579 - loss: 0.5695 - val_acc: 0.4324 - val_auc: 0.5780 - val_loss: 1.0820
# Epoch 71/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6866 - auc: 0.7678 - loss: 0.5585
# Epoch 71: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.6866 - auc: 0.7678 - loss: 0.5584 - val_acc: 0.5946 - val_auc: 0.3495 - val_loss: 0.7810
# Epoch 72/100
# 267/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7233 - auc: 0.7938 - loss: 0.5315
# Epoch 72: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7232 - auc: 0.7937 - loss: 0.5313 - val_acc: 0.7297 - val_auc: 0.6613 - val_loss: 0.6025
# Epoch 73/100
# 264/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7177 - auc: 0.7731 - loss: 0.5556
# Epoch 73: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7178 - auc: 0.7742 - loss: 0.5541 - val_acc: 0.4324 - val_auc: 0.4624 - val_loss: 1.0574
# Epoch 74/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7199 - auc: 0.8084 - loss: 0.5162
# Epoch 74: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7199 - auc: 0.8083 - loss: 0.5163 - val_acc: 0.6486 - val_auc: 0.8333 - val_loss: 0.7676
# Epoch 75/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7404 - auc: 0.8179 - loss: 0.5052
# Epoch 75: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7404 - auc: 0.8178 - loss: 0.5053 - val_acc: 0.7297 - val_auc: 0.6747 - val_loss: 0.5632
# Epoch 76/100
# 266/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7170 - auc: 0.8124 - loss: 0.5135
# Epoch 76: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7173 - auc: 0.8118 - loss: 0.5138 - val_acc: 0.4865 - val_auc: 0.6882 - val_loss: 1.1325
# Epoch 77/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7122 - auc: 0.7924 - loss: 0.5181
# Epoch 77: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7122 - auc: 0.7923 - loss: 0.5184 - val_acc: 0.6486 - val_auc: 0.5699 - val_loss: 0.7179
# Epoch 78/100
# 268/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7147 - auc: 0.7977 - loss: 0.5177
# Epoch 78: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7136 - auc: 0.7965 - loss: 0.5189 - val_acc: 0.4595 - val_auc: 0.5780 - val_loss: 0.8646
# Epoch 79/100
# 265/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6996 - auc: 0.7693 - loss: 0.5444
# Epoch 79: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7007 - auc: 0.7712 - loss: 0.5431 - val_acc: 0.5946 - val_auc: 0.5753 - val_loss: 0.7288
# Epoch 80/100
# 268/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7135 - auc: 0.8078 - loss: 0.5169
# Epoch 80: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7138 - auc: 0.8075 - loss: 0.5170 - val_acc: 0.6486 - val_auc: 0.5376 - val_loss: 0.6747
# Epoch 81/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7325 - auc: 0.8162 - loss: 0.4975
# Epoch 81: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7325 - auc: 0.8161 - loss: 0.4976 - val_acc: 0.7568 - val_auc: 0.7554 - val_loss: 0.7008
# Epoch 82/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7404 - auc: 0.7947 - loss: 0.5229
# Epoch 82: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7398 - auc: 0.7946 - loss: 0.5231 - val_acc: 0.6216 - val_auc: 0.6882 - val_loss: 0.6740
# Epoch 83/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7235 - auc: 0.8114 - loss: 0.5030
# Epoch 83: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7233 - auc: 0.8112 - loss: 0.5033 - val_acc: 0.5946 - val_auc: 0.5215 - val_loss: 0.7381
# Epoch 84/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7627 - auc: 0.8290 - loss: 0.4986
# Epoch 84: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7611 - auc: 0.8278 - loss: 0.4997 - val_acc: 0.6486 - val_auc: 0.3817 - val_loss: 0.7769
# Epoch 85/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.
val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7110 - auc: 0.8050 - loss: 0.5158 - val_acc: 0.6216 - val_auc: 0.5699 - val_loss: 0.7630
# Epoch 100/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7376 - auc: 0.8098 - loss: 0.5311
# Epoch 100: val_loss did not improve from 0.43451
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.7376 - auc: 0.8100 - loss: 0.5305 - val_acc: 0.3514 - val_auc: 0.7581 - val_loss: 1.2172
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 7 | TEST@0.5  ACC=0.8797 | PREC=0.0000 | REC=0.0000 | F1=0.0000 | AUC=0.2912 | SPEC=0.9435 | n=133
# Fold 7 | TEST@J    ACC=0.3083 | PREC=0.0891 | REC=1.0000 | F1=0.1636 | AUC=0.2912 | SPEC=0.2581 | thr=0.0954, J=0.2581
# Confusion matrix (@0.5):
#  [[117   7]
#  [  9   0]]
# Classification report (@0.5):
#                precision    recall  f1-score   support
#
#            0      0.929     0.944     0.936       124
#            1      0.000     0.000     0.000         9
#
#     accuracy                          0.880       133
#    macro avg      0.464     0.472     0.468       133
# weighted avg      0.866     0.880     0.873       133
#
#
# === TEST metrics per fold — threshold 0.5 ===
# AUC : [np.float64(0.4016), np.float64(0.3456), np.float64(0.7248), np.float64(0.8135), np.float64(0.084), np.float64(0.7567), np.float64(0.2912)]
# ACC : [0.6565, 0.6964, 0.6594, 0.6608, 0.4524, 0.3822, 0.8797]
# PREC: [0.0, 1.0, 1.0, 0.9091, 0.0, 0.0, 0.0]
# REC : [0.0, 0.2444, 0.3188, 0.1163, 0.0, 0.0, 0.0]
# SPEC: [np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(0.9929), np.float64(0.5377), np.float64(1.0), np.float64(0.9435)]
# F1  : [0.0, 0.3929, 0.4835, 0.2062, 0.0, 0.0, 0.0]
#
# === TEST metrics per fold — Youden-J (on TEST) ===
# AUC@J : [np.float64(0.4016), np.float64(0.3456), np.float64(0.7248), np.float64(0.8135), np.float64(0.084), np.float64(0.7567), np.float64(0.2912)]
# ACC@J : [0.4351, 0.6964, 0.7029, 0.7093, 0.1825, 0.8917, 0.3083]
# PREC@J: [0.3761, 1.0, 0.9375, 0.5714, 0.1626, 0.8571, 0.0891]
# REC@J : [0.9778, 0.2444, 0.4348, 0.9302, 1.0, 0.9897, 1.0]
# SPEC@J: [np.float64(0.1512), np.float64(1.0), np.float64(0.971), np.float64(0.5745), np.float64(0.0283), np.float64(0.7333), np.float64(0.2581)]
# F1@J  : [0.5432, 0.3929, 0.5941, 0.708, 0.2797, 0.9187, 0.1636]
#
# === Mean ± SD across folds (TEST) — 0.5 ===
#          AUC: 0.4882 ± 0.2575
#          ACC: 0.6268 ± 0.1522
#    Precision: 0.4156 ± 0.4807
#       Recall: 0.0971 ± 0.1248
#  Specificity: 0.9249 ± 0.1592
#           F1: 0.1547 ± 0.1939
#
# === Mean ± SD across folds (TEST) — Youden-J (on TEST) ===
#        AUC@J: 0.4882 ± 0.2575
#        ACC@J: 0.5609 ± 0.2369
#  Precision@J: 0.5706 ± 0.3458
#     Recall@J: 0.7967 ± 0.2944
# Specificity@J: 0.5309 ± 0.3641
#         F1@J: 0.5143 ± 0.2393
#
# Saved TEST-only per-fold metrics to cv7_img_fold_metrics.csv
