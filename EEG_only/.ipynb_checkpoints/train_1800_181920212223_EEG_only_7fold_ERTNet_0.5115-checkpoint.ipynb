# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.transforms as transforms
import os
import argparse
from pathlib import Path
import re
import random
import math
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
from torch.utils.data import Dataset, DataLoader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### EEGNet-8,2

# %%
from pathlib import Path
import re, random, math, os
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    accuracy_score, roc_auc_score, classification_report, confusion_matrix,
    precision_score, recall_score, f1_score, roc_curve,
)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.constraints import max_norm   # used in ShallowConvNet

# =========================
# Config
# =========================
SPLIT_DIR = r"/content/drive/MyDrive/CD/patient_data_clean_1800s_nozero_181920212223_in3days_v2"
POS_PATIENTS = {1, 2, 16, 19, 21, 22, 25, 37, 39, 43, 44, 47, 50, 56, 58, 62, 65, 66, 73, 78}

BATCH_SIZE       = 3
EPOCHS           = 100
LR               = 1e-4
SEED             = 1
K_FOLDS          = 7
BEST_MODEL_TPL   = "best_fold_{:02d}.h5"

# not used for dedup height; kept for reference
TARGET_H = 300

# =========================
# Noise config (train-time augmentation only)
# =========================
TRAIN_ADD_GAUSS_NOISE = True     # training generator only
TRAIN_NOISE_FRAC      = 0.10
TRAIN_NOISE_PROB      = 1.0
EPS_STD               = 1e-8

# =========================
# Repro
# =========================
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
for g in tf.config.list_physical_devices('GPU'):
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception:
        pass

# =========================
# Helpers for ID/labels
# =========================
PATIENT_NUM_RX = re.compile(r'^ID(\d+)')

def patient_num_from_path(pathlike):
    stem = Path(pathlike).stem
    m = PATIENT_NUM_RX.match(stem)
    return int(m.group(1)) if m else None

def label_for_file(p: Path) -> int:
    pnum = patient_num_from_path(p)
    return 1 if (pnum is not None and pnum in POS_PATIENTS) else 0

# =========================
# List files (all) & labels by patient ID
# =========================
split_dir = Path(SPLIT_DIR)
all_csvs = sorted(split_dir.glob("*.csv"))
if not all_csvs:
    raise FileNotFoundError(f"No CSV found in {SPLIT_DIR}")

id_to_files = {}
for f in all_csvs:
    pid = patient_num_from_path(f)
    if pid is None or pid == 12:    # exclude ID 12
        continue
    id_to_files.setdefault(pid, []).append(f)

all_ids = sorted(id_to_files.keys())
id_labels = np.array([1 if pid in POS_PATIENTS else 0 for pid in all_ids], dtype=int)
print("Total IDs:", len(all_ids), "| Pos IDs:", id_labels.sum(), "| Neg IDs:", (1 - id_labels).sum())

# =========================
# Column handling
# =========================
def _drop_time_cols(df: pd.DataFrame) -> pd.DataFrame:
    time_like = [c for c in df.columns if isinstance(c, str) and c.strip().lower() == "time"]
    return df.drop(columns=time_like, errors="ignore")

def _to_numeric_df(df: pd.DataFrame) -> pd.DataFrame:
    df = _drop_time_cols(df)
    return df.apply(pd.to_numeric, errors="coerce").fillna(0.0)

def _pad_crop_2d(x: np.ndarray, H: int, W: int) -> np.ndarray:
    h, w = x.shape
    if h < H:
        pad = np.zeros((H, w), dtype=x.dtype); pad[:h, :] = x; x = pad; h = H
    elif h > H:
        x = x[:H, :]; h = H
    if w < W:
        pad = np.zeros((h, W), dtype=x.dtype); pad[:, :w] = x; x = pad
    elif w > W:
        x = x[:, :W]
    return x

def _infer_target_width(example_csv: Path) -> int:
    df = pd.read_csv(example_csv)
    df2 = _to_numeric_df(df)
    return df2.shape[1]

# Fix width/height ONCE using the whole dataset (so all folds match)
TARGET_W = _infer_target_width(all_csvs[0])
print(f"TARGET_W={TARGET_W} (non-Time columns)")

def _dedupe_consecutive_rows(mat: np.ndarray) -> np.ndarray:
    if mat.size == 0:
        return mat
    if mat.ndim == 1:
        mat = mat[:, None]
    if mat.shape[0] == 1:
        return mat
    diffs = np.any(mat[1:] != mat[:-1], axis=1)
    keep = np.concatenate(([True], diffs))
    return mat[keep]

def _dedup_len_from_csv(p: Path) -> int:
    df = pd.read_csv(p)
    mat = _to_numeric_df(df).to_numpy(dtype=np.float32)
    mat_d = _dedupe_consecutive_rows(mat)
    return int(mat_d.shape[0])

TARGET_H_DEDUP = max(_dedup_len_from_csv(f) for f in all_csvs)
if TARGET_H_DEDUP <= 0:
    raise RuntimeError("After de-dup, zero-length found in data.")
print(f"Fixed input height after de-dup (all IDs): H={TARGET_H_DEDUP}")

def load_csv_as_image_dedup(csv_path: Path) -> np.ndarray:
    df  = pd.read_csv(csv_path)
    df2 = _to_numeric_df(df)
    mat = df2.to_numpy(dtype=np.float32)      # shape ~ (Samples, Chans)
    if mat.ndim != 2:
        mat = mat.reshape(mat.shape[0], -1) if mat.ndim > 2 else mat
    mat = _dedupe_consecutive_rows(mat)
    if mat.shape[0] == 0:
        mat = np.zeros((1, TARGET_W), dtype=np.float32)
    mat = _pad_crop_2d(mat, TARGET_H_DEDUP, TARGET_W)
    # keep shape as (Samples, Chans); model will permute internally
    img = np.expand_dims(mat, axis=-1).astype(np.float32)  # (Samples, Chans, 1)
    if img.shape != (TARGET_H_DEDUP, TARGET_W, 1):
        raise ValueError(f"loader produced {img.shape}, expected {(TARGET_H_DEDUP, TARGET_W, 1)} for {csv_path}")
    return img

# cache
CACHE_DEDUP = {}
def load_csv_as_image_cached(csv_path: Path) -> np.ndarray:
    key = ("dedup", str(csv_path))
    if key in CACHE_DEDUP:
        return CACHE_DEDUP[key]
    img = load_csv_as_image_dedup(csv_path)
    CACHE_DEDUP[key] = img
    return img

print("Normalization: NONE. De-dup: remove consecutive duplicate rows (row-wise).")

# =========================
# Keras Sequence
# =========================
class ImageSequence(keras.utils.Sequence):
    def __init__(self, files, batch_size=BATCH_SIZE, shuffle=True,
                 add_noise=False, noise_frac=TRAIN_NOISE_FRAC, noise_prob=TRAIN_NOISE_PROB):
        super().__init__()
        self.files = list(files)
        self.batch_size = int(batch_size)
        self.shuffle = shuffle
        self.add_noise = add_noise
        self.noise_frac = float(noise_frac)
        self.noise_prob = float(noise_prob)
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.files) / self.batch_size)

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.files))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __getitem__(self, idx):
        idxs = self.indexes[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch_files = [self.files[i] for i in idxs]
        B = len(batch_files)
        X = np.empty((B, TARGET_H_DEDUP, TARGET_W, 1), dtype=np.float32)  # (Samples, Chans, 1)
        y = np.empty((B,), dtype=np.int32)

        for i, f in enumerate(batch_files):
            xi = load_csv_as_image_cached(f)
            if xi.ndim == 2:
                xi = xi[..., None]
            if xi.shape != (TARGET_H_DEDUP, TARGET_W, 1):
                raise ValueError(f"Sample shape {xi.shape} for {f}; expected {(TARGET_H_DEDUP, TARGET_W, 1)}")
            X[i] = xi
            y[i] = label_for_file(f)

        if self.add_noise and self.noise_frac > 0.0 and self.noise_prob > 0.0:
            samp_std = X.reshape(B, -1).std(axis=1).astype(np.float32)
            samp_std = np.maximum(samp_std, EPS_STD).reshape(B, 1, 1, 1)
            noise = np.random.normal(0.0, 1.0, size=X.shape).astype(np.float32)
            noise *= (self.noise_frac * samp_std)
            if self.noise_prob < 1.0:
                mask = (np.random.rand(B, 1, 1, 1) < self.noise_prob).astype(np.float32)
                noise *= mask
            X = X + noise

        if X.shape[1:] != (TARGET_H_DEDUP, TARGET_W, 1):
            raise ValueError(f"Batch X has shape {X.shape}; expected (B, {TARGET_H_DEDUP}, {TARGET_W}, 1)")
        return X, y

# =========================
# ShallowConvNet model (binary head)
# =========================
# =========================
# EEG-Transformer model (binary head)
# =========================
# =========================
# ERTNet-style CNN + Transformer model (binary head)
# =========================
def build_model(
    samples=TARGET_H_DEDUP,
    chans=TARGET_W,
    lr=LR,
    cnn_filters=(32, 64),   # CNN stem filters
    cnn_kernel=7,           # temporal conv kernel size
    cnn_pool=2,             # temporal pooling factor
    d_model=64,             # transformer embedding dim
    num_heads=4,            # attention heads
    ff_dim=128,             # FFN hidden dim in transformer
    num_layers=2,           # number of transformer encoder blocks
    dropout=0.3
):
    """
    ERTNet-style model:
      - CNN stem (1D convs over time) to get local temporal features
      - Transformer encoder over time for long-range dependencies
      - Global pooling + MLP + sigmoid for binary classification

    Input shape: (samples, chans, 1) ~ (T, C, 1)
    """

    inputs = keras.Input(shape=(samples, chans, 1))   # (T, C, 1)

    # ---- CNN STEM (temporal Conv1D over time) ----
    # (T, C, 1) -> (T, C)
    x = layers.Reshape((samples, chans))(inputs)      # (T, C)

    # Conv1D expects shape (batch, steps, channels) = (batch, T, features)
    # Here "features" initially = chans
    for i, f in enumerate(cnn_filters):
        x = layers.Conv1D(
            filters=f,
            kernel_size=cnn_kernel,
            padding="same",
            activation="relu"
        )(x)                                          # (T, f)
        x = layers.MaxPooling1D(pool_size=cnn_pool)(x)  # (T/cnn_pool, f)
        x = layers.Dropout(dropout)(x)

    # Now x: (T', F_last). Make sure its feature dim = d_model
    x = layers.Dense(d_model)(x)                      # (T', d_model)
    x = layers.LayerNormalization(epsilon=1e-6)(x)

    # ---- TRANSFORMER ENCODER BLOCKS OVER TIME ----
    for _ in range(num_layers):
        # Multi-head self-attention (time axis as sequence)
        attn_output = layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=d_model,
            dropout=dropout
        )(x, x)                                       # (T', d_model)

        # Residual + norm
        x = layers.Add()([x, attn_output])
        x = layers.LayerNormalization(epsilon=1e-6)(x)

        # Feed-forward sublayer
        ffn = layers.Dense(ff_dim, activation="relu")(x)
        ffn = layers.Dropout(dropout)(ffn)
        ffn = layers.Dense(d_model)(ffn)

        # Residual + norm
        x = layers.Add()([x, ffn])
        x = layers.LayerNormalization(epsilon=1e-6)(x)

    # ---- CLASSIFICATION HEAD ----
    # Global average over time
    x = layers.GlobalAveragePooling1D()(x)            # (d_model,)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(dropout)(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[
            keras.metrics.BinaryAccuracy(name="acc"),
            keras.metrics.AUC(name="auc"),
        ],
    )
    return model



# =========================
# Metric helpers (for TEST)
# =========================
def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
    return tn / (tn + fp) if (tn + fp) > 0 else 0.0

def youden_threshold_from_probs(y_true, y_prob):
    """Return best threshold and J on this set."""
    if len(np.unique(y_true)) < 2:
        return 0.5, 0.0
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    j = tpr - fpr
    i = int(np.argmax(j))
    return float(thr[i]), float(j[i])

def mean_std(x):
    x = np.asarray(x, dtype=float)
    return np.nanmean(x), np.nanstd(x)

# =========================
# 7-fold CV by patient ID
# =========================
skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

# Lists for TEST metrics (@0.5 and @Youden-J)
AUC_list,  ACC_list,  PREC_list,  REC_list,  F1_list,  SPEC_list  = [], [], [], [], [], []
AUC_J_list, ACC_J_list, PREC_J_list, REC_J_list, F1_J_list, SPEC_J_list = [], [], [], [], [], []

rows = []

print(f"\n=== {K_FOLDS}-Fold CV (by patient ID) ===")
for fold_idx, (train_idx, test_idx) in enumerate(skf.split(all_ids, id_labels), start=1):
    ids_train_full = [all_ids[i] for i in train_idx]
    ids_test       = [all_ids[i] for i in test_idx]

    # small validation split from training IDs (for checkpointing)
    train_labels_full = np.array([1 if pid in POS_PATIENTS else 0 for pid in ids_train_full], dtype=int)
    try:
        ids_tr, ids_val = train_test_split(
            ids_train_full, test_size=0.10, random_state=SEED, stratify=train_labels_full
        )
    except ValueError:
        ids_tr, ids_val = train_test_split(ids_train_full, test_size=0.10, random_state=SEED, shuffle=True)
        print(f"(Fold {fold_idx}) Warning: stratified VAL split failed; using unstratified split.")

    # Files for each split
    train_files = [f for pid in ids_tr  for f in id_to_files[pid]]
    val_files   = [f for pid in ids_val for f in id_to_files[pid]]
    test_files  = [f for pid in ids_test for f in id_to_files[pid]]

    def split_summary(name, ids, files):
        ys = np.array([label_for_file(f) for f in files], dtype=int)
        print(f"{name:>6} | ids: {len(ids):4d} | files: {len(files):5d} | pos files: {(ys==1).sum():4d} | neg files: {(ys==0).sum():4d}")

    print(f"\n--- Fold {fold_idx}/{K_FOLDS} ---")
    split_summary("train", ids_tr,  train_files)
    split_summary("val",   ids_val, val_files)
    split_summary("test",  ids_test, test_files)

    # Generators
    train_gen = ImageSequence(train_files, batch_size=BATCH_SIZE, shuffle=True,
                              add_noise=TRAIN_ADD_GAUSS_NOISE,
                              noise_frac=TRAIN_NOISE_FRAC,
                              noise_prob=TRAIN_NOISE_PROB)
    val_gen   = ImageSequence(val_files,   batch_size=BATCH_SIZE, shuffle=False, add_noise=False)
    test_gen  = ImageSequence(test_files,  batch_size=BATCH_SIZE, shuffle=False, add_noise=False)

    # Train & pick best by val_loss
    model = build_model()
    best_path = BEST_MODEL_TPL.format(fold_idx)
    ckpt = keras.callbacks.ModelCheckpoint(best_path, monitor="val_loss", mode="min",
                                           save_best_only=True, verbose=1)
    _ = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS, callbacks=[ckpt], verbose=1)

    # Evaluate on TEST
    best_model = keras.models.load_model(best_path)
    test_probs = best_model.predict(test_gen, verbose=0).ravel().astype(float)
    test_y     = np.array([label_for_file(f) for f in test_gen.files], dtype=int)

    # AUC (threshold-free)
    try:
        test_auc = roc_auc_score(test_y, test_probs)
    except ValueError:
        test_auc = float('nan')

    # --- Threshold 0.5 ---
    y_pred_05 = (test_probs >= 0.5).astype(int)
    acc_05  = accuracy_score(test_y, y_pred_05)
    prec_05 = precision_score(test_y, y_pred_05, zero_division=0)
    rec_05  = recall_score(test_y, y_pred_05, zero_division=0)
    f1_05   = f1_score(test_y, y_pred_05, zero_division=0)
    spec_05 = specificity_score(test_y, y_pred_05)

    # --- Youden-J threshold on TEST ---
    t_star, J_val = youden_threshold_from_probs(test_y, test_probs)
    y_pred_J = (test_probs >= t_star).astype(int)
    acc_J  = accuracy_score(test_y, y_pred_J)
    prec_J = precision_score(test_y, y_pred_J, zero_division=0)
    rec_J  = recall_score(test_y, y_pred_J, zero_division=0)
    f1_J   = f1_score(test_y, y_pred_J, zero_division=0)
    spec_J = specificity_score(test_y, y_pred_J)

    # collect lists
    AUC_list.append(test_auc); ACC_list.append(acc_05);   PREC_list.append(prec_05)
    REC_list.append(rec_05);   F1_list.append(f1_05);     SPEC_list.append(spec_05)

    AUC_J_list.append(test_auc); ACC_J_list.append(acc_J);   PREC_J_list.append(prec_J)
    REC_J_list.append(rec_J);    F1_J_list.append(f1_J);     SPEC_J_list.append(spec_J)

    print(f"Fold {fold_idx} | TEST@0.5  ACC={acc_05:.4f} | PREC={prec_05:.4f} | "
          f"REC={rec_05:.4f} | F1={f1_05:.4f} | AUC={test_auc:.4f} | SPEC={spec_05:.4f} | n={len(test_y)}")
    print(f"Fold {fold_idx} | TEST@J    ACC={acc_J:.4f} | PREC={prec_J:.4f} | "
          f"REC={rec_J:.4f} | F1={f1_J:.4f} | AUC={test_auc:.4f} | SPEC={spec_J:.4f} | thr={t_star:.4f}, J={J_val:.4f}")
    print("Confusion matrix (@0.5):\n", confusion_matrix(test_y, y_pred_05))
    print("Classification report (@0.5):\n", classification_report(test_y, y_pred_05, digits=3))

    rows.append({
        "fold": fold_idx,
        "train_files": len(train_files),
        "val_files": len(val_files),
        "test_files": len(test_files),

        "ACC_0.5": acc_05,
        "PREC_0.5": prec_05,
        "REC_0.5": rec_05,
        "F1_0.5": f1_05,
        "AUC": test_auc,
        "SPEC_0.5": spec_05,

        "thr_J": t_star,
        "J": J_val,
        "ACC_J": acc_J,
        "PREC_J": prec_J,
        "REC_J": rec_J,
        "F1_J": f1_J,
        "SPEC_J": spec_J,
    })

# =========================
# Summary across folds
# =========================
print("\n=== TEST metrics per fold — threshold 0.5 ===")
print("AUC :", [None if np.isnan(x) else round(x,4) for x in AUC_list])
print("ACC :", [round(x,4) for x in ACC_list])
print("PREC:", [round(x,4) for x in PREC_list])
print("REC :", [round(x,4) for x in REC_list])
print("SPEC:", [round(x,4) for x in SPEC_list])
print("F1  :", [round(x,4) for x in F1_list])

print("\n=== TEST metrics per fold — Youden-J (on TEST) ===")
print("AUC@J :", [None if np.isnan(x) else round(x,4) for x in AUC_J_list])
print("ACC@J :", [round(x,4) for x in ACC_J_list])
print("PREC@J:", [round(x,4) for x in PREC_J_list])
print("REC@J :", [round(x,4) for x in REC_J_list])
print("SPEC@J:", [round(x,4) for x in SPEC_J_list])
print("F1@J  :", [round(x,4) for x in F1_J_list])

mAUC,  sAUC  = mean_std(AUC_list)
mACC,  sACC  = mean_std(ACC_list)
mPREC, sPREC = mean_std(PREC_list)
mREC,  sREC  = mean_std(REC_list)
mF1,   sF1   = mean_std(F1_list)
mSPEC, sSPEC = mean_std(SPEC_list)

print("\n=== Mean ± SD across folds (TEST) — 0.5 ===")
print(f"{'AUC':>12}: {mAUC:.4f} ± {sAUC:.4f}")
print(f"{'ACC':>12}: {mACC:.4f} ± {sACC:.4f}")
print(f"{'Precision':>12}: {mPREC:.4f} ± {sPREC:.4f}")
print(f"{'Recall':>12}: {mREC:.4f} ± {sREC:.4f}")
print(f"{'Specificity':>12}: {mSPEC:.4f} ± {sSPEC:.4f}")
print(f"{'F1':>12}: {mF1:.4f} ± {sF1:.4f}")

mAUC_J,  sAUC_J  = mean_std(AUC_J_list)
mACC_J,  sACC_J  = mean_std(ACC_J_list)
mPREC_J, sPREC_J = mean_std(PREC_J_list)
mREC_J,  sREC_J  = mean_std(REC_J_list)
mF1_J,   sF1_J   = mean_std(F1_J_list)
mSPEC_J, sSPEC_J = mean_std(SPEC_J_list)

print("\n=== Mean ± SD across folds (TEST) — Youden-J (on TEST) ===")
print(f"{'AUC@J':>12}: {mAUC_J:.4f} ± {sAUC_J:.4f}")
print(f"{'ACC@J':>12}: {mACC_J:.4f} ± {sACC_J:.4f}")
print(f"{'Precision@J':>12}: {mPREC_J:.4f} ± {sPREC_J:.4f}")
print(f"{'Recall@J':>12}: {mREC_J:.4f} ± {sREC_J:.4f}")
print(f"{'Specificity@J':>12}: {mSPEC_J:.4f} ± {sSPEC_J:.4f}")
print(f"{'F1@J':>12}: {mF1_J:.4f} ± {sF1_J:.4f}")

metrics_df = pd.DataFrame(rows)
metrics_df.to_csv("cv7_img_fold_metrics.csv", index=False)
print("\nSaved TEST-only per-fold metrics to cv7_img_fold_metrics.csv")
# Out:
# Total IDs: 42 | Pos IDs: 13 | Neg IDs: 29
# TARGET_W=6 (non-Time columns)
# Fixed input height after de-dup (all IDs): H=360
# Normalization: NONE. De-dup: remove consecutive duplicate rows (row-wise).
#
# === 7-Fold CV (by patient ID) ===
#
# --- Fold 1/7 ---
#  train | ids:   32 | files:   808 | pos files:  320 | neg files:  488
#    val | ids:    4 | files:    85 | pos files:    6 | neg files:   79
#   test | ids:    6 | files:   131 | pos files:   45 | neg files:   86
# Epoch 1/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - acc: 0.5616 - auc: 0.5244 - loss: 0.7117
# Epoch 1: val_loss improved from inf to 0.39907, saving model to best_fold_01.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 66s 135ms/step - acc: 0.5618 - auc: 0.5247 - loss: 0.7115 - val_acc: 0.8588 - val_auc: 0.4283 - val_loss: 0.3991
# Epoch 2/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.5901 - auc: 0.5838 - loss: 0.6683
# Epoch 2: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.5905 - auc: 0.5842 - loss: 0.6681 - val_acc: 0.7882 - val_auc: 0.4546 - val_loss: 0.5319
# Epoch 3/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6018 - auc: 0.5874 - loss: 0.6735
# Epoch 3: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6022 - auc: 0.5878 - loss: 0.6732 - val_acc: 0.7647 - val_auc: 0.4599 - val_loss: 0.5748
# Epoch 4/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6011 - auc: 0.6181 - loss: 0.6468
# Epoch 4: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6014 - auc: 0.6185 - loss: 0.6466 - val_acc: 0.7765 - val_auc: 0.6530 - val_loss: 0.6348
# Epoch 5/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6474 - auc: 0.6818 - loss: 0.6058
# Epoch 5: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6477 - auc: 0.6818 - loss: 0.6059 - val_acc: 0.8588 - val_auc: 0.6508 - val_loss: 0.4866
# Epoch 6/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6102 - auc: 0.6344 - loss: 0.6209
# Epoch 6: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6104 - auc: 0.6347 - loss: 0.6208 - val_acc: 0.8118 - val_auc: 0.7890 - val_loss: 0.6100
# Epoch 7/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6565 - auc: 0.6580 - loss: 0.6041
# Epoch 7: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6556 - auc: 0.6596 - loss: 0.6041 - val_acc: 0.8588 - val_auc: 0.6973 - val_loss: 0.5281
# Epoch 8/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6375 - auc: 0.6760 - loss: 0.6099
# Epoch 8: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6384 - auc: 0.6771 - loss: 0.6092 - val_acc: 0.8000 - val_auc: 0.7089 - val_loss: 0.6645
# Epoch 9/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6715 - auc: 0.7280 - loss: 0.5606
# Epoch 9: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6713 - auc: 0.7282 - loss: 0.5606 - val_acc: 0.4353 - val_auc: 0.6319 - val_loss: 0.8119
# Epoch 10/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6467 - auc: 0.7060 - loss: 0.5921
# Epoch 10: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6472 - auc: 0.7069 - loss: 0.5910 - val_acc: 0.5882 - val_auc: 0.6551 - val_loss: 0.6290
# Epoch 11/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.6805 - auc: 0.7672 - loss: 0.5319
# Epoch 11: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6803 - auc: 0.7667 - loss: 0.5322 - val_acc: 0.6471 - val_auc: 0.6361 - val_loss: 0.6298
# Epoch 12/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6755 - auc: 0.7222 - loss: 0.5720
# Epoch 12: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6755 - auc: 0.7223 - loss: 0.5720 - val_acc: 0.8706 - val_auc: 0.6213 - val_loss: 0.4333
# Epoch 13/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6991 - auc: 0.7512 - loss: 0.5489
# Epoch 13: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6991 - auc: 0.7512 - loss: 0.5489 - val_acc: 0.6824 - val_auc: 0.6624 - val_loss: 0.6039
# Epoch 14/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6855 - auc: 0.7795 - loss: 0.5293
# Epoch 14: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6853 - auc: 0.7785 - loss: 0.5298 - val_acc: 0.8941 - val_auc: 0.6192 - val_loss: 0.5548
# Epoch 15/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6989 - auc: 0.7899 - loss: 0.5139
# Epoch 15: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6987 - auc: 0.7890 - loss: 0.5143 - val_acc: 0.8824 - val_auc: 0.5802 - val_loss: 0.5946
# Epoch 16/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6787 - auc: 0.7653 - loss: 0.5185
# Epoch 16: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6787 - auc: 0.7652 - loss: 0.5187 - val_acc: 0.4824 - val_auc: 0.5781 - val_loss: 0.8440
# Epoch 17/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6654 - auc: 0.7638 - loss: 0.5255
# Epoch 17: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6665 - auc: 0.7642 - loss: 0.5251 - val_acc: 0.5882 - val_auc: 0.5770 - val_loss: 0.6924
# Epoch 18/100
# 255/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7189 - auc: 0.7964 - loss: 0.4961
# Epoch 18: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7187 - auc: 0.7955 - loss: 0.4973 - val_acc: 0.6118 - val_auc: 0.6688 - val_loss: 0.6621
# Epoch 19/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6868 - auc: 0.8052 - loss: 0.4949
# Epoch 19: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6870 - auc: 0.8044 - loss: 0.4956 - val_acc: 0.7882 - val_auc: 0.5549 - val_loss: 0.6031
# Epoch 20/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6886 - auc: 0.7703 - loss: 0.5378
# Epoch 20: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6894 - auc: 0.7705 - loss: 0.5370 - val_acc: 0.5059 - val_auc: 0.5759 - val_loss: 0.9400
# Epoch 21/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6729 - auc: 0.7372 - loss: 0.5568
# Epoch 21: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6732 - auc: 0.7377 - loss: 0.5564 - val_acc: 0.8588 - val_auc: 0.5791 - val_loss: 0.5176
# Epoch 22/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7129 - auc: 0.7729 - loss: 0.5335
# Epoch 22: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7131 - auc: 0.7732 - loss: 0.5326 - val_acc: 0.7529 - val_auc: 0.5823 - val_loss: 0.6904
# Epoch 23/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7278 - auc: 0.7912 - loss: 0.5252
# Epoch 23: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7279 - auc: 0.7913 - loss: 0.5251 - val_acc: 0.5059 - val_auc: 0.5707 - val_loss: 0.9409
# Epoch 24/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6916 - auc: 0.7749 - loss: 0.5204
# Epoch 24: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6916 - auc: 0.7747 - loss: 0.5203 - val_acc: 0.5765 - val_auc: 0.5907 - val_loss: 0.9234
# Epoch 25/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7301 - auc: 0.8063 - loss: 0.4967
# Epoch 25: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7299 - auc: 0.8061 - loss: 0.4969 - val_acc: 0.8824 - val_auc: 0.5443 - val_loss: 0.5534
# Epoch 26/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7307 - auc: 0.7951 - loss: 0.4974
# Epoch 26: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7309 - auc: 0.7954 - loss: 0.4973 - val_acc: 0.8000 - val_auc: 0.5633 - val_loss: 0.6367
# Epoch 27/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6877 - auc: 0.7510 - loss: 0.5189
# Epoch 27: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6882 - auc: 0.7517 - loss: 0.5185 - val_acc: 0.7412 - val_auc: 0.5612 - val_loss: 0.6708
# Epoch 28/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7082 - auc: 0.7604 - loss: 0.5136
# Epoch 28: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7087 - auc: 0.7614 - loss: 0.5130 - val_acc: 0.6000 - val_auc: 0.5612 - val_loss: 0.7533
# Epoch 29/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7637 - auc: 0.8289 - loss: 0.4717
# Epoch 29: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7632 - auc: 0.8285 - loss: 0.4721 - val_acc: 0.7529 - val_auc: 0.5295 - val_loss: 0.8781
# Epoch 30/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7339 - auc: 0.8114 - loss: 0.4807
# Epoch 30: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7338 - auc: 0.8112 - loss: 0.4808 - val_acc: 0.7765 - val_auc: 0.5042 - val_loss: 0.8888
# Epoch 31/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7133 - auc: 0.7922 - loss: 0.4950
# Epoch 31: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7133 - auc: 0.7919 - loss: 0.4952 - val_acc: 0.7412 - val_auc: 0.5359 - val_loss: 1.1083
# Epoch 32/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7291 - auc: 0.7833 - loss: 0.4983
# Epoch 32: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7291 - auc: 0.7836 - loss: 0.4981 - val_acc: 0.4000 - val_auc: 0.5496 - val_loss: 1.5827
# Epoch 33/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7443 - auc: 0.7706 - loss: 0.5139
# Epoch 33: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7437 - auc: 0.7707 - loss: 0.5139 - val_acc: 0.6941 - val_auc: 0.5369 - val_loss: 0.9088
# Epoch 34/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7321 - auc: 0.7905 - loss: 0.4926
# Epoch 34: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7322 - auc: 0.7905 - loss: 0.4928 - val_acc: 0.8824 - val_auc: 0.4884 - val_loss: 0.5780
# Epoch 35/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7284 - auc: 0.7969 - loss: 0.4845
# Epoch 35: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7282 - auc: 0.7966 - loss: 0.4849 - val_acc: 0.8118 - val_auc: 0.3871 - val_loss: 0.7758
# Epoch 36/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7359 - auc: 0.7844 - loss: 0.5032
# Epoch 36: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7355 - auc: 0.7841 - loss: 0.5032 - val_acc: 0.2824 - val_auc: 0.5570 - val_loss: 1.3034
# Epoch 37/100
# 255/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7224 - auc: 0.7838 - loss: 0.5142
# Epoch 37: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7212 - auc: 0.7832 - loss: 0.5144 - val_acc: 0.7412 - val_auc: 0.4641 - val_loss: 1.0773
# Epoch 38/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7153 - auc: 0.7724 - loss: 0.5061
# Epoch 38: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7155 - auc: 0.7726 - loss: 0.5060 - val_acc: 0.8353 - val_auc: 0.5116 - val_loss: 0.5728
# Epoch 39/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6574 - auc: 0.7173 - loss: 0.5614
# Epoch 39: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6592 - auc: 0.7192 - loss: 0.5594 - val_acc: 0.6353 - val_auc: 0.4884 - val_loss: 0.8353
# Epoch 40/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7237 - auc: 0.8193 - loss: 0.4769
# Epoch 40: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7252 - auc: 0.8194 - loss: 0.4769 - val_acc: 0.7059 - val_auc: 0.4979 - val_loss: 0.7759
# Epoch 41/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7581 - auc: 0.7896 - loss: 0.4984
# Epoch 41: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7576 - auc: 0.7899 - loss: 0.4980 - val_acc: 0.7765 - val_auc: 0.4124 - val_loss: 1.0451
# Epoch 42/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7406 - auc: 0.8087 - loss: 0.4826
# Epoch 42: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7403 - auc: 0.8083 - loss: 0.4827 - val_acc: 0.6118 - val_auc: 0.4810 - val_loss: 1.2713
# Epoch 43/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7313 - auc: 0.7847 - loss: 0.4932
# Epoch 43: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7317 - auc: 0.7850 - loss: 0.4931 - val_acc: 0.7765 - val_auc: 0.3755 - val_loss: 0.8895
# Epoch 44/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7266 - auc: 0.8071 - loss: 0.4834
# Epoch 44: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7272 - auc: 0.8070 - loss: 0.4834 - val_acc: 0.7529 - val_auc: 0.3586 - val_loss: 0.8835
# Epoch 45/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6882 - auc: 0.7432 - loss: 0.5275
# Epoch 45: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6884 - auc: 0.7433 - loss: 0.5274 - val_acc: 0.6588 - val_auc: 0.4589 - val_loss: 0.9930
# Epoch 46/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7455 - auc: 0.8202 - loss: 0.4770
# Epoch 46: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7453 - auc: 0.8197 - loss: 0.4774 - val_acc: 0.6588 - val_auc: 0.4494 - val_loss: 1.3229
# Epoch 47/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7212 - auc: 0.7919 - loss: 0.5146
# Epoch 47: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7219 - auc: 0.7921 - loss: 0.5136 - val_acc: 0.7882 - val_auc: 0.4831 - val_loss: 0.9715
# Epoch 48/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7296 - auc: 0.7820 - loss: 0.4977
# Epoch 48: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7294 - auc: 0.7817 - loss: 0.4980 - val_acc: 0.8118 - val_auc: 0.5011 - val_loss: 0.6754
# Epoch 49/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7498 - auc: 0.7955 - loss: 0.4936
# Epoch 49: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7497 - auc: 0.7955 - loss: 0.4936 - val_acc: 0.8000 - val_auc: 0.5095 - val_loss: 0.6261
# Epoch 50/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7697 - auc: 0.8070 - loss: 0.4537
# Epoch 50: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7697 - auc: 0.8070 - loss: 0.4538 - val_acc: 0.8118 - val_auc: 0.4705 - val_loss: 0.6902
# Epoch 51/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7571 - auc: 0.8134 - loss: 0.4864
# Epoch 51: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7568 - auc: 0.8133 - loss: 0.4864 - val_acc: 0.6824 - val_auc: 0.5211 - val_loss: 0.7859
# Epoch 52/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7671 - auc: 0.8115 - loss: 0.4497
# Epoch 52: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7665 - auc: 0.8110 - loss: 0.4504 - val_acc: 0.8471 - val_auc: 0.5011 - val_loss: 0.6297
# Epoch 53/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7423 - auc: 0.8039 - loss: 0.4699
# Epoch 53: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7423 - auc: 0.8039 - loss: 0.4698 - val_acc: 0.7647 - val_auc: 0.5274 - val_loss: 0.9909
# Epoch 54/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7234 - auc: 0.7791 - loss: 0.4902
# Epoch 54: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7236 - auc: 0.7792 - loss: 0.4902 - val_acc: 0.8471 - val_auc: 0.5116 - val_loss: 0.6446
# Epoch 55/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7448 - auc: 0.8314 - loss: 0.4673
# Epoch 55: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7447 - auc: 0.8313 - loss: 0.4673 - val_acc: 0.7647 - val_auc: 0.6435 - val_loss: 0.6387
# Epoch 56/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7289 - auc: 0.7870 - loss: 0.4938
# Epoch 56: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7295 - auc: 0.7876 - loss: 0.4932 - val_acc: 0.7765 - val_auc: 0.4768 - val_loss: 0.8020
# Epoch 57/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7296 - auc: 0.8033 - loss: 0.5009
# Epoch 57: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7305 - auc: 0.8040 - loss: 0.4994 - val_acc: 0.8941 - val_auc: 0.4937 - val_loss: 0.5486
# Epoch 58/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7332 - auc: 0.7894 - loss: 0.4950
# Epoch 58: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7336 - auc: 0.7896 - loss: 0.4945 - val_acc: 0.8706 - val_auc: 0.4504 - val_loss: 0.5864
# Epoch 59/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7630 - auc: 0.8218 - loss: 0.4475
# Epoch 59: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7629 - auc: 0.8219 - loss: 0.4476 - val_acc: 0.9176 - val_auc: 0.5411 - val_loss: 0.5403
# Epoch 60/100
# 267/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7341 - auc: 0.7901 - loss: 0.4853
# Epoch 60: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7344 - auc: 0.7901 - loss: 0.4852 - val_acc: 0.8235 - val_auc: 0.4589 - val_loss: 0.6865
# Epoch 61/100
# 255/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7653 - auc: 0.7966 - loss: 0.4782
# Epoch 61: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7649 - auc: 0.7974 - loss: 0.4775 - val_acc: 0.8588 - val_auc: 0.5243 - val_loss: 0.6217
# Epoch 62/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7825 - auc: 0.8481 - loss: 0.4173
# Epoch 62: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7821 - auc: 0.8474 - loss: 0.4182 - val_acc: 0.8471 - val_auc: 0.5306 - val_loss: 0.6419
# Epoch 63/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7490 - auc: 0.7875 - loss: 0.4681
# Epoch 63: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7492 - auc: 0.7880 - loss: 0.4678 - val_acc: 0.9176 - val_auc: 0.4483 - val_loss: 0.5606
# Epoch 64/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7609 - auc: 0.8169 - loss: 0.4318
# Epoch 64: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7608 - auc: 0.8165 - loss: 0.4323 - val_acc: 0.8824 - val_auc: 0.5464 - val_loss: 0.6389
# Epoch 65/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7672 - auc: 0.8156 - loss: 0.4480
# Epoch 65: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7669 - auc: 0.8156 - loss: 0.4484 - val_acc: 0.7059 - val_auc: 0.5770 - val_loss: 0.7540
# Epoch 66/100
# 265/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7461 - auc: 0.8120 - loss: 0.4621
# Epoch 66: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7463 - auc: 0.8124 - loss: 0.4618 - val_acc: 0.7059 - val_auc: 0.5643 - val_loss: 0.7643
# Epoch 67/100
# 264/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7569 - auc: 0.8174 - loss: 0.4499
# Epoch 67: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7572 - auc: 0.8173 - loss: 0.4499 - val_acc: 0.8353 - val_auc: 0.4557 - val_loss: 0.6310
# Epoch 68/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7491 - auc: 0.8252 - loss: 0.4596
# Epoch 68: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7491 - auc: 0.8251 - loss: 0.4595 - val_acc: 0.8941 - val_auc: 0.5000 - val_loss: 0.5856
# Epoch 69/100
# 260/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7701 - auc: 0.8297 - loss: 0.4260
# Epoch 69: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7698 - auc: 0.8293 - loss: 0.4265 - val_acc: 0.8706 - val_auc: 0.5042 - val_loss: 0.6234
# Epoch 70/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7836 - auc: 0.7988 - loss: 0.4410
# Epoch 70: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7831 - auc: 0.7991 - loss: 0.4411 - val_acc: 0.8000 - val_auc: 0.5000 - val_loss: 0.7538
# Epoch 71/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7750 - auc: 0.8370 - loss: 0.4338
# Epoch 71: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7745 - auc: 0.8364 - loss: 0.4346 - val_acc: 0.9176 - val_auc: 0.5654 - val_loss: 0.5693
# Epoch 72/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7373 - auc: 0.7659 - loss: 0.4735
# Epoch 72: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7375 - auc: 0.7672 - loss: 0.4731 - val_acc: 0.9176 - val_auc: 0.5105 - val_loss: 0.5742
# Epoch 73/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7879 - auc: 0.8088 - loss: 0.4629
# Epoch 73: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7880 - auc: 0.8091 - loss: 0.4626 - val_acc: 0.8706 - val_auc: 0.4409 - val_loss: 0.5540
# Epoch 74/100
# 258/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7807 - auc: 0.8352 - loss: 0.4272
# Epoch 74: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7804 - auc: 0.8350 - loss: 0.4275 - val_acc: 0.9059 - val_auc: 0.4346 - val_loss: 0.5783
# Epoch 75/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7620 - auc: 0.8143 - loss: 0.4572
# Epoch 75: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7617 - auc: 0.8140 - loss: 0.4575 - val_acc: 0.8353 - val_auc: 0.5137 - val_loss: 0.6573
# Epoch 76/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7439 - auc: 0.8263 - loss: 0.4480
# Epoch 76: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7441 - auc: 0.8262 - loss: 0.4480 - val_acc: 0.9059 - val_auc: 0.5190 - val_loss: 0.5774
# Epoch 77/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7634 - auc: 0.8181 - loss: 0.4428
# Epoch 77: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7634 - auc: 0.8180 - loss: 0.4430 - val_acc: 0.9176 - val_auc: 0.4610 - val_loss: 0.5633
# Epoch 78/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7738 - auc: 0.8208 - loss: 0.4516
# Epoch 78: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7736 - auc: 0.8209 - loss: 0.4516 - val_acc: 0.7529 - val_auc: 0.4810 - val_loss: 0.6732
# Epoch 79/100
# 259/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7377 - auc: 0.8030 - loss: 0.4691
# Epoch 79: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7380 - auc: 0.8035 - loss: 0.4685 - val_acc: 0.8000 - val_auc: 0.5000 - val_loss: 0.8534
# Epoch 80/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7693 - auc: 0.8349 - loss: 0.4232
# Epoch 80: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7691 - auc: 0.8350 - loss: 0.4237 - val_acc: 0.7412 - val_auc: 0.5095 - val_loss: 0.7491
# Epoch 81/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7626 - auc: 0.8409 - loss: 0.4419
# Epoch 81: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7626 - auc: 0.8409 - loss: 0.4419 - val_acc: 0.7176 - val_auc: 0.5042 - val_loss: 0.6826
# Epoch 82/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7780 - auc: 0.8557 - loss: 0.4328
# Epoch 82: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7780 - auc: 0.8546 - loss: 0.4333 - val_acc: 0.7765 - val_auc: 0.4747 - val_loss: 0.6647
# Epoch 83/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7578 - auc: 0.8165 - loss: 0.4533
# Epoch 83: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7579 - auc: 0.8169 - loss: 0.4530 - val_acc: 0.8471 - val_auc: 0.4304 - val_loss: 0.5962
# Epoch 84/100
# 268/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7542 - auc: 0.8386 - loss: 0.4368
# Epoch 84: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7543 - auc: 0.8386 - loss: 0.4369 - val_acc: 0.7765 - val_auc: 0.5032 - val_loss: 0.6629
# Epoch 85/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7657 - auc: 0.8177 - loss: 0.4536
# Epoch 85: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7658 - auc: 0.8180 - loss: 0.4534 - val_acc: 0.8471 - val_auc: 0.4420 - val_loss: 0.6132
# Epoch 86/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7636 - auc: 0.8427 - loss: 0.4386
# Epoch 86: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7632 - auc: 0.8417 - loss: 0.4388 - val_acc: 0.7176 - val_auc: 0.5243 - val_loss: 0.8100
# Epoch 87/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7883 - auc: 0.8575 - loss: 0.4183
# Epoch 87: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7880 - auc: 0.8569 - loss: 0.4190 - val_acc: 0.8235 - val_auc: 0.4810 - val_loss: 0.6287
# Epoch 88/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7727 - auc: 0.8099 - loss: 0.4549
# Epoch 88: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7725 - auc: 0.8103 - loss: 0.4546 - val_acc: 0.6235 - val_auc: 0.5095 - val_loss: 0.8684
# Epoch 89/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7782 - auc: 0.8410 - loss: 0.4238
# Epoch 89: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7781 - auc: 0.8409 - loss: 0.4238 - val_acc: 0.7882 - val_auc: 0.5264 - val_loss: 0.6567
# Epoch 90/100
# 263/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7543 - auc: 0.8358 - loss: 0.4489
# Epoch 90: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7544 - auc: 0.8358 - loss: 0.4488 - val_acc: 0.8235 - val_auc: 0.4061 - val_loss: 0.6385
# Epoch 91/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7763 - auc: 0.8527 - loss: 0.4125
# Epoch 91: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7761 - auc: 0.8520 - loss: 0.4136 - val_acc: 0.9176 - val_auc: 0.4789 - val_loss: 0.5651
# Epoch 92/100
# 266/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7828 - auc: 0.8411 - loss: 0.4348
# Epoch 92: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7827 - auc: 0.8413 - loss: 0.4345 - val_acc: 0.6706 - val_auc: 0.4873 - val_loss: 0.8322
# Epoch 93/100
# 269/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7777 - auc: 0.8555 - loss: 0.4300
# Epoch 93: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7778 - auc: 0.8555 - loss: 0.4300 - val_acc: 0.9059 - val_auc: 0.4093 - val_loss: 0.5398
# Epoch 94/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7127 - auc: 0.7971 - loss: 0.4844
# Epoch 94: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7140 - auc: 0.7979 - loss: 0.4835 - val_acc: 0.5647 - val_auc: 0.4968 - val_loss: 0.9404
# Epoch 95/100
# 256/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8068 - auc: 0.8460 - loss: 0.4002
# Epoch 95: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.8062 - auc: 0.8462 - loss: 0.4009 - val_acc: 0.5647 - val_auc: 0.5158 - val_loss: 0.8725
# Epoch 96/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8088 - auc: 0.8572 - loss: 0.4040
# Epoch 96: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.8085 - auc: 0.8572 - loss: 0.4042 - val_acc: 0.6235 - val_auc: 0.4778 - val_loss: 1.0066
# Epoch 97/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7650 - auc: 0.8299 - loss: 0.4449
# Epoch 97: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7650 - auc: 0.8299 - loss: 0.4448 - val_acc: 0.6471 - val_auc: 0.5179 - val_loss: 0.7961
# Epoch 98/100
# 257/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7882 - auc: 0.8573 - loss: 0.4046
# Epoch 98: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7875 - auc: 0.8570 - loss: 0.4056 - val_acc: 0.5765 - val_auc: 0.4747 - val_loss: 0.7710
# Epoch 99/100
# 262/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7746 - auc: 0.8212 - loss: 0.4401
# Epoch 99: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7746 - auc: 0.8217 - loss: 0.4399 - val_acc: 0.5647 - val_auc: 0.4388 - val_loss: 0.8777
# Epoch 100/100
# 261/270 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8176 - auc: 0.8753 - loss: 0.3811
# Epoch 100: val_loss did not improve from 0.39907
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.8172 - auc: 0.8750 - loss: 0.3819 - val_acc: 0.5529 - val_auc: 0.4536 - val_loss: 1.0681
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 1 | TEST@0.5  ACC=0.6565 | PREC=0.0000 | REC=0.0000 | F1=0.0000 | AUC=0.6948 | SPEC=1.0000 | n=131
# Fold 1 | TEST@J    ACC=0.7405 | PREC=0.5775 | REC=0.9111 | F1=0.7069 | AUC=0.6948 | SPEC=0.6512 | thr=0.1671, J=0.5623
# Confusion matrix (@0.5):
#  [[86  0]
#  [45  0]]
# Classification report (@0.5):
#                precision    recall  f1-score   support
#
#            0      0.656     1.000     0.793        86
#            1      0.000     0.000     0.000        45
#
#     accuracy                          0.656       131
#    macro avg      0.328     0.500     0.396       131
# weighted avg      0.431     0.656     0.520       131
#
#
# --- Fold 2/7 ---
#  train | ids:   32 | files:   763 | pos files:  322 | neg files:  441
#    val | ids:    4 | files:   149 | pos files:    4 | neg files:  145
#   test | ids:    6 | files:   112 | pos files:   45 | neg files:   67
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.5436 - auc: 0.5217 - loss: 0.7105
# Epoch 1: val_loss improved from inf to 0.42746, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 33s 55ms/step - acc: 0.5441 - auc: 0.5227 - loss: 0.7100 - val_acc: 0.9732 - val_auc: 0.4440 - val_loss: 0.4275
# Epoch 2/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5701 - auc: 0.5856 - loss: 0.6741
# Epoch 2: val_loss did not improve from 0.42746
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.5700 - auc: 0.5855 - loss: 0.6740 - val_acc: 0.9128 - val_auc: 0.2509 - val_loss: 0.4491
# Epoch 3/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5811 - auc: 0.5840 - loss: 0.6503
# Epoch 3: val_loss did not improve from 0.42746
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.5807 - auc: 0.5843 - loss: 0.6508 - val_acc: 0.9732 - val_auc: 0.3362 - val_loss: 0.4431
# Epoch 4/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5863 - auc: 0.6097 - loss: 0.6440
# Epoch 4: val_loss did not improve from 0.42746
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.5867 - auc: 0.6104 - loss: 0.6437 - val_acc: 0.6711 - val_auc: 0.2716 - val_loss: 0.4914
# Epoch 5/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6000 - auc: 0.6606 - loss: 0.6201
# Epoch 5: val_loss improved from 0.42746 to 0.41610, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.5997 - auc: 0.6602 - loss: 0.6202 - val_acc: 0.9195 - val_auc: 0.1629 - val_loss: 0.4161
# Epoch 6/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6122 - auc: 0.6899 - loss: 0.6016
# Epoch 6: val_loss did not improve from 0.41610
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6128 - auc: 0.6901 - loss: 0.6013 - val_acc: 0.8389 - val_auc: 0.0759 - val_loss: 0.5233
# Epoch 7/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6313 - auc: 0.6988 - loss: 0.6008
# Epoch 7: val_loss improved from 0.41610 to 0.39760, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6319 - auc: 0.6995 - loss: 0.6004 - val_acc: 0.9060 - val_auc: 0.0897 - val_loss: 0.3976
# Epoch 8/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6598 - auc: 0.7529 - loss: 0.5552
# Epoch 8: val_loss improved from 0.39760 to 0.34957, saving model to best_fold_02.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6601 - auc: 0.7530 - loss: 0.5552 - val_acc: 0.9463 - val_auc: 0.1207 - val_loss: 0.3496
# Epoch 9/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6710 - auc: 0.7145 - loss: 0.5808
# Epoch 9: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6711 - auc: 0.7149 - loss: 0.5806 - val_acc: 0.8993 - val_auc: 0.0690 - val_loss: 0.5143
# Epoch 10/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6439 - auc: 0.7113 - loss: 0.5749
# Epoch 10: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6453 - auc: 0.7126 - loss: 0.5745 - val_acc: 0.8255 - val_auc: 0.1345 - val_loss: 0.5401
# Epoch 11/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6685 - auc: 0.7558 - loss: 0.5517
# Epoch 11: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6688 - auc: 0.7559 - loss: 0.5517 - val_acc: 0.8456 - val_auc: 0.0862 - val_loss: 0.5298
# Epoch 12/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6804 - auc: 0.7442 - loss: 0.5612
# Epoch 12: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6806 - auc: 0.7444 - loss: 0.5610 - val_acc: 0.5168 - val_auc: 0.0241 - val_loss: 0.7880
# Epoch 13/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7096 - auc: 0.7805 - loss: 0.5268
# Epoch 13: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7096 - auc: 0.7805 - loss: 0.5269 - val_acc: 0.8523 - val_auc: 0.0759 - val_loss: 0.5154
# Epoch 14/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6697 - auc: 0.7759 - loss: 0.5455
# Epoch 14: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6706 - auc: 0.7757 - loss: 0.5455 - val_acc: 0.9128 - val_auc: 0.0172 - val_loss: 0.5812
# Epoch 15/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6893 - auc: 0.7580 - loss: 0.5397
# Epoch 15: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6892 - auc: 0.7577 - loss: 0.5403 - val_acc: 0.8658 - val_auc: 0.0172 - val_loss: 0.6572
# Epoch 16/100
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6841 - auc: 0.7543 - loss: 0.5523
# Epoch 16: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6844 - auc: 0.7548 - loss: 0.5521 - val_acc: 0.7248 - val_auc: 0.0655 - val_loss: 0.6681
# Epoch 17/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7044 - auc: 0.8004 - loss: 0.5244
# Epoch 17: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7043 - auc: 0.8002 - loss: 0.5245 - val_acc: 0.8926 - val_auc: 0.0172 - val_loss: 0.4967
# Epoch 18/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7345 - auc: 0.7958 - loss: 0.5217
# Epoch 18: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7342 - auc: 0.7956 - loss: 0.5219 - val_acc: 0.9530 - val_auc: 0.0345 - val_loss: 0.4536
# Epoch 19/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7180 - auc: 0.7695 - loss: 0.5260
# Epoch 19: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7178 - auc: 0.7695 - loss: 0.5262 - val_acc: 0.8926 - val_auc: 0.0448 - val_loss: 0.5065
# Epoch 20/100
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6673 - auc: 0.7506 - loss: 0.5520
# Epoch 20: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6675 - auc: 0.7507 - loss: 0.5519 - val_acc: 0.9060 - val_auc: 0.0621 - val_loss: 0.4935
# Epoch 21/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7114 - auc: 0.7675 - loss: 0.5317
# Epoch 21: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7113 - auc: 0.7677 - loss: 0.5317 - val_acc: 0.8658 - val_auc: 0.0724 - val_loss: 0.5113
# Epoch 22/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7461 - auc: 0.7931 - loss: 0.5144
# Epoch 22: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7453 - auc: 0.7924 - loss: 0.5152 - val_acc: 0.9530 - val_auc: 0.0345 - val_loss: 0.4414
# Epoch 23/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7076 - auc: 0.7967 - loss: 0.5125
# Epoch 23: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7078 - auc: 0.7966 - loss: 0.5127 - val_acc: 0.8926 - val_auc: 0.0345 - val_loss: 0.5886
# Epoch 24/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7350 - auc: 0.8103 - loss: 0.5109
# Epoch 24: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7349 - auc: 0.8102 - loss: 0.5110 - val_acc: 0.8523 - val_auc: 0.1621 - val_loss: 0.4631
# Epoch 25/100
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7095 - auc: 0.7887 - loss: 0.5256
# Epoch 25: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7090 - auc: 0.7879 - loss: 0.5266 - val_acc: 0.8993 - val_auc: 0.0483 - val_loss: 0.5149
# Epoch 26/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7169 - auc: 0.8000 - loss: 0.5144
# Epoch 26: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7172 - auc: 0.7992 - loss: 0.5153 - val_acc: 0.9060 - val_auc: 0.0862 - val_loss: 0.4904
# Epoch 27/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7213 - auc: 0.7926 - loss: 0.5218
# Epoch 27: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7212 - auc: 0.7926 - loss: 0.5218 - val_acc: 0.8859 - val_auc: 0.0724 - val_loss: 0.4750
# Epoch 28/100
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7319 - auc: 0.7991 - loss: 0.5294
# Epoch 28: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7320 - auc: 0.7992 - loss: 0.5293 - val_acc: 0.9597 - val_auc: 0.0310 - val_loss: 0.4809
# Epoch 29/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7131 - auc: 0.7855 - loss: 0.5156
# Epoch 29: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7132 - auc: 0.7856 - loss: 0.5157 - val_acc: 0.8926 - val_auc: 0.0724 - val_loss: 0.4777
# Epoch 30/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7401 - auc: 0.8179 - loss: 0.4898
# Epoch 30: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7397 - auc: 0.8174 - loss: 0.4904 - val_acc: 0.9195 - val_auc: 0.2138 - val_loss: 0.4144
# Epoch 31/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6565 - auc: 0.7425 - loss: 0.5589
# Epoch 31: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6572 - auc: 0.7432 - loss: 0.5581 - val_acc: 0.9262 - val_auc: 0.1793 - val_loss: 0.4424
# Epoch 32/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7028 - auc: 0.7540 - loss: 0.5721
# Epoch 32: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7036 - auc: 0.7552 - loss: 0.5705 - val_acc: 0.8792 - val_auc: 0.1000 - val_loss: 0.5202
# Epoch 33/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7151 - auc: 0.7838 - loss: 0.5094
# Epoch 33: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7149 - auc: 0.7838 - loss: 0.5098 - val_acc: 0.8859 - val_auc: 0.1483 - val_loss: 0.5044
# Epoch 34/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7372 - auc: 0.8091 - loss: 0.4990
# Epoch 34: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7363 - auc: 0.8081 - loss: 0.5000 - val_acc: 0.9732 - val_auc: 0.1069 - val_loss: 0.4519
# Epoch 35/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7070 - auc: 0.7661 - loss: 0.5375
# Epoch 35: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7070 - auc: 0.7665 - loss: 0.5371 - val_acc: 0.9530 - val_auc: 0.1276 - val_loss: 0.4433
# Epoch 36/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6909 - auc: 0.7782 - loss: 0.5314
# Epoch 36: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6920 - auc: 0.7793 - loss: 0.5305 - val_acc: 0.8322 - val_auc: 0.2000 - val_loss: 0.4724
# Epoch 37/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7217 - auc: 0.7833 - loss: 0.5213
# Epoch 37: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7211 - auc: 0.7835 - loss: 0.5212 - val_acc: 0.9329 - val_auc: 0.2069 - val_loss: 0.4086
# Epoch 38/100
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7253 - auc: 0.7870 - loss: 0.5314
# Epoch 38: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7255 - auc: 0.7870 - loss: 0.5312 - val_acc: 0.9732 - val_auc: 0.0828 - val_loss: 0.4523
# Epoch 39/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7289 - auc: 0.7871 - loss: 0.5213
# Epoch 39: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7290 - auc: 0.7874 - loss: 0.5211 - val_acc: 0.8658 - val_auc: 0.1000 - val_loss: 0.5327
# Epoch 40/100
# 248/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7521 - auc: 0.8181 - loss: 0.4727
# Epoch 40: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7513 - auc: 0.8177 - loss: 0.4735 - val_acc: 0.8658 - val_auc: 0.1207 - val_loss: 0.5150
# Epoch 41/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7365 - auc: 0.7938 - loss: 0.5087
# Epoch 41: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7361 - auc: 0.7938 - loss: 0.5090 - val_acc: 0.9262 - val_auc: 0.0448 - val_loss: 0.5414
# Epoch 42/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7254 - auc: 0.8001 - loss: 0.4964
# Epoch 42: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7252 - auc: 0.7998 - loss: 0.4971 - val_acc: 0.8456 - val_auc: 0.2103 - val_loss: 0.4830
# Epoch 43/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7163 - auc: 0.8065 - loss: 0.5032
# Epoch 43: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7159 - auc: 0.8060 - loss: 0.5035 - val_acc: 0.8322 - val_auc: 0.1966 - val_loss: 0.4933
# Epoch 44/100
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7354 - auc: 0.8066 - loss: 0.4949
# Epoch 44: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7347 - auc: 0.8061 - loss: 0.4961 - val_acc: 0.9262 - val_auc: 0.0276 - val_loss: 0.5933
# Epoch 45/100
# 240/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7106 - auc: 0.7943 - loss: 0.5263
# Epoch 45: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7115 - auc: 0.7947 - loss: 0.5257 - val_acc: 0.9530 - val_auc: 0.0690 - val_loss: 0.4888
# Epoch 46/100
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7370 - auc: 0.8150 - loss: 0.4978
# Epoch 46: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7370 - auc: 0.8150 - loss: 0.4979 - val_acc: 0.9463 - val_auc: 0.1276 - val_loss: 0.5133
# Epoch 47/100
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7512 - auc: 0.7991 - loss: 0.4871
# Epoch 47: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7510 - auc: 0.7993 - loss: 0.4874 - val_acc: 0.9396 - val_auc: 0.0586 - val_loss: 0.5076
# Epoch 48/100
# 248/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7325 - auc: 0.8207 - loss: 0.5064
# Epoch 48: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7322 - auc: 0.8203 - loss: 0.5064 - val_acc: 0.9195 - val_auc: 0.1379 - val_loss: 0.4427
# Epoch 49/100
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7598 - auc: 0.8131 - loss: 0.4919
# Epoch 49: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7597 - auc: 0.8131 - loss: 0.4919 - val_acc: 0.9128 - val_auc: 0.0414 - val_loss: 0.4982
# Epoch 50/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7074 - auc: 0.7854 - loss: 0.5263
# Epoch 50: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7080 - auc: 0.7859 - loss: 0.5258 - val_acc: 0.9396 - val_auc: 0.1483 - val_loss: 0.4572
# Epoch 51/100
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7388 - auc: 0.8212 - loss: 0.4978
# Epoch 51: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7388 - auc: 0.8211 - loss: 0.4978 - val_acc: 0.9597 - val_auc: 0.0345 - val_loss: 0.4889
# Epoch 52/100
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7283 - auc: 0.8165 - loss: 0.4854
# Epoch 52: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7284 - auc: 0.8167 - loss: 0.4856 - val_acc: 0.8121 - val_auc: 0.0517 - val_loss: 0.5483
# Epoch 53/100
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7121 - auc: 0.8121 - loss: 0.4943
# Epoch 53: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7131 - auc: 0.8124 - loss: 0.4944 - val_acc: 0.9329 - val_auc: 0.0621 - val_loss: 0.4713
# Epoch 54/100
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7512 - auc: 0.8406 - loss: 0.4669
# Epoch 54: val_loss did not improve from 0.34957
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7505 - auc: 0.8399 - loss: 0.4675 - val_acc: 0.8523 - val_auc: 0.1517 - val_loss: 0.5163
# Epoch 55/100
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7175 - auc: 0.8114 - loss: 0.4943
# Epoch 55: val_loss did not improve from 0.34957
# ...
# Epoch 57/100
# 279/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7301 - auc: 0.7859 - loss: 0.5103
# Epoch 57: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7301 - auc: 0.7859 - loss: 0.5104 - val_acc: 0.8378 - val_auc: 0.4839 - val_loss: 0.5817
# Epoch 58/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7264 - auc: 0.8054 - loss: 0.5145
# Epoch 58: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7263 - auc: 0.8054 - loss: 0.5145 - val_acc: 0.8378 - val_auc: 0.5376 - val_loss: 0.5574
# Epoch 59/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7064 - auc: 0.7617 - loss: 0.5244
# Epoch 59: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7063 - auc: 0.7619 - loss: 0.5242 - val_acc: 0.8378 - val_auc: 0.6048 - val_loss: 0.5856
# Epoch 60/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6954 - auc: 0.7787 - loss: 0.5136
# Epoch 60: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6956 - auc: 0.7788 - loss: 0.5135 - val_acc: 0.8378 - val_auc: 0.6263 - val_loss: 0.5607
# Epoch 61/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7022 - auc: 0.7876 - loss: 0.5229
# Epoch 61: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7023 - auc: 0.7875 - loss: 0.5229 - val_acc: 0.8378 - val_auc: 0.6398 - val_loss: 0.5838
# Epoch 62/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7447 - auc: 0.7741 - loss: 0.5138
# Epoch 62: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7440 - auc: 0.7747 - loss: 0.5134 - val_acc: 0.8378 - val_auc: 0.6586 - val_loss: 0.5366
# Epoch 63/100
# 272/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.6994 - auc: 0.7935 - loss: 0.5047
# Epoch 63: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7012 - auc: 0.7941 - loss: 0.5041 - val_acc: 0.8378 - val_auc: 0.6156 - val_loss: 0.5378
# Epoch 64/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7234 - auc: 0.8122 - loss: 0.4893
# Epoch 64: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7232 - auc: 0.8117 - loss: 0.4896 - val_acc: 0.8108 - val_auc: 0.4677 - val_loss: 0.6048
# Epoch 65/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7364 - auc: 0.8012 - loss: 0.4920
# Epoch 65: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7366 - auc: 0.8011 - loss: 0.4922 - val_acc: 0.8378 - val_auc: 0.5565 - val_loss: 0.5395
# Epoch 66/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7333 - auc: 0.7846 - loss: 0.5069
# Epoch 66: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7334 - auc: 0.7847 - loss: 0.5068 - val_acc: 0.8378 - val_auc: 0.4435 - val_loss: 0.5587
# Epoch 67/100
# 271/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7410 - auc: 0.8157 - loss: 0.5003
# Epoch 67: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7409 - auc: 0.8153 - loss: 0.5002 - val_acc: 0.7838 - val_auc: 0.4973 - val_loss: 0.5465
# Epoch 68/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7438 - auc: 0.7928 - loss: 0.5154
# Epoch 68: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7438 - auc: 0.7929 - loss: 0.5152 - val_acc: 0.8378 - val_auc: 0.5860 - val_loss: 0.5211
# Epoch 69/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7337 - auc: 0.7959 - loss: 0.4879
# Epoch 69: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7339 - auc: 0.7960 - loss: 0.4877 - val_acc: 0.8378 - val_auc: 0.4812 - val_loss: 0.5526
# Epoch 70/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7458 - auc: 0.8100 - loss: 0.4830
# Epoch 70: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7458 - auc: 0.8099 - loss: 0.4831 - val_acc: 0.8378 - val_auc: 0.5000 - val_loss: 0.5126
# Epoch 71/100
# 281/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7328 - auc: 0.8004 - loss: 0.4955
# Epoch 71: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7331 - auc: 0.8007 - loss: 0.4953 - val_acc: 0.8378 - val_auc: 0.5403 - val_loss: 0.5290
# Epoch 72/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7326 - auc: 0.8070 - loss: 0.4936
# Epoch 72: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7327 - auc: 0.8067 - loss: 0.4937 - val_acc: 0.8378 - val_auc: 0.4812 - val_loss: 0.5754
# Epoch 73/100
# 274/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7604 - auc: 0.7806 - loss: 0.4718
# Epoch 73: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7598 - auc: 0.7812 - loss: 0.4725 - val_acc: 0.8108 - val_auc: 0.6075 - val_loss: 0.5491
# Epoch 74/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7647 - auc: 0.8168 - loss: 0.4716
# Epoch 74: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7647 - auc: 0.8168 - loss: 0.4717 - val_acc: 0.8378 - val_auc: 0.4677 - val_loss: 0.5308
# Epoch 75/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7361 - auc: 0.7980 - loss: 0.4952
# Epoch 75: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7362 - auc: 0.7980 - loss: 0.4951 - val_acc: 0.7297 - val_auc: 0.5269 - val_loss: 0.5855
# Epoch 76/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7349 - auc: 0.7930 - loss: 0.4914
# Epoch 76: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7349 - auc: 0.7930 - loss: 0.4914 - val_acc: 0.8378 - val_auc: 0.5887 - val_loss: 0.5135
# Epoch 77/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7473 - auc: 0.8112 - loss: 0.4741
# Epoch 77: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7473 - auc: 0.8114 - loss: 0.4741 - val_acc: 0.7838 - val_auc: 0.5215 - val_loss: 0.5744
# Epoch 78/100
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7309 - auc: 0.7962 - loss: 0.4942
# Epoch 78: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7309 - auc: 0.7962 - loss: 0.4942 - val_acc: 0.7297 - val_auc: 0.5108 - val_loss: 0.6100
# Epoch 79/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7733 - auc: 0.8308 - loss: 0.4624
# Epoch 79: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7731 - auc: 0.8307 - loss: 0.4625 - val_acc: 0.7027 - val_auc: 0.5511 - val_loss: 0.5795
# Epoch 80/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7561 - auc: 0.8231 - loss: 0.4648
# Epoch 80: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7559 - auc: 0.8230 - loss: 0.4650 - val_acc: 0.6216 - val_auc: 0.5591 - val_loss: 0.6288
# Epoch 81/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7498 - auc: 0.8041 - loss: 0.4768
# Epoch 81: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7499 - auc: 0.8041 - loss: 0.4767 - val_acc: 0.8108 - val_auc: 0.6290 - val_loss: 0.5369
# Epoch 82/100
# 281/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7357 - auc: 0.8238 - loss: 0.4772
# Epoch 82: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7360 - auc: 0.8238 - loss: 0.4771 - val_acc: 0.8378 - val_auc: 0.6183 - val_loss: 0.5363
# Epoch 83/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7614 - auc: 0.7936 - loss: 0.4799
# Epoch 83: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7615 - auc: 0.7942 - loss: 0.4795 - val_acc: 0.8108 - val_auc: 0.5403 - val_loss: 0.5415
# Epoch 84/100
# 272/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7714 - auc: 0.8279 - loss: 0.4595
# Epoch 84: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7706 - auc: 0.8278 - loss: 0.4599 - val_acc: 0.8378 - val_auc: 0.4570 - val_loss: 0.5418
# Epoch 85/100
# 274/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7518 - auc: 0.8233 - loss: 0.4650
# Epoch 85: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7513 - auc: 0.8224 - loss: 0.4656 - val_acc: 0.8108 - val_auc: 0.4704 - val_loss: 0.5745
# Epoch 86/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7549 - auc: 0.8147 - loss: 0.4886
# Epoch 86: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7549 - auc: 0.8147 - loss: 0.4886 - val_acc: 0.6216 - val_auc: 0.5215 - val_loss: 0.6083
# Epoch 87/100
# 279/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7267 - auc: 0.8002 - loss: 0.5037
# Epoch 87: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7272 - auc: 0.8004 - loss: 0.5032 - val_acc: 0.7568 - val_auc: 0.5376 - val_loss: 0.5519
# Epoch 88/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7552 - auc: 0.8372 - loss: 0.4704
# Epoch 88: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7553 - auc: 0.8371 - loss: 0.4704 - val_acc: 0.8378 - val_auc: 0.4382 - val_loss: 0.5518
# Epoch 89/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7578 - auc: 0.8251 - loss: 0.4779
# Epoch 89: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7579 - auc: 0.8250 - loss: 0.4779 - val_acc: 0.8108 - val_auc: 0.4328 - val_loss: 0.5771
# Epoch 90/100
# 282/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7766 - auc: 0.8432 - loss: 0.4478
# Epoch 90: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7764 - auc: 0.8431 - loss: 0.4478 - val_acc: 0.8378 - val_auc: 0.4785 - val_loss: 0.5093
# Epoch 91/100
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7253 - auc: 0.8078 - loss: 0.5120
# Epoch 91: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7256 - auc: 0.8079 - loss: 0.5117 - val_acc: 0.8378 - val_auc: 0.4274 - val_loss: 0.5214
# Epoch 92/100
# 278/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7249 - auc: 0.8139 - loss: 0.4818
# Epoch 92: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7251 - auc: 0.8136 - loss: 0.4818 - val_acc: 0.8378 - val_auc: 0.4462 - val_loss: 0.5464
# Epoch 93/100
# 279/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7721 - auc: 0.8254 - loss: 0.4541
# Epoch 93: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7717 - auc: 0.8252 - loss: 0.4543 - val_acc: 0.7838 - val_auc: 0.4543 - val_loss: 0.5537
# Epoch 94/100
# 275/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7514 - auc: 0.8118 - loss: 0.4852
# Epoch 94: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7513 - auc: 0.8122 - loss: 0.4846 - val_acc: 0.8108 - val_auc: 0.4731 - val_loss: 0.5603
# Epoch 95/100
# 277/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7778 - auc: 0.8318 - loss: 0.4589
# Epoch 95: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7776 - auc: 0.8321 - loss: 0.4584 - val_acc: 0.8378 - val_auc: 0.3602 - val_loss: 0.5814
# Epoch 96/100
# 274/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7506 - auc: 0.7863 - loss: 0.4947
# Epoch 96: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7504 - auc: 0.7871 - loss: 0.4942 - val_acc: 0.5405 - val_auc: 0.4140 - val_loss: 0.6251
# Epoch 97/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.7835 - auc: 0.8319 - loss: 0.4611
# Epoch 97: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7833 - auc: 0.8319 - loss: 0.4612 - val_acc: 0.8108 - val_auc: 0.4409 - val_loss: 0.5525
# Epoch 98/100
# 283/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.8011 - auc: 0.8706 - loss: 0.4091
# Epoch 98: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.8007 - auc: 0.8702 - loss: 0.4096 - val_acc: 0.7568 - val_auc: 0.3441 - val_loss: 0.6109
# Epoch 99/100
# 281/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7977 - auc: 0.8593 - loss: 0.4352
# Epoch 99: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7972 - auc: 0.8590 - loss: 0.4356 - val_acc: 0.5676 - val_auc: 0.4247 - val_loss: 0.6747
# Epoch 100/100
# 280/285 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.7657 - auc: 0.8274 - loss: 0.4596
# Epoch 100: val_loss did not improve from 0.43523
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.7658 - auc: 0.8275 - loss: 0.4596 - val_acc: 0.6216 - val_auc: 0.2796 - val_loss: 0.6991
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fold 7 | TEST@0.5  ACC=0.9323 | PREC=0.0000 | REC=0.0000 | F1=0.0000 | AUC=0.8387 | SPEC=1.0000 | n=133
# Fold 7 | TEST@J    ACC=0.8045 | PREC=0.2571 | REC=1.0000 | F1=0.4091 | AUC=0.8387 | SPEC=0.7903 | thr=0.3429, J=0.7903
# Confusion matrix (@0.5):
#  [[124   0]
#  [  9   0]]
# Classification report (@0.5):
#                precision    recall  f1-score   support
#
#            0      0.932     1.000     0.965       124
#            1      0.000     0.000     0.000         9
#
#     accuracy                          0.932       133
#    macro avg      0.466     0.500     0.482       133
# weighted avg      0.869     0.932     0.900       133
#
#
# === TEST metrics per fold — threshold 0.5 ===
# AUC : [np.float64(0.6948), np.float64(0.4166), np.float64(0.4169), np.float64(0.6702), np.float64(0.0863), np.float64(0.4567), np.float64(0.8387)]
# ACC : [0.6565, 0.5536, 0.3623, 0.6167, 0.4524, 0.3822, 0.9323]
# PREC: [0.0, 0.0, 0.2432, 0.0, 0.0196, 0.0, 0.0]
# REC : [0.0, 0.0, 0.1304, 0.0, 0.05, 0.0, 0.0]
# SPEC: [np.float64(1.0), np.float64(0.9254), np.float64(0.5942), np.float64(0.9929), np.float64(0.5283), np.float64(1.0), np.float64(1.0)]
# F1  : [0.0, 0.0, 0.1698, 0.0, 0.0282, 0.0, 0.0]
#
# === TEST metrics per fold — Youden-J (on TEST) ===
# AUC@J : [np.float64(0.6948), np.float64(0.4166), np.float64(0.4169), np.float64(0.6702), np.float64(0.0863), np.float64(0.4567), np.float64(0.8387)]
# ACC@J : [0.7405, 0.5625, 0.6014, 0.6035, 0.1984, 0.7452, 0.8045]
# PREC@J: [0.5775, 0.4787, 0.5636, 0.4886, 0.1653, 0.7436, 0.2571]
# REC@J : [0.9111, 1.0, 0.8986, 1.0, 1.0, 0.8969, 1.0]
# SPEC@J: [np.float64(0.6512), np.float64(0.2687), np.float64(0.3043), np.float64(0.3617), np.float64(0.0472), np.float64(0.5), np.float64(0.7903)]
# F1@J  : [0.7069, 0.6475, 0.6927, 0.6565, 0.2837, 0.8131, 0.4091]
#
# === Mean ± SD across folds (TEST) — 0.5 ===
#          AUC: 0.5115 ± 0.2292
#          ACC: 0.5651 ± 0.1826
#    Precision: 0.0376 ± 0.0842
#       Recall: 0.0258 ± 0.0461
#  Specificity: 0.8630 ± 0.1932
#           F1: 0.0283 ± 0.0586
#
# === Mean ± SD across folds (TEST) — Youden-J (on TEST) ===
#        AUC@J: 0.5115 ± 0.2292
#        ACC@J: 0.6080 ± 0.1870
#  Precision@J: 0.4678 ± 0.1827
#     Recall@J: 0.9581 ± 0.0486
# Specificity@J: 0.4176 ± 0.2316
#         F1@J: 0.6014 ± 0.1721
#
# Saved TEST-only per-fold metrics to cv7_img_fold_metrics.csv
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
